# %%
import math
import pickle
import random
from typing import Dict, List, Tuple

from gensim.corpora import Dictionary

# %%
with open(r"../data/interim/positive_words.pkl", "rb") as input_file:
    positive_docs = pickle.load(input_file)

# %%
with open(r"../data/interim/negative_words.pkl", "rb") as input_file:
    negative_docs = pickle.load(input_file)

# %%
math.floor(5.3)
# Out:
# 5

# %%
negative_docs
# Out:
# [['town',
#   'especially',
#   'be',
#   'go',
#   'antiguena',
#   'good',
#   'sized',
#   'private',
#   'twin',
#   'room',
#   'shared_bathroom',
#   'great',
#   'price',
#   'nice',
#   'ish',
#   'garden',
#   'swing',
#   'basic',
#   'bathroom',
#   'tatty',
#   'hot',
#   'shower',
#   'always',
#   'keep',
#   'water',
#   'flow',
#   'slow',
#   'super',
#   'basic',
#   'pretty',
#   'dirty',
#   'kitchenette',
#   'load',
#   'cat',
#   'dog',
#   'cheap',
#   'basic',
#   's'],
#  ['go',
#   'hotel',
#   'directly',
#   'book',
#   'room',
#   'receptionist',
#   'first',
#   'really',
#   'high',
#   'price',
#   'lower',
#   'ask',
#   'much',
#   'cost',
#   'qetale',
#   'comission',
#   'rate',
#   'dollar',
#   'know',
#   'randomly',
#   'gove',
#   'non',
#   'exist',
#   'rate',
#   'lower',
#   'real',
#   'rate',
#   'agree',
#   'price',
#   'include',
#   'breakfast',
#   'follow',
#   'morning',
#   'get',
#   'breakfast',
#   'receive',
#   'plain',
#   'piece',
#   'toast',
#   'fruit',
#   'theother',
#   'table',
#   'receive',
#   'also',
#   'egg',
#   'ask',
#   'also',
#   'egg',
#   'reply',
#   'come',
#   'breakfast',
#   'pay',
#   'good',
#   'experience',
#   'hotel',
#   'place',
#   'stay'],
#  ['go',
#   'break',
#   'good',
#   'bad',
#   'good_location',
#   'free_breakfast',
#   'warm',
#   'helpful',
#   'staff',
#   'hour',
#   'massage',
#   'bad',
#   'small',
#   'room',
#   'great',
#   'air_circulation',
#   'awful',
#   'quality',
#   'bed',
#   'noisy',
#   'dog',
#   'let',
#   'decide',
#   'important',
#   'awful',
#   'bed',
#   'kill',
#   'massage',
#   'make',
#   'feel',
#   'well',
#   'choice',
#   'sure',
#   'come_back',
#   'back',
#   'handle',
#   'way',
#   'night',
#   'advertise',
#   'totally',
#   'wrong',
#   'end',
#   'night',
#   'triple',
#   'room',
#   'really',
#   'worth',
#   'many',
#   'choice'],
#  ['night',
#   'delay',
#   'bus',
#   'journey',
#   'original',
#   'accommodation',
#   'give',
#   'away',
#   'place',
#   'could',
#   'find',
#   'could',
#   'accommodate',
#   'grateful',
#   'price',
#   'wifi',
#   'seem',
#   'decent',
#   'value',
#   'however',
#   'room',
#   'incredibly',
#   'basic',
#   'unclean',
#   'mosquito',
#   'everywhere',
#   'insect',
#   'floor',
#   'bathroom',
#   'key',
#   'door',
#   'apparently',
#   'however',
#   'lock',
#   'inside',
#   'feel',
#   'secure',
#   'place',
#   'stay',
#   'night_guard',
#   'big',
#   'lock',
#   'night',
#   'staff',
#   'limit',
#   'test',
#   'see',
#   'much',
#   'else',
#   'bathroom',
#   'bedroom',
#   'morning',
#   'come'],
#  [],
#  ['dirty',
#   'offer',
#   'towel',
#   'sheet',
#   'nasty',
#   'bathroom',
#   'gross',
#   'owner',
#   'take',
#   'dollar',
#   'give',
#   'receipt',
#   'terrible'],
#  ['use',
#   'tourist',
#   'shuttle',
#   'get',
#   'back_forth',
#   'country',
#   'pretty',
#   'often',
#   'book',
#   'shuttle',
#   'shuttle',
#   'woman',
#   'sit',
#   'phone',
#   'look',
#   'time',
#   'tell',
#   'come',
#   'minute',
#   'standard',
#   'sometimes',
#   'bus',
#   'pick',
#   'early',
#   'sometimes',
#   'pick',
#   'minute',
#   'late',
#   'today',
#   'bus',
#   'minute',
#   'late',
#   'still',
#   'wait',
#   'front',
#   'woman',
#   'say',
#   'fault',
#   'true',
#   'charge',
#   'inflated',
#   'price',
#   'later',
#   'shuttle',
#   'say',
#   'less',
#   'people',
#   'shuttle',
#   'price',
#   'expensive',
#   'finally',
#   'call',
#   'shuttle',
#   'company',
#   'say',
#   'pick',
#   'people'],
#  ['stay',
#   'home',
#   'last',
#   'weekend',
#   'want',
#   'room',
#   'nice',
#   'hotel',
#   'already',
#   'want',
#   'see',
#   'hotel',
#   'maybe',
#   'even',
#   'look',
#   'room',
#   'meeting',
#   'friend',
#   'take',
#   'look',
#   'arrive',
#   'early',
#   'clerk',
#   'personal',
#   'call',
#   'refuse',
#   'acknowledge',
#   'even',
#   'look',
#   'minute',
#   'early',
#   'take',
#   'look',
#   'lobby',
#   'pool',
#   'use',
#   'man',
#   'room',
#   'go',
#   'wild',
#   'start',
#   'scream',
#   'man',
#   'room',
#   'guest',
#   'scream',
#   'embarrassing',
#   'basically',
#   'kick',
#   'hotel',
#   'group'],
#  ['book',
#   'hotel',
#   'pool',
#   'parking',
#   'good',
#   'review',
#   'request',
#   'upstairs',
#   'room',
#   'balcony',
#   'get',
#   'room',
#   'clean',
#   'however',
#   'way',
#   'overpriced',
#   'get',
#   'tiny',
#   'quaint',
#   'rather',
#   'charming',
#   'room',
#   'big',
#   'drawback',
#   'noise',
#   'venue',
#   'bar',
#   'loud_music',
#   'reverberate',
#   'wall',
#   'way',
#   'go',
#   'able',
#   'sleep',
#   'credit',
#   'management',
#   'ring',
#   'bar',
#   'ask',
#   'turn',
#   'still',
#   'terribly',
#   'loud',
#   'manager',
#   'come',
#   'offer',
#   'room',
#   'hotel',
#   'happy'],
#  ['arrive',
#   'hotel',
#   'around',
#   'already',
#   'read',
#   'previous',
#   'review',
#   'want',
#   'charge',
#   'early',
#   'check',
#   'expect',
#   'bad',
#   'first',
#   'tell',
#   'room',
#   'available',
#   'wait',
#   'couple',
#   'hour',
#   'minute',
#   'wait',
#   'receptionist',
#   'call',
#   'say',
#   'room',
#   'available',
#   'charging',
#   'hour',
#   'early',
#   'check',
#   'standard',
#   'checking',
#   'time',
#   'pm',
#   'ask',
#   'additional',
#   'order',
#   'check',
#   'disappoint',
#   'upset',
#   'treated',
#   'way',
#   'specially',
#   'explain',
#   'already',
#   'pay',
#   'almost',
#   'red',
#   'eye',
#   'fly',
#   'want',
#   'rest',
#   'somehow',
#   'negotiate',
#   'still',
#   'rip',
#   'disgusting',
#   'decided_stay',
#   'additional',
#   'night'],
#  ['stay',
#   'total',
#   'nearly',
#   'week',
#   'visit',
#   'visit',
#   'already',
#   'reserve',
#   'family',
#   'friend',
#   'stranger',
#   'become',
#   'friend',
#   'slap',
#   'dash',
#   'haphazard',
#   'time',
#   'much',
#   'wifi',
#   'wonky',
#   'back',
#   'recommend',
#   'friend',
#   'oasis',
#   'expectation',
#   'courtyard',
#   'walk',
#   'way',
#   'hang',
#   'dense',
#   'flower',
#   'vine',
#   'spring',
#   'summer',
#   'add',
#   'flowering',
#   'shrub',
#   'tree',
#   'perfume',
#   'small',
#   'aspire',
#   'main',
#   'courtyard',
#   'add',
#   'bouquet',
#   'soundtrack',
#   'splash',
#   'water',
#   'perfect',
#   'place',
#   'sip',
#   'beer',
#   'read',
#   'book',
#   'fall'],
#  ['hotel',
#   'medium',
#   'size',
#   'make',
#   'big',
#   'effort',
#   'give',
#   'feel',
#   'colonial',
#   'town',
#   'feel',
#   'authentic',
#   'walkable',
#   'distance',
#   'central_park',
#   'block',
#   'food',
#   'good',
#   'coffee',
#   'however',
#   'people',
#   'bite',
#   'cold',
#   'make',
#   'eye',
#   'contact',
#   'bathroom',
#   'design',
#   'smart',
#   'step',
#   'open',
#   'door',
#   'light',
#   'switch',
#   'step',
#   'easily',
#   'trip',
#   'dark',
#   'shower',
#   'partial',
#   'wall',
#   'water',
#   'get',
#   'floor',
#   'make',
#   'slippery',
#   'pool',
#   'pretty',
#   'warmish',
#   'water',
#   'area',
#   'well',
#   'take',
#   'care'],
#  ['room',
#   'front',
#   'entrance',
#   'squeaky',
#   'gate',
#   'drop',
#   'oil',
#   'would',
#   'sort',
#   'problem',
#   'second',
#   'come',
#   'go',
#   'also',
#   'people',
#   'tend',
#   'stop',
#   'front',
#   'room',
#   'talk',
#   'could',
#   'look',
#   'window',
#   'closed',
#   'shutter',
#   'however',
#   'room',
#   'dark',
#   'maybe',
#   'room',
#   'upstairs',
#   'well',
#   'old',
#   'look',
#   'worn',
#   'fit',
#   'double',
#   'mattress',
#   'also',
#   'pillow',
#   'pretty',
#   'horrendous',
#   'towel',
#   'bite',
#   'threadbare',
#   'plus_side',
#   'shower',
#   'good',
#   'room',
#   'clean',
#   'could',
#   'decent',
#   'place',
#   'need',
#   'look',
#   'certainly',
#   'overpriced'],
#  ['place',
#   'dump',
#   'day',
#   'evening',
#   'day',
#   'shower',
#   'disgusting',
#   'waste',
#   'money',
#   'less',
#   'money',
#   'stay',
#   'hotstel'],
#  ['hotel',
#   'terrible',
#   'measureable',
#   'way',
#   'entire',
#   'stay',
#   'people',
#   'hotel',
#   'order',
#   'door',
#   'lock',
#   'properly',
#   'take',
#   'nearly',
#   'go',
#   'shower',
#   'extremely',
#   'cold',
#   'lock',
#   'big',
#   'issue',
#   'travel',
#   'girl',
#   'sit',
#   'shower',
#   'overall',
#   'stay',
#   'hotel',
#   'ruin',
#   'visit',
#   'beautiful',
#   'town'],
#  ['friendly',
#   'staff',
#   'room',
#   'amenity',
#   'close',
#   'town',
#   'centre',
#   'unlucky',
#   'apartment',
#   'own',
#   'really',
#   'like',
#   'sound',
#   'voice',
#   'like',
#   'drink',
#   'lot',
#   'make',
#   'stay',
#   'unpleasant'],
#  ['fairly',
#   'affordable',
#   'location',
#   'good',
#   'fairly',
#   'busy',
#   'loud',
#   'street',
#   'basic',
#   'amenity',
#   'work',
#   'clean',
#   'safe',
#   'place',
#   'nice',
#   'little',
#   'courtyard',
#   'hairdryer',
#   'overall',
#   'decent',
#   'place',
#   'picky'],
#  ['former',
#   'hotel',
#   'other',
#   'say',
#   'review',
#   'room',
#   'super',
#   'clean',
#   'bathroom',
#   'nice',
#   'flat',
#   'screen',
#   'tv',
#   'room',
#   'truly',
#   'cute',
#   'little',
#   'hotel',
#   'exceptional',
#   'nice',
#   'kind',
#   'super',
#   'friendly',
#   'owner',
#   'son',
#   's',
#   'make',
#   'review',
#   'little',
#   'difficult',
#   'want',
#   'love',
#   'hotel',
#   'support',
#   'hotel',
#   'owner',
#   'thing',
#   'likely',
#   'struggle',
#   'stay',
#   'kinda',
#   'noisey',
#   'parking',
#   'inside',
#   'literally',
#   'bed',
#   'asleep',
#   'pm',
#   'awaken',
#   'sound',
#   'car',
#   'backing',
#   'downstairs',
#   'noise',
#   'loud',
#   'enough',
#   'sound',
#   'sleep',
#   'garage'],
#  ['great',
#   'set',
#   'relax',
#   'lot',
#   'really',
#   'positive',
#   'stuff',
#   'resort',
#   'gym',
#   'good',
#   'pool',
#   'area',
#   'great',
#   'kid',
#   'playground',
#   'room',
#   'recently',
#   'renovate',
#   'smart',
#   'dinner',
#   'restaurant',
#   'good',
#   'staff',
#   'also',
#   'lovely',
#   'friendly_helpful',
#   'relaxed',
#   'vibe',
#   'negative',
#   'stuff',
#   'mainly',
#   'hinge',
#   'reception',
#   'experience',
#   'honest',
#   'arrive',
#   'pm',
#   'guy',
#   'reception',
#   'large',
#   'wedding',
#   'party',
#   'take',
#   'place',
#   'probably',
#   'bit',
#   'stressed',
#   'however',
#   'welcome',
#   'quite',
#   'dismissive',
#   'want',
#   'sign',
#   'various',
#   'paperwork',
#   'key',
#   'send',
#   'way',
#   'travel',
#   'hour',
#   'say'],
#  ['seem',
#   'new',
#   'good',
#   'working',
#   'order',
#   'impecable',
#   'breakfast',
#   'good',
#   'far',
#   'negative',
#   'parking',
#   'nightmare',
#   'parking',
#   'send',
#   'sketchy',
#   'place',
#   'parking',
#   'attendant',
#   'seem',
#   'confused',
#   'hotel',
#   'come',
#   'car',
#   'would',
#   'block',
#   'exit',
#   'end',
#   'work',
#   'well',
#   'also',
#   'bathroom',
#   'small',
#   'place',
#   'put',
#   'toiletry',
#   'bag',
#   'finally',
#   'hotel',
#   'heavy',
#   'traffic',
#   'time',
#   'weekend'],
#  ['friend',
#   'book',
#   'online',
#   'online',
#   'say',
#   'room',
#   'leave',
#   'book',
#   'show',
#   'hotel',
#   'receptionist',
#   'lady',
#   'turn',
#   'away',
#   'room',
#   'available',
#   'say',
#   'small',
#   'room',
#   'small',
#   'room',
#   'would',
#   'put',
#   'extra',
#   'bed',
#   'would',
#   'tight',
#   'look',
#   'accommodation',
#   'ask',
#   'cancel',
#   'reservation',
#   'charge',
#   'card',
#   'say',
#   'would',
#   'cancel',
#   'stay',
#   'night',
#   'hotel',
#   'card',
#   'still',
#   'get',
#   'charge',
#   'go',
#   'back',
#   'ask',
#   'stay',
#   'get',
#   'refund',
#   'night',
#   'suppose',
#   'reservation',
#   'come',
#   'office',
#   'card',
#   'charge',
#   'could',
#   'cancel',
#   'lady'],
#  ['stayed_night',
#   'aware',
#   'high',
#   'rating',
#   'hotel',
#   'agree',
#   'point',
#   'mention',
#   'clean',
#   'good',
#   'service',
#   'book',
#   'transportation',
#   'fast',
#   'efficient',
#   'however',
#   'room',
#   'small',
#   'put',
#   'stuff',
#   'closet',
#   'fast',
#   'internet',
#   'small',
#   'tv',
#   'english',
#   'channel',
#   'room',
#   'safe',
#   'visit',
#   'city',
#   'take',
#   'passport',
#   'money',
#   'privacy',
#   'also',
#   'question',
#   'shut',
#   'window',
#   'light',
#   'pass',
#   'would',
#   'see',
#   'room'],
#  ['bed_comfortable',
#   'bite',
#   'short',
#   'foot',
#   'almost',
#   'stick',
#   'bed',
#   'pillow',
#   'thin',
#   'stack',
#   'together',
#   'make',
#   'pillow',
#   'noisy',
#   'use',
#   'earplug',
#   'paint',
#   'bathroom',
#   'peel',
#   'old',
#   'miss',
#   'ring',
#   'hole',
#   'would',
#   'stay',
#   'everywhere',
#   'else',
#   'book',
#   'pay',
#   'night'],
#  ['book',
#   'printout',
#   'confirmation',
#   'arrive',
#   'tourist',
#   'shuttle',
#   'eve',
#   'soon',
#   'mention',
#   'hotel',
#   'name',
#   'driver',
#   'couple',
#   'front',
#   'book',
#   'hotel',
#   'day',
#   'prior',
#   'use',
#   'honor',
#   'think',
#   'bad',
#   'incident',
#   'wrong',
#   'manager',
#   'refuse',
#   'look',
#   'booking_com',
#   'printout',
#   'room',
#   'normally',
#   'problem',
#   'know',
#   'hotel',
#   'tend',
#   'full',
#   'time',
#   'even',
#   'one',
#   'room',
#   'charge',
#   'much',
#   'high',
#   'normal',
#   'rate',
#   'reason',
#   'book',
#   'advance',
#   'luckily',
#   'find'],
#  ['good',
#   'view',
#   'obligingly',
#   'spew',
#   'cloud',
#   'smoke',
#   'dust',
#   'breakfast',
#   'time',
#   'day',
#   'room',
#   'poor',
#   'lighting',
#   'window_opene',
#   'internal',
#   'street',
#   'rather',
#   'useless',
#   'main',
#   'problem',
#   'hotel',
#   'situation',
#   'long',
#   'way',
#   'minute',
#   'walk_centre',
#   'many',
#   'uneven',
#   'surface',
#   'pothole',
#   'route',
#   'dimly',
#   'light',
#   'street',
#   'dark',
#   'necessitate',
#   'taxi',
#   'ride',
#   'especially',
#   'concerned',
#   'safety',
#   'evening',
#   'go',
#   'town',
#   'tend',
#   'stay',
#   'return',
#   'tend',
#   'go_back',
#   'inconvenient',
#   'problem',
#   'breakfast',
#   'absolutely',
#   'disgusting',
#   'coffee',
#   'merely',
#   'poor',
#   'nearest'],
#  ['want',
#   'much',
#   'hotel',
#   'nice',
#   'place',
#   'price',
#   'point',
#   'hotel',
#   'quite',
#   'lovely',
#   'centrally_located',
#   'nice',
#   'garden',
#   'clean',
#   'fantastic',
#   'view',
#   'room',
#   'great',
#   'apart',
#   'soft',
#   'bed',
#   'breakfast',
#   'parking',
#   'site',
#   'inconvenient',
#   'square',
#   'min',
#   'shape',
#   'deal',
#   'would',
#   'overlook',
#   'fact',
#   'first',
#   'day',
#   'constant',
#   'clanging',
#   'bell',
#   'nearby',
#   'church',
#   'complaint',
#   'unfortunately',
#   'loud',
#   'bar',
#   'playing',
#   'music'],
#  ['hate',
#   'write',
#   'arrive',
#   'hotel',
#   'truly',
#   'beautiful',
#   'staff',
#   'lovely',
#   'food',
#   'stay',
#   'friend',
#   'travel',
#   'arrival',
#   'wake',
#   'cover',
#   'way',
#   'spend',
#   'vacation',
#   'horrible',
#   'hotel',
#   'ask',
#   'proof',
#   'provide',
#   'clothe',
#   'change',
#   'room',
#   'appreciate',
#   'bad',
#   'rented',
#   'room',
#   'next',
#   'night',
#   'take',
#   'quickly',
#   'check',
#   'wonderful',
#   'city',
#   'would',
#   'stay'],
#  ['discover',
#   'reservation',
#   'fall',
#   'gain',
#   'room',
#   'generous',
#   'sized',
#   'bathroom',
#   'roomy',
#   'parking',
#   'need',
#   'owner',
#   'lovely',
#   'people',
#   'hotel',
#   'within_walke',
#   'distance',
#   'la_merce',
#   'restaurant',
#   'internet',
#   'service',
#   'close'],
#  ['disappointment',
#   'hotel',
#   'start',
#   'fact',
#   'reservation',
#   'want',
#   'send',
#   'hotel',
#   'complaie',
#   'mention',
#   'day',
#   'exchange',
#   'mail',
#   'own',
#   'confirm',
#   'transfer',
#   'airport',
#   'hotel',
#   'take',
#   'know',
#   'come',
#   'say',
#   'reservation',
#   'end',
#   'gave_us',
#   'room',
#   'discover',
#   'dirty',
#   'noisy',
#   'place',
#   'commune',
#   'photo',
#   'web',
#   'site',
#   'end',
#   'trip',
#   'use',
#   'hotel',
#   'much',
#   'clean',
#   'comfortable',
#   'nicer',
#   'also',
#   'none',
#   'people',
#   'reception',
#   'train',
#   'idea',
#   'accept',
#   'payment'],
#  ['stay',
#   'previously',
#   'decide',
#   'book',
#   'upmarket',
#   'hotel',
#   'final',
#   'night',
#   'flight',
#   'hotel',
#   'decent',
#   'location',
#   'dirty',
#   'comfortable',
#   'compare',
#   'cheap',
#   'hotel',
#   'previously',
#   'stay',
#   'arrive',
#   'ask',
#   'sheet',
#   'change',
#   'due',
#   'dirty',
#   'stay',
#   'also',
#   'notice',
#   'mug',
#   'old',
#   'lipstick',
#   'towel',
#   'dirty',
#   'pillowcase',
#   'first',
#   'time',
#   'consider',
#   'use',
#   'sleep',
#   'bag',
#   'inner',
#   'sleep',
#   'bed',
#   'staff',
#   'offer',
#   'solution',
#   'problem',
#   'walkable',
#   'location',
#   'relevant',
#   'definitely',
#   'much_better',
#   'stay',
#   'clean'],
#  ['night',
#   'previous',
#   'visit',
#   'stay',
#   'hotel',
#   'time',
#   'try',
#   'book',
#   'single',
#   'room',
#   'online',
#   'discount',
#   'bring',
#   'price',
#   'night',
#   'gtq',
#   'include',
#   'additional',
#   'taxis',
#   'come',
#   'room',
#   'small',
#   'come',
#   'ensuite',
#   'daily',
#   'housekeeping',
#   'hot_shower',
#   'cable',
#   'tv',
#   'breakfast',
#   'room',
#   'excellent',
#   'value',
#   'gtq',
#   'worth',
#   'rack',
#   'rate',
#   'night',
#   'list',
#   'worth',
#   'night',
#   'include',
#   'breakfast',
#   'host',
#   'nice',
#   'people',
#   'comfy',
#   'probably',
#   'little',
#   'much',
#   'edge',
#   'town',
#   'centre',
#   'people',
#   'decent'],
#  ['book',
#   'young',
#   'male',
#   'attempt',
#   'charge',
#   'tell',
#   'breakfast',
#   'include',
#   'other',
#   'egg',
#   'include',
#   'non',
#   'included_breakfast',
#   'want',
#   'egg',
#   'check',
#   'tell',
#   'woman',
#   'nee',
#   'pay',
#   'breakfast',
#   'correct',
#   'say',
#   'breakfast_include',
#   'catch',
#   'previous',
#   'man',
#   'lie',
#   'otherwise',
#   'like',
#   'pay',
#   'top',
#   'dollar',
#   'peak',
#   'time',
#   'accept',
#   'visa',
#   'cash',
#   'believe',
#   'man',
#   'lie',
#   'breakfast'],
#  ['basic',
#   'hotel',
#   'staff',
#   'nice',
#   'friendly',
#   'location',
#   'slightly',
#   'fringe',
#   'street',
#   'light',
#   'bright',
#   'area',
#   'happen',
#   'bedroom',
#   'back',
#   'hotel',
#   'open_air',
#   'market',
#   'start',
#   'really',
#   'early',
#   'noisy',
#   'light',
#   'sleeper',
#   'otherwise',
#   'ok',
#   'look',
#   'cheap',
#   'clean',
#   'place',
#   'stay'],
#  ['make',
#   'reservation',
#   'ask',
#   'pay',
#   'hotel',
#   'night',
#   'charge',
#   'night',
#   'credit_card',
#   'week',
#   'week',
#   'ask',
#   'refund',
#   'waste',
#   'time',
#   'polite',
#   'whatsapp',
#   'end',
#   'take',
#   'money',
#   'twice',
#   'never',
#   'get',
#   'refund',
#   'thief',
#   'avoid',
#   'cost',
#   'bad',
#   'experience',
#   'ever'],
#  ['room',
#   'majority',
#   'share',
#   'many',
#   'super',
#   'small',
#   'toilet',
#   'careful',
#   'price',
#   'quote',
#   'online',
#   'add',
#   'tourist',
#   'tax',
#   'represent',
#   'budget',
#   'hotel',
#   'experience',
#   'quality',
#   'definitely',
#   'high',
#   'hostel'],
#  ['hotel',
#   'bad',
#   'cute',
#   'style',
#   'room',
#   'decent',
#   'clean',
#   'linen',
#   'towel',
#   'wifi',
#   'water',
#   'lukewarm',
#   'gorgeous',
#   'location',
#   'pretty',
#   'good',
#   'quiet',
#   'place',
#   'stay',
#   'big',
#   'issue',
#   'put',
#   'room',
#   'night',
#   'room',
#   'occupy',
#   'need',
#   'move',
#   'next',
#   'night',
#   'room',
#   'able',
#   'fit',
#   'bed',
#   'large',
#   'group',
#   'huge',
#   'inconvenience',
#   'plan',
#   'well',
#   'could',
#   'avoid',
#   'otherwise',
#   'pretty',
#   'cute',
#   'place'],
#  ['first',
#   'good',
#   'common',
#   'space',
#   'nice',
#   'enough',
#   'staff_friendly',
#   'bed',
#   'ok',
#   'great',
#   'noise',
#   'shower',
#   'cleanliness',
#   'could',
#   'spend',
#   'little',
#   'add',
#   'fresh',
#   'paint',
#   'curtain',
#   'need',
#   'clean',
#   'place',
#   'old',
#   'run'],
#  ['room',
#   'invite',
#   'relax',
#   'want',
#   'room',
#   'sleep',
#   'fine',
#   'share',
#   'space',
#   'nice',
#   'balcony',
#   'watch',
#   'firework',
#   'amazing',
#   'kind',
#   'although',
#   'mix',
#   'online',
#   'payment',
#   'result',
#   'take',
#   'quetzale',
#   'later',
#   'need',
#   'room',
#   'push',
#   'wall',
#   'quite',
#   'cramped',
#   'even',
#   'couple',
#   'window',
#   'appear',
#   'storage',
#   'area',
#   'cleaning',
#   'supply',
#   'mean',
#   'get',
#   'hear',
#   'lot',
#   'morning',
#   'conversation',
#   'housekeeping',
#   'staff',
#   'hallway',
#   'pretty',
#   'loud',
#   'seem',
#   'room',
#   'exterior',
#   'window',
#   'glad'],
#  ['advertise',
#   'hotel',
#   'euro_maya',
#   'suite',
#   'real',
#   'name',
#   'hotel',
#   'select',
#   'hotel',
#   'due',
#   'nice',
#   'review',
#   'read',
#   'question',
#   'review',
#   'real',
#   'people',
#   'opinion',
#   'service',
#   'kind',
#   'crazy',
#   'standard',
#   'high',
#   'hotel',
#   'website',
#   'picture',
#   'well',
#   'do',
#   'real',
#   'hotel',
#   'totally',
#   'different',
#   'form',
#   'reality',
#   'pay',
#   'dollar',
#   'night',
#   'quetzal',
#   'breakfast_include',
#   'room',
#   'terrible',
#   'poor',
#   'clean',
#   'nasty',
#   'towel',
#   'really',
#   'old',
#   'almost',
#   'useless',
#   'location',
#   'far',
#   'central_square',
#   'convenience',
#   'location',
#   'review',
#   'say',
#   'love',
#   'cultural',
#   'site',
#   'many',
#   'thing',
#   'learn',
#   'colonial',
#   'time'],
#  ['euro_maya',
#   'nice',
#   'small',
#   'hotel',
#   'staff_friendly',
#   'helpful',
#   'room',
#   'clean',
#   'breakfast',
#   'thing',
#   'go',
#   'roof_top',
#   'terrace',
#   'great',
#   'spot',
#   'breakfast',
#   'enjoy',
#   'volcano',
#   'view',
#   'block',
#   'central_park',
#   'look',
#   'posh',
#   'place',
#   'top',
#   'line',
#   'sheet',
#   'towel',
#   'service',
#   'look',
#   'clean',
#   'friendly',
#   'affordable',
#   'place',
#   'lie',
#   'head',
#   'fit',
#   'bill'],
#  ['book',
#   'return',
#   'mainly',
#   'mistakenly',
#   'list',
#   'book',
#   'hotel',
#   'fact',
#   'hotel',
#   'travel_agency',
#   'happen',
#   'rent',
#   'room',
#   'could',
#   'tell',
#   'property',
#   'sign',
#   'location',
#   'superb',
#   'problem',
#   'disgraceful',
#   'service',
#   'begin',
#   'even',
#   'step',
#   'foot',
#   'hotel',
#   'charge',
#   'issue',
#   'get',
#   'lousy',
#   'ask',
#   'arrive',
#   'suppose',
#   'check',
#   'time',
#   'complain',
#   'talk',
#   'policy',
#   'mention',
#   'employee',
#   'suppose',
#   'probably',
#   'could',
#   'hardly',
#   'speak'],
#  ['birthday',
#   'celebration',
#   'book',
#   'hotel',
#   'think',
#   'centrally_locate',
#   'price',
#   'ok',
#   'hotel',
#   'locate',
#   'town',
#   'central',
#   'accessible',
#   'offer',
#   'parking',
#   'blocks_away',
#   'bad',
#   'thing',
#   'hotel',
#   'locate',
#   'next',
#   'alliance',
#   'weekend',
#   'stay',
#   'concert',
#   'bad',
#   'concert',
#   'last',
#   'ask',
#   'watchman',
#   'call',
#   'police',
#   'aware',
#   'pm',
#   'manager',
#   'leave',
#   'close',
#   'door',
#   'assist',
#   'also',
#   'establishment',
#   'sure',
#   'bar',
#   'restaurant',
#   'hotel',
#   'group',
#   'noisy',
#   'people',
#   'come',
#   'go',
#   'night',
#   'long',
#   'sleep',
#   'horrible'],
#  ['stay',
#   'first',
#   'hotel',
#   'full',
#   'last_night',
#   'stay',
#   'place',
#   'sorry',
#   'state',
#   'disrepair',
#   'look',
#   'unloved',
#   'room',
#   'general',
#   'appearance',
#   'bite',
#   'shabby',
#   'one',
#   'hotel',
#   'entire',
#   'town',
#   'full',
#   'big',
#   'event',
#   'service',
#   'obvious',
#   'place',
#   'seem',
#   'spooky',
#   'luckily',
#   'good',
#   'conscience',
#   'can',
#   'recommend'],
#  ['hotel',
#   'room',
#   'nice',
#   'wife',
#   'get',
#   'room',
#   'thing',
#   'bathroom',
#   'really',
#   'small',
#   'flush',
#   'toilet',
#   'water_pressure',
#   'super',
#   'super',
#   'slow',
#   'bathroom',
#   'toilet',
#   'really',
#   'small',
#   'nee',
#   'leave',
#   'use',
#   'really',
#   'important',
#   'party',
#   'super',
#   'cool',
#   'door',
#   'lot',
#   'people',
#   'visit',
#   'socialize',
#   'sleep',
#   'early',
#   'energize',
#   'tour',
#   'good',
#   'place',
#   'stay',
#   'noise',
#   'end',
#   'costumer',
#   'service',
#   'really',
#   'amazing',
#   'really',
#   'enjoy',
#   'service'],
#  ['stayed_night',
#   'hotel',
#   'could',
#   'sleep',
#   'staff_friendly',
#   'unfortunately',
#   'complain',
#   'noise',
#   'clock',
#   'evening',
#   'noise',
#   'movement',
#   'room',
#   'also',
#   'unlucky',
#   'client',
#   'hotel',
#   'care',
#   'client',
#   'want',
#   'sleep',
#   'recommend',
#   'hotel',
#   'want',
#   'peace',
#   'quiet'],
#  ['first',
#   'positive',
#   'hotel',
#   'look',
#   'great',
#   'ground',
#   'credit',
#   'team',
#   'responsible',
#   'location',
#   'restaurant',
#   'overlook',
#   'active',
#   'volcano',
#   'spectacular',
#   'imagine',
#   'dinner',
#   'backdrop',
#   'lava',
#   'spout',
#   'volcano',
#   'probably',
#   'daily',
#   'event',
#   'lucky',
#   'hotel',
#   'however',
#   'well',
#   'let',
#   'room',
#   'clean',
#   'lack_air',
#   'would',
#   'therefore',
#   'expect',
#   'able',
#   'ventilate',
#   'open',
#   'window',
#   'insect',
#   'screen',
#   'sensible',
#   'result',
#   'stuffy',
#   'room',
#   'room',
#   'also',
#   'room',
#   'safe',
#   'guest',
#   'place',
#   'valuable',
#   'security',
#   'box',
#   'reception',
#   'traveller',
#   'carry',
#   'tablet',
#   'laptop',
#   'camera',
#   'phone',
#   'suitable',
#   'practical',
#   'really',
#   'good',
#   'enough'],
#  ['lovely',
#   'position',
#   'nice',
#   'room',
#   'glad',
#   'courtyard',
#   'people',
#   'breakfast',
#   'right_outside',
#   'bedroom',
#   'window',
#   'sad',
#   'poor',
#   'attitude',
#   'staff',
#   'water',
#   'ration',
#   'attempt',
#   'offer',
#   'filtered_water',
#   'tea',
#   'service',
#   'room',
#   'morning',
#   'tea',
#   'fine',
#   'undrinkable',
#   'manager',
#   'provide',
#   'maybe',
#   'lack',
#   'also',
#   'good',
#   'enough',
#   'way',
#   'charge',
#   'effort',
#   'make',
#   'resolve',
#   'problem',
#   'plastic',
#   'flower',
#   'petal',
#   'towel',
#   'really',
#   'bother',
#   'turn',
#   'service',
#   'dirty',
#   'towel',
#   'cup',
#   'leave',
#   'night',
#   'would',
#   'call',
#   'average',
#   'hotel',
#   'label'],
#  ['stay',
#   'book',
#   'pay',
#   'cash',
#   'check',
#   'month',
#   'later',
#   'notice',
#   'charge',
#   'visa',
#   'card',
#   'well',
#   'refuse',
#   'refund',
#   'many',
#   'better_option',
#   'well',
#   'price',
#   'steer',
#   'clear'],
#  ['provide',
#   'bed',
#   'average',
#   'price',
#   'location',
#   'rather',
#   'decent',
#   'want',
#   'rather',
#   'problem',
#   'cold',
#   'night',
#   'quite',
#   'strong',
#   'smell',
#   'disinfectant',
#   'time',
#   'least',
#   'tell',
#   'cleaning',
#   'occur',
#   'little',
#   'way',
#   'social',
#   'atmosphere',
#   'certainly',
#   'lack',
#   'kind',
#   'usefulness',
#   'warmth',
#   'staff',
#   'friendly',
#   'knowledgeable',
#   'town',
#   'transport',
#   'importantly',
#   'stay',
#   'begin',
#   'suffer',
#   'virus',
#   'hostel',
#   'fault',
#   'concern',
#   'bed',
#   'several',
#   'day',
#   'moan',
#   'look',
#   'dreadful',
#   'staff',
#   'walk',
#   'past',
#   'unconcerned',
#   'would',
#   'value',
#   'social',
#   'responsibility'],
#  ['arrive',
#   'reserve',
#   'advance',
#   'room',
#   'show',
#   'picture',
#   'even',
#   'window',
#   'place',
#   'dirty',
#   'smell',
#   'damp',
#   'staff',
#   'insist',
#   'pay',
#   'full',
#   'amount',
#   'offer',
#   'use',
#   'try',
#   'resolve',
#   'problem',
#   'terrible',
#   'room',
#   'terrible',
#   'customer_service'],
#  ['stay',
#   'three_night',
#   'unfortunately',
#   'room',
#   'small',
#   'appear',
#   'picture',
#   'stuffy',
#   'air',
#   'keep',
#   'staircase',
#   'staff_friendly',
#   'enough',
#   'seem',
#   'bit',
#   'work',
#   'often',
#   'let',
#   'night',
#   'ring',
#   'clean',
#   'enough',
#   'decent',
#   'location',
#   'decent',
#   'shower',
#   'pretty',
#   'nice',
#   'upstairs',
#   'courtyard',
#   'place',
#   'offer',
#   'well',
#   'value_money',
#   'elsewhere'],
#  ['receptionist',
#   'provide',
#   'little',
#   'information',
#   'detail',
#   'hotel',
#   'prompt',
#   'room',
#   'clean',
#   'hear',
#   'may',
#   'make',
#   'noise',
#   'fan',
#   'hot',
#   'hot',
#   'breakfast_include',
#   'rate',
#   'say',
#   'hotel',
#   'confirmation',
#   'ask',
#   'staff',
#   'really',
#   'problem',
#   'meh',
#   'would',
#   'probably',
#   'next',
#   'time',
#   'deserve',
#   'well',
#   'experience'],
#  ['room',
#   'small',
#   'box',
#   'ventilation',
#   'even',
#   'fan',
#   'get',
#   'tiny',
#   'courtyard',
#   'view',
#   'shower',
#   'get',
#   'turn',
#   'water',
#   'periodically',
#   'night',
#   'say',
#   'staff',
#   'generally',
#   'nice',
#   'good',
#   'make',
#   'stay',
#   'pleasant',
#   'evening',
#   'flight',
#   'staff',
#   'keep',
#   'bag',
#   'hotel',
#   'checkout',
#   'luxury',
#   'place',
#   'decent',
#   'location',
#   'need',
#   'place',
#   'crash',
#   'may',
#   'ok',
#   'visit',
#   'thankfully',
#   'cold',
#   'night',
#   'imagine',
#   'would',
#   'impossible_sleep',
#   'temperature',
#   'hotter'],
#  ['people',
#   'nice',
#   'desk',
#   'get',
#   'fool',
#   'picture',
#   'window',
#   'window',
#   'give',
#   'hallway',
#   'noisy',
#   'lack',
#   'lousy',
#   'internet',
#   'bad',
#   'location',
#   'good',
#   'repeat'],
#  ['price',
#   'decent',
#   'value',
#   'screen',
#   'mosquiro',
#   'wake',
#   'night',
#   'onsite',
#   'bar',
#   'room',
#   'noisy',
#   'fan',
#   'room',
#   'turn',
#   'drip',
#   'night',
#   'stay',
#   'never'],
#  ['nice',
#   'decoration',
#   'terrace',
#   'overcharge',
#   'convert',
#   'price',
#   'currency',
#   'push',
#   'consume',
#   'difference',
#   'hotel',
#   'service',
#   'poor',
#   'price',
#   'pay',
#   'give_us',
#   'towel',
#   'clean',
#   'table',
#   'breakfast',
#   'also',
#   'book',
#   'morning',
#   'really',
#   'unfriendly',
#   'make',
#   'feel',
#   'unwelcome',
#   'would',
#   'never',
#   'come_back',
#   'place',
#   'money',
#   'pay',
#   'good',
#   'hostel',
#   'sure',
#   'attend',
#   'well'],
#  ['locate',
#   'site',
#   'middle',
#   'restaurant',
#   'shop',
#   'bar',
#   'view',
#   'balcony',
#   'breathtake',
#   'complaint',
#   'breakfast',
#   'fry',
#   'egg',
#   'toast',
#   'bean',
#   'think',
#   'well',
#   'even',
#   'guest',
#   'pay'],
#  ['nice',
#   'decor',
#   'breakfast_include',
#   'courtyard',
#   'sit',
#   'blanket',
#   'ask',
#   'little',
#   'wifi',
#   'drop',
#   'stay',
#   'room',
#   'reception',
#   'busy',
#   'road',
#   'bus',
#   'lorry',
#   'wake'],
#  ['room',
#   'small',
#   'clean',
#   'dusty',
#   'bed',
#   'uncomfortable',
#   'hardly',
#   'shower'],
#  ['pretty',
#   'really',
#   'cute',
#   'spacious',
#   'room',
#   'staff',
#   'nice',
#   'hotel',
#   'safe',
#   'quiet',
#   'downside',
#   'central',
#   'area',
#   'day',
#   'recommend',
#   'walk',
#   'night',
#   'plan',
#   'late',
#   'evening',
#   'recommend_staye',
#   'little',
#   'close',
#   'central',
#   'area',
#   'close',
#   'really',
#   'loud',
#   'even'],
#  ['book',
#   'afterwards',
#   'find',
#   'hotel',
#   'much',
#   'low',
#   'rate',
#   'expedia',
#   'would',
#   'cancel',
#   'first',
#   'hotel',
#   'room',
#   'show',
#   'extraordinary',
#   'usd_p',
#   'day',
#   'dark',
#   'dingy',
#   'bath',
#   'view',
#   'express',
#   'dismay',
#   'price',
#   'offer',
#   'move',
#   'upstairs',
#   'nice',
#   'room',
#   'breakfast',
#   'consist',
#   'coffee',
#   'toast',
#   'egg',
#   'refrie',
#   'bean',
#   'little_bit',
#   'cheese',
#   'complain',
#   'lack',
#   'fruit',
#   'monotony',
#   'menu',
#   'daily',
#   'arrive',
#   'take'],
#  ['say',
#   'hotel',
#   'nice',
#   'breakfast',
#   'splendid',
#   'view',
#   'terrace',
#   'unfortunately',
#   'room',
#   'one',
#   'wait',
#   'standard',
#   'room',
#   'book',
#   'tiny',
#   'sqm',
#   'advertise',
#   'sqm',
#   'suite',
#   'book',
#   'double',
#   'price',
#   'normal',
#   'room',
#   'sure',
#   'separate',
#   'bed',
#   'advertise',
#   'booking',
#   'site',
#   'separate',
#   'bed',
#   'suite',
#   'consider',
#   'public',
#   'seating',
#   'place',
#   'part',
#   'room',
#   'indeed',
#   'arriving_late',
#   'hotel',
#   'reason',
#   'give_us',
#   'leftover',
#   'book',
#   'month',
#   'advance'],
#  ['pro',
#   'friendly',
#   'staff',
#   'good',
#   'price',
#   'con',
#   'room',
#   'street',
#   'noisy',
#   'bring',
#   'sleep',
#   'medication',
#   'noise',
#   'continue',
#   'midnight',
#   'start',
#   'also',
#   'able',
#   'hear_people',
#   'room',
#   'breakfast',
#   'morning',
#   'toast',
#   'jam',
#   'fruit',
#   'next_morning',
#   'egg',
#   'fruit',
#   'third',
#   'morning',
#   'decide',
#   'go',
#   'restaurant',
#   'substantial',
#   'breakfast',
#   'give',
#   'coffee',
#   'produce',
#   'country',
#   'expect',
#   'good',
#   'coffee',
#   'morning',
#   'bad',
#   'coffee',
#   'ever',
#   'watery',
#   'weak'],
#  ['location',
#   'hotel',
#   'staff',
#   'make',
#   'feel',
#   'welcome',
#   'breakfast',
#   'nice',
#   'breakfast',
#   'fresh',
#   'fruit',
#   'room',
#   'spacious',
#   'dislike',
#   'super',
#   'thin_wall',
#   'hear',
#   'everything_goe',
#   'include',
#   'extracurricular',
#   'activity',
#   'include',
#   'music',
#   'could',
#   'provide',
#   'face',
#   'towel',
#   'verdict',
#   'hotel',
#   'get',
#   'endorsement',
#   'location',
#   'price',
#   'however',
#   'mindful',
#   'super',
#   'thin',
#   'paper',
#   'wall',
#   'hear',
#   'thing',
#   'want',
#   'hear'],
#  ['good',
#   'pool',
#   'nice',
#   'room',
#   'mattress',
#   'room',
#   'terrible',
#   'room',
#   'number',
#   'wor',
#   'thing',
#   'small',
#   'hotel',
#   'service',
#   'people',
#   'rude',
#   'even',
#   'look',
#   'face',
#   'never',
#   'ever',
#   'say',
#   'good',
#   'morning',
#   'incredible',
#   'small',
#   'hotel',
#   'can',
#   'train',
#   'employee',
#   'properly',
#   'hard',
#   'say',
#   'good',
#   'morning',
#   'never',
#   'back'],
#  ['somewhere',
#   'online',
#   'first',
#   'sure',
#   'last',
#   'time',
#   'check',
#   'write',
#   'already',
#   'hotel',
#   'massively',
#   'loud',
#   'fairness',
#   'ridiculous',
#   'loud',
#   'apart',
#   'standard',
#   'room',
#   'tiny',
#   'wardrobe',
#   'replace',
#   'toilet',
#   'shower',
#   'aware'],
#  ['staff',
#   'wonderful',
#   'girl',
#   'desk',
#   'could',
#   'helpful',
#   'horribly',
#   'noisy',
#   'place',
#   'stay',
#   'intermittent',
#   'machinery',
#   'noise',
#   'night',
#   'due',
#   'courtyard',
#   'also',
#   'room',
#   'courtyard_garden',
#   'people',
#   'sit',
#   'talk',
#   'noisy',
#   'night',
#   'room',
#   'nice',
#   'seem',
#   'better_place',
#   'stay'],
#  ['plus_side',
#   'hotel',
#   'conveniently_locate',
#   'many',
#   'business',
#   'around',
#   'keep',
#   'clean',
#   'employee',
#   'try',
#   'make',
#   'feel',
#   'good',
#   'negative',
#   'side',
#   'room',
#   'pack',
#   'small',
#   'location',
#   'easily',
#   'hear',
#   'outside',
#   'noise',
#   'night',
#   'get',
#   'late',
#   'listen',
#   'say',
#   'coffee',
#   'maker',
#   'room',
#   'keep',
#   'make',
#   'noise',
#   'night',
#   'recommend',
#   'place'],
#  ['room',
#   'really',
#   'small',
#   'lady',
#   'really',
#   'rude',
#   'family',
#   'good',
#   'think',
#   'boy',
#   'stay',
#   'night',
#   'rest',
#   'enjoy',
#   'time'],
#  ['always',
#   'come',
#   'hotel',
#   'day',
#   'service',
#   'change',
#   'alot',
#   'feel',
#   'welcome',
#   'price',
#   'change',
#   'well',
#   'month',
#   'thing',
#   'make',
#   'sence',
#   'room',
#   'people',
#   'room',
#   'people',
#   'choice'],
#  ['bad',
#   'definitely',
#   'top',
#   'notch',
#   'entire',
#   'week',
#   'free_wifi',
#   'terrible',
#   'often',
#   'cut',
#   'weak',
#   'signal',
#   'bed',
#   'ask',
#   'extra',
#   'pillow',
#   'say',
#   'thin_hear',
#   'neighbor',
#   'talk',
#   'sneeze',
#   'use',
#   'restroom',
#   'place',
#   'price',
#   'high',
#   'quality',
#   'staff',
#   'always',
#   'friendly',
#   'stay'],
#  ['room',
#   'room',
#   'large',
#   'bathroom',
#   'bed',
#   'firm',
#   'room',
#   'dark',
#   'comfortable',
#   'fridge',
#   'mini',
#   'bar',
#   'kettle',
#   'make',
#   'staff_friendly',
#   'helpful',
#   'especially',
#   'work',
#   'restaurant',
#   'give',
#   'exceptional',
#   'service',
#   'breakfast_include',
#   'stay',
#   'standard',
#   'victor',
#   'really',
#   'great',
#   'try',
#   'restaurant',
#   'food',
#   'average',
#   'room',
#   'overlook',
#   'beautiful',
#   'garden',
#   'ground',
#   'room',
#   'clean',
#   'room',
#   'story',
#   'walk',
#   'early_morne'],
#  ['cute',
#   'charming',
#   'staff',
#   'kind',
#   'professional',
#   'helpful',
#   'perk',
#   'hotel',
#   'breakfast_include',
#   'use',
#   'amenity',
#   'hotel',
#   'stay',
#   'daughter',
#   'upper',
#   'terrace',
#   'room',
#   'sadly',
#   'rough',
#   'night',
#   'sleep',
#   'noise',
#   'street',
#   'notify',
#   'beforehand',
#   'receptionist',
#   'agree',
#   'noisy',
#   'room',
#   'complaint',
#   'common',
#   'disappointed',
#   'value',
#   'room',
#   'lack',
#   'rest',
#   'perhaps',
#   'stay',
#   'room',
#   'bottom',
#   'floor',
#   'back',
#   'would',
#   'pleasant',
#   'experience'],
#  ['last_night',
#   'try',
#   'come',
#   'assume',
#   'drunk',
#   'get',
#   'room',
#   'girl',
#   'touch',
#   'inappropriately',
#   'ask',
#   'leave',
#   'minute',
#   'try',
#   'come',
#   'back',
#   'additional',
#   'guy',
#   'get',
#   'room',
#   'eventually',
#   'give',
#   'horrible',
#   'experience',
#   'specially',
#   'overnight',
#   'guard'],
#  ['arrive',
#   'hotel',
#   'early',
#   'start',
#   'long',
#   'travel',
#   'tell',
#   'immediately',
#   'room',
#   'due',
#   'overbooking',
#   'room',
#   'reserve',
#   'pay',
#   'full',
#   'least',
#   'month',
#   'previous',
#   'tell',
#   'upgrade',
#   'property',
#   'euro_maya',
#   'suite',
#   'room',
#   'nicer',
#   'apparently',
#   'quick',
#   'check',
#   'online',
#   'find',
#   'stay',
#   'euro_maya',
#   'suite',
#   'indeed',
#   'little_bit',
#   'expensive',
#   'reason',
#   'book',
#   'euro_maya',
#   'location',
#   'rooftop_terrace',
#   'girl_reception',
#   'nice',
#   'small',
#   'discount',
#   'excursion',
#   'room',
#   'suite',
#   'lovely',
#   'room',
#   'great',
#   'time'],
#  ['stayed_night',
#   'change',
#   'book',
#   'apparently',
#   'issue',
#   'room',
#   'other',
#   'available',
#   'move',
#   'nice',
#   'spacious',
#   'triple',
#   'room',
#   'double',
#   'single',
#   'fan',
#   'evening',
#   'fan',
#   'adequate',
#   'room',
#   'get',
#   'quite',
#   'stuffy',
#   'open',
#   'window',
#   'whenever',
#   'room',
#   'air',
#   'shower',
#   'would',
#   'quickly',
#   'lose',
#   'still',
#   'good',
#   'pressure',
#   'various',
#   'receptionist',
#   'see',
#   'night',
#   'speak',
#   'little',
#   'luckily',
#   'really',
#   'nee',
#   'speak',
#   'much',
#   'breakfast_include',
#   'head',
#   'food',
#   'slow',
#   'occasionally'],
#  ['pro',
#   'fantastic',
#   'location',
#   'nice',
#   'courtyard',
#   'kitchen',
#   'great',
#   'could',
#   'make',
#   'breakfast',
#   'con',
#   'unfortunately',
#   'none',
#   'really',
#   'matter',
#   'wall',
#   'hotel',
#   'room',
#   'thin',
#   'barely',
#   'sleep',
#   'guest',
#   'hotel',
#   'night',
#   'clearly',
#   'impossible',
#   'awoken',
#   'finally_got',
#   'quiet',
#   'noise',
#   'start',
#   'guest',
#   'wake',
#   'presumably',
#   'early_morne',
#   'pick',
#   'up',
#   'hike',
#   'expensive',
#   'fail',
#   'provide',
#   'decent',
#   'sleep',
#   'addition',
#   'wifi',
#   'really',
#   'poor',
#   'time',
#   'finally',
#   'provide',
#   'free_coffee',
#   'coffee',
#   'rubbish',
#   'cup',
#   'taste',
#   'chlorine',
#   'small',
#   'thing',
#   'generally',
#   'really',
#   'disappointing'],
#  ['stay',
#   'week',
#   'solo',
#   'female',
#   'traveler',
#   'positive',
#   'hotel',
#   'apartment',
#   'photo',
#   'nice',
#   'look',
#   'cozy',
#   'housekeeping',
#   'good',
#   'never',
#   'come',
#   'say',
#   'come',
#   'security',
#   'beds_comfortable',
#   'good',
#   'safe',
#   'room',
#   'great',
#   'sure',
#   'could',
#   'fit',
#   'full',
#   'sized',
#   'lap',
#   'top',
#   'pad',
#   'perfect',
#   'wireless',
#   'access',
#   'pretty',
#   'reliable',
#   'even',
#   'lose',
#   'access',
#   'quickly',
#   'negative',
#   'noisy',
#   'side',
#   'okay',
#   'otherwise',
#   'hear_everythe',
#   'several_time',
#   'people',
#   'party',
#   'quite',
#   'loudly',
#   'go',
#   'speak',
#   'speak',
#   'tenant',
#   'change'],
#  ['second',
#   'time',
#   'come',
#   'back',
#   'recent',
#   'experience',
#   'hotel',
#   'barely',
#   'space',
#   'bag',
#   'book',
#   'triple',
#   'room',
#   'book',
#   'room',
#   'price',
#   'dollar',
#   'night',
#   'eve',
#   'good_location',
#   'many_restaurant',
#   'friendly',
#   'staff',
#   'however',
#   'try',
#   'good',
#   'understand',
#   'room',
#   'upper',
#   'floor',
#   'housekeeping',
#   'room',
#   'night',
#   'hear',
#   'laundry',
#   'machine',
#   'turn',
#   'bother',
#   'good',
#   'sleeper',
#   'room',
#   'mold',
#   'ceile',
#   'good',
#   'free_wifi',
#   'bathroom',
#   'small',
#   'clean',
#   'difficult',
#   'regulate',
#   'shower',
#   'airport',
#   'pick',
#   'book'],
#  ['secure',
#   'centrally_locate',
#   'beds_comfortable',
#   'cleanliness',
#   'sheet',
#   'questionable',
#   'stain',
#   'hair',
#   'window',
#   'room',
#   'look',
#   'garden',
#   'common',
#   'space',
#   'airflow',
#   'room',
#   'limited',
#   'fan',
#   'provide',
#   'water_pressure',
#   'good',
#   'day',
#   'next_day',
#   'run',
#   'water',
#   'sure',
#   'freak',
#   'accident',
#   'common',
#   'occurrence',
#   'hour',
#   'job',
#   'memorable'],
#  ['share',
#   'room',
#   'bed',
#   'clean',
#   'basic',
#   'bathroom',
#   'tight',
#   'fit',
#   'mirror',
#   'turn',
#   'pressure',
#   'high',
#   'staff',
#   'kind',
#   'accommodate',
#   'ask',
#   'move',
#   'room',
#   'downstairs',
#   'carry',
#   'luggage',
#   'narrow',
#   'stair',
#   'enough',
#   'place',
#   'eat',
#   'shop',
#   'great',
#   'walking',
#   'everywhere'],
#  ['bad',
#   'allow',
#   'audio',
#   'upload',
#   'review',
#   'owner',
#   'place',
#   'make',
#   'much',
#   'noise',
#   'night',
#   'talk',
#   'loud',
#   'courtyard',
#   'listen',
#   'want',
#   'good',
#   'night',
#   'rest',
#   'look'],
#  ['big',
#   'disappointment',
#   'see',
#   'room',
#   'think',
#   'nice',
#   'close',
#   'inspection',
#   'soon',
#   'realise',
#   'place',
#   'dirty',
#   'hotel',
#   'make',
#   'look',
#   'nice',
#   'painting',
#   'wall',
#   'add',
#   'mood',
#   'light',
#   'nice',
#   'design',
#   'bed',
#   'sheet',
#   'take',
#   'nice',
#   'photo',
#   'see',
#   'fb',
#   'page',
#   'reality',
#   'room',
#   'dirty',
#   'looked_like',
#   'floor',
#   'clean',
#   'long_time',
#   'bathroom',
#   'also',
#   'bad',
#   'eventually',
#   'bite',
#   'warm',
#   'still',
#   'freeze',
#   'shower',
#   'also',
#   'noisy',
#   'main',
#   'street',
#   'room',
#   'furthest',
#   'away',
#   'talk',
#   'reception',
#   'noise',
#   'amplify',
#   'design',
#   'hotel',
#   'door',
#   'come',
#   'back',
#   'late',
#   'hear',
#   'loudly',
#   'corner'],
#  ['pro',
#   'beautiful',
#   'hotel',
#   'contra',
#   'horrible',
#   'check',
#   'experience',
#   'inflexible',
#   'policy',
#   'inform',
#   'arrival',
#   'solve',
#   'problem',
#   'hotel',
#   'beautiful',
#   'keep',
#   'mind',
#   'problem',
#   'nightmare',
#   'try',
#   'solve'],
#  ['large',
#   'clean',
#   'room',
#   'room',
#   'side',
#   'colorful',
#   'courtyard',
#   'lobby',
#   'staff',
#   'carry',
#   'luggage',
#   'hotel',
#   'garden',
#   'full',
#   'plant',
#   'flower',
#   'well',
#   'arrange',
#   'regular',
#   'breakfast',
#   'waiter',
#   'service',
#   'need',
#   'improvement'],
#  ['hard',
#   'wife',
#   'take',
#   'could',
#   'sleep',
#   'hard',
#   'double',
#   'lucky',
#   'endure',
#   'multiple',
#   'bed',
#   'bug',
#   'bite',
#   'get',
#   'away',
#   'still',
#   'itch',
#   'write',
#   'promise',
#   'room',
#   'size',
#   'thimble',
#   'great',
#   'staff',
#   'sort',
#   'next_day',
#   'thank',
#   'roof_top',
#   'great',
#   'breakfast',
#   'kitchen',
#   'good',
#   'basic',
#   'meal',
#   'good',
#   'price'],
#  ['overall',
#   'hotel',
#   'nice',
#   'service',
#   'great',
#   'however',
#   'want',
#   'iin',
#   'room',
#   'right',
#   'courtyard',
#   'use',
#   'breakfast',
#   'set',
#   'start',
#   'also',
#   'visitor',
#   'arrive',
#   'leave',
#   'night',
#   'wake',
#   'also',
#   'room',
#   'window',
#   'hotel',
#   'toilet',
#   'open',
#   'bathroom',
#   'noise',
#   'use',
#   'overnight',
#   'finally',
#   'live',
#   'rock',
#   'band',
#   'play',
#   'pub',
#   'effectively',
#   'side',
#   'wall',
#   'room',
#   'ask',
#   'move',
#   'tell',
#   'suitable',
#   'room',
#   'available',
#   'clearly',
#   'untrue',
#   'saw',
#   'room',
#   'come',
#   'go',
#   'suitable',
#   'quite',
#   'location',
#   'hotel',
#   'say',
#   'room'],
#  ['made_reservation',
#   'location',
#   'list',
#   'locate',
#   'arrive',
#   'gentleman',
#   'tell',
#   'driver',
#   'take',
#   'location',
#   'decent',
#   'location',
#   'bathroom',
#   'nice',
#   'breakfast',
#   'good',
#   'well',
#   'comfortable',
#   'frustration',
#   'location',
#   'want',
#   'center',
#   'charming'],
#  ['confusion',
#   'get',
#   'think',
#   'book',
#   'euro_maya',
#   'suite',
#   'end',
#   'location',
#   'call',
#   'confirm',
#   'fine',
#   'room',
#   'pretty',
#   'cramped',
#   'big',
#   'issue',
#   'ac',
#   'also',
#   'overhead',
#   'fan',
#   'hotel',
#   'fan',
#   'bring',
#   'stuff',
#   'even',
#   'leave',
#   'breeze',
#   'really',
#   'stuffy',
#   'nice',
#   'breakfast',
#   'roof',
#   'breakfast',
#   'super',
#   'plentiful',
#   'serve',
#   'lovely',
#   'staff',
#   'location',
#   'top'],
#  ['gorgeous',
#   'spacious',
#   'room',
#   'nice',
#   'breakfast_include',
#   'day',
#   'complimentary',
#   'coffee_tea',
#   'purify',
#   'water',
#   'convenient',
#   'centrally_locate',
#   'unfortunately',
#   'shower',
#   'water',
#   'cold',
#   'let',
#   'know',
#   'plan',
#   'return',
#   'late_night',
#   'lock',
#   'use',
#   'door',
#   'call',
#   'exhaust',
#   'find',
#   'alternate',
#   'accommodation',
#   'middle_night',
#   'explain',
#   'staff',
#   'next_morne',
#   'refund',
#   'fee',
#   'night'],
#  ['night',
#   'way',
#   'service',
#   'trip',
#   'location_close',
#   'market',
#   'square',
#   'concrete',
#   'design',
#   'wall',
#   'noise',
#   'would',
#   'travel',
#   'stairwell',
#   'night',
#   'long',
#   'lot',
#   'stay',
#   'seam',
#   'care',
#   'hot',
#   'much',
#   'noise',
#   'make',
#   'night',
#   'long',
#   'room',
#   'sparsely',
#   'decorate',
#   'could',
#   'use',
#   'upgrade',
#   'bed',
#   'bedding',
#   'pillow',
#   'public',
#   'area',
#   'pretty',
#   'wifi',
#   'work',
#   'room',
#   'area',
#   'stay'],
#  ['spend',
#   'would',
#   'return',
#   'downstairs',
#   'room',
#   'subject',
#   'noisy',
#   'chatter',
#   'patron',
#   'night',
#   'long',
#   'even',
#   'early_morne',
#   'charge',
#   'wifi',
#   'water',
#   'positive',
#   'supermarket',
#   'door',
#   'room',
#   'clean',
#   'spend',
#   'double',
#   'room',
#   'need'],
#  ['stay',
#   'property',
#   'night',
#   'big',
#   'mistake',
#   'old',
#   'place',
#   'dump',
#   'waste',
#   'money',
#   'bed',
#   'hard',
#   'nee',
#   'see',
#   'doctor',
#   'back',
#   'pain',
#   'trust',
#   'really',
#   'bad',
#   'old',
#   'towel',
#   'loud',
#   'night',
#   'bar',
#   'noise',
#   'stop',
#   'shower',
#   'old',
#   'sink',
#   'come',
#   'apart',
#   'old',
#   'pillow'],
#  ['month',
#   'work',
#   'leisure',
#   'stay',
#   'several',
#   'always',
#   'pleased',
#   'staff',
#   'service',
#   'accommodation',
#   'area',
#   'hotel',
#   'worst',
#   'stay',
#   'far',
#   'price_range',
#   'receptionist',
#   'accommodate',
#   'slightly',
#   'rude',
#   'definitely',
#   'friendly',
#   'personable',
#   'staff',
#   'act',
#   'know',
#   'time',
#   'stay',
#   'politely',
#   'ask',
#   'possible',
#   'change',
#   'room',
#   'first_night',
#   'room',
#   'locate',
#   'reception',
#   'desk',
#   'noisy',
#   'loud',
#   'people',
#   'check',
#   'day',
#   'night',
#   'could',
#   'sleep',
#   'first',
#   'room',
#   'comfortable'],
#  ['break',
#   'room',
#   'steal',
#   'cash',
#   'expensive',
#   'sunglass',
#   'staff',
#   'want',
#   'help',
#   'reluctant',
#   'inquire',
#   'staff',
#   'customer',
#   'incident',
#   'call',
#   'police',
#   'staff',
#   'actually',
#   'try',
#   'imply',
#   'lose',
#   'item',
#   'lock',
#   'door',
#   'fabricate',
#   'incident',
#   'lack',
#   'assistance',
#   'bad',
#   'invasion',
#   'privacy',
#   'particularly',
#   'young',
#   'solo',
#   'female',
#   'traveller',
#   'hotel',
#   'actually',
#   'large',
#   'house',
#   'room',
#   'rent',
#   'tell',
#   'else',
#   'room',
#   'staff',
#   'later',
#   'admit',
#   'owner',
#   'key',
#   'local',
#   'authority',
#   'tourism',
#   'police',
#   'helpful'],
#  ['room',
#   'clean',
#   'nice',
#   'however',
#   'walk',
#   'kitchen',
#   'get',
#   'shower',
#   'also',
#   'family',
#   'daily',
#   'live',
#   'believe',
#   'always',
#   'kitchen',
#   'also',
#   'reception',
#   'keep',
#   'people',
#   'child',
#   'talking_loudly',
#   'night',
#   'pm',
#   'family',
#   'feel',
#   'hotel',
#   'also',
#   'kitchen',
#   'fridge',
#   'clean',
#   'staff',
#   'owner',
#   'friendly',
#   'also',
#   'advertise',
#   'quite',
#   'distance',
#   'central',
#   'least',
#   'much',
#   'close',
#   'would',
#   'stay'],
#  ['good_location',
#   'check',
#   'clerk',
#   'show',
#   'old',
#   'rip',
#   'hand',
#   'towel',
#   'say',
#   'find',
#   'room',
#   'must',
#   'pay',
#   'rip',
#   'towel',
#   'charge',
#   'anyway',
#   'stay'],
#  ['stay',
#   'night',
#   'hotel',
#   'room',
#   'twin',
#   'bed',
#   'room',
#   'change',
#   'room',
#   'nice',
#   'little_bit',
#   'hard',
#   'regulate',
#   'shower',
#   'first_night',
#   'quiet',
#   'second_night',
#   'big',
#   'group',
#   'volunteer',
#   'stay',
#   'hotel',
#   'make',
#   'early_morne',
#   'location',
#   'hotel',
#   'good',
#   'central_park'],
#  ['really',
#   'clean',
#   'hotel',
#   'smell',
#   'bad',
#   'noisy',
#   'night',
#   'quite',
#   'close',
#   'guardian',
#   'friendly',
#   'price',
#   'possible',
#   'find',
#   'much_better',
#   'address'],
#  ['outside',
#   'town',
#   'mean',
#   'large',
#   'coach',
#   'stop',
#   'group',
#   'night',
#   'whole',
#   'quiet',
#   'sleep',
#   'town',
#   'also',
#   'cater',
#   'function',
#   'evening',
#   'disturbed',
#   'band',
#   'quite',
#   'late_night',
#   'add',
#   'tour',
#   'group',
#   'arrive',
#   'depart',
#   'nighttime',
#   'hour',
#   'voice',
#   'suitcase',
#   'bump',
#   'cobble',
#   'reverberate',
#   'complex',
#   'always',
#   'make',
#   'peaceful',
#   'sleep',
#   'look',
#   'ok',
#   'surface',
#   'tastefully',
#   'do',
#   'old',
#   'colonial',
#   'town',
#   'nice',
#   'area',
#   'lack',
#   'charm',
#   'personality',
#   'staff',
#   'particularly',
#   'friendly',
#   'room',
#   'rather',
#   'date',
#   'certainly',
#   'one',
#   'smell',
#   'damp',
#   'need',
#   'air',
#   'bed'],
#  ['end',
#   'awake',
#   'sound',
#   'room',
#   'alarm',
#   'noisy',
#   'guest',
#   'check',
#   'room',
#   'sound',
#   'control',
#   'poor',
#   'ventilation',
#   'get',
#   'quite',
#   'warm',
#   'vent',
#   'bed',
#   'squeaky',
#   'confortable',
#   'bathroom',
#   'horribly',
#   'decorate',
#   'overall',
#   'price',
#   'usd',
#   'sure',
#   'well',
#   'choice'],
#  ['lovely',
#   'grear',
#   'coffee',
#   'first',
#   'room',
#   'get',
#   'give',
#   'absolutely',
#   'stong',
#   'chemical',
#   'smell',
#   'imagine',
#   'floor',
#   'cleaner',
#   'ask',
#   'move',
#   'minute',
#   'make',
#   'nauseous',
#   'next',
#   'room',
#   'also',
#   'smell',
#   'old',
#   'run',
#   'road',
#   'noise',
#   'loud',
#   'mattress',
#   'mattress',
#   'protector',
#   'thin',
#   'fitted',
#   'sheet',
#   'go',
#   'straight',
#   'matress',
#   'gross',
#   'thumb'],
#  ['conveniently_locate',
#   'block',
#   'first',
#   'time',
#   'visit',
#   'select',
#   'mainly',
#   'basis',
#   'review',
#   'retrospect',
#   'may',
#   'safe',
#   'stay',
#   'night',
#   'give',
#   'location',
#   'search',
#   'alternative',
#   'meet',
#   'satisfaction',
#   'location',
#   'excellent',
#   'capable',
#   'walk',
#   'flight',
#   'steep',
#   'place',
#   'may',
#   'pose',
#   'challenge',
#   'help',
#   'assist',
#   'bag',
#   'maybe',
#   'much',
#   'early',
#   'check',
#   'next_morne',
#   'simply',
#   'furnish',
#   'hotel',
#   'many',
#   'similar',
#   'offering',
#   'thing',
#   'note',
#   'price',
#   'drop',
#   'considerably',
#   'made_reservation',
#   'line',
#   'several',
#   'month',
#   'ago',
#   'sometimes',
#   'inclined'],
#  ['right',
#   'market',
#   'grocery',
#   'store',
#   'employee',
#   'great',
#   'courteous',
#   'room',
#   'grand',
#   'special',
#   'hotel',
#   'old',
#   'look',
#   'room',
#   'hot',
#   'ask',
#   'second',
#   'fan',
#   'sauna',
#   'temperature',
#   'cool',
#   'deck',
#   'patio',
#   'cheap',
#   'charge',
#   'day',
#   'wifi',
#   'disappointment',
#   'hotel',
#   'include',
#   'level',
#   'dining',
#   'living_room',
#   'area',
#   'fountain',
#   'nice',
#   'chill',
#   'patio',
#   'nice',
#   'well',
#   'great_views',
#   'lot',
#   'seating'],
#  ['find',
#   'pet',
#   'friendly',
#   'hotel',
#   'blocks_main',
#   'able',
#   'visit',
#   'lot',
#   'landmark',
#   'small',
# ...
#   'could',
#   'clean',
#   'price',
#   'would',
#   'expect',
#   'bit',
#   'tip',
#   'go',
#   'pancake',
#   'breakfast'],
#  ['hotel',
#   'wet',
#   'room',
#   'could',
#   'smell',
#   'time',
#   'may',
#   'hard',
#   'sleep',
#   'room',
#   'hand',
#   'room',
#   'clean',
#   'receptionist',
#   'speak',
#   'good',
#   'willing',
#   'help',
#   'water',
#   'coffee',
#   'free',
#   'day',
#   'long'],
#  ['disappoint',
#   'lack',
#   'ambience',
#   'intermittent',
#   'music',
#   'table',
#   'decorate',
#   'normally',
#   'food',
#   'serve',
#   'room',
#   'temperature',
#   'quickly',
#   'go',
#   'cold',
#   'disappointing',
#   'experience',
#   'whole',
#   'entrance',
#   'area',
#   'need',
#   'revamp',
#   'previously',
#   'stay',
#   'years_ago',
#   'lovely',
#   'memory',
#   'choose',
#   'lunch',
#   'disappoint',
#   'find',
#   'aged',
#   'staff',
#   'welcome'],
#  ['stayed_night',
#   'staff_friendly',
#   'restaurant',
#   'great',
#   'breakfast',
#   'also',
#   'adjoin',
#   'bakery',
#   'location',
#   'hotel',
#   'area',
#   'unfortunately',
#   'bed',
#   'rather',
#   'hard',
#   'uncomfortable',
#   'room',
#   'hot',
#   'rather',
#   'noisy',
#   'could_hear',
#   'people',
#   'clearly',
#   'make',
#   'somewhat',
#   'difficult',
#   'sleep',
#   'time'],
#  ['night',
#   'budget',
#   'establishment',
#   'nice',
#   'proprietor',
#   'helpful',
#   'need',
#   'pro',
#   'relatively',
#   'quiet',
#   'first',
#   'room',
#   'see',
#   'review',
#   'convenient',
#   'excellent',
#   'breakfast',
#   'lunch_dinner',
#   'first',
#   'place',
#   'get',
#   'size',
#   'bed',
#   'con',
#   'room',
#   'bite',
#   'dark',
#   'well',
#   'use',
#   'bit',
#   'dusty',
#   'noisy',
#   'tenant',
#   'courtyard',
#   'late',
#   'loud',
#   'nice',
#   'aware',
#   'noisy',
#   'loud',
#   'singe',
#   'entertainment',
#   'weekend',
#   'room',
#   'back',
#   'wall',
#   'luckily',
#   'seem',
#   'stop',
#   'keep',
#   'second'],
#  ['couple',
#   'year',
#   'old',
#   'stay',
#   'room',
#   'small',
#   'clean',
#   'private_bathroom',
#   'also',
#   'clean',
#   'however',
#   'small',
#   'open',
#   'bathroom',
#   'hallway',
#   'high',
#   'wall',
#   'bar',
#   'roof',
#   'noisy',
#   'staff',
#   'shut',
#   'pm',
#   'hostel',
#   'quiet',
#   'night',
#   'staff',
#   'insist',
#   'hold',
#   'passport',
#   'ensure',
#   'payment',
#   'even_though',
#   'pay',
#   'cash',
#   'advance',
#   'claim',
#   'never',
#   'encounter',
#   'practice',
#   'would',
#   'good',
#   'place',
#   'young',
#   'traveler',
#   'look',
#   'socialize',
#   'party'],
#  ['noise',
#   'place',
#   'crazy',
#   'church_bell',
#   'ring',
#   'hotel',
#   'loudspeaker',
#   'play',
#   'mariachi',
#   'full',
#   'volume',
#   'pm',
#   'pm',
#   'traffic',
#   'definitely',
#   'pick',
#   'night',
#   'leave',
#   'torture',
#   'ear',
#   'violate',
#   'mind',
#   'advertisement',
#   'play',
#   'imagination',
#   'regard',
#   'place',
#   'reality',
#   'however',
#   'different'],
#  ['good',
#   'thing',
#   'come',
#   'stay',
#   'terrace',
#   'fellow',
#   'traveler',
#   'friend',
#   'meet',
#   'make',
#   'far',
#   'expensive',
#   'variety',
#   'hostel',
#   'option',
#   'would',
#   'also',
#   'poor',
#   'service',
#   'noisy',
#   'day',
#   'morning',
#   'view',
#   'volcano',
#   'terrace',
#   'save',
#   'grace',
#   'actually',
#   'enjoy',
#   'included_breakfast',
#   'include',
#   'beverage',
#   'drink',
#   'breakfast',
#   'price',
#   'pay',
#   'criminal',
#   'speak',
#   'criminal',
#   'friend',
#   'also',
#   'camera',
#   'steal',
#   'hostel',
#   'footage',
#   'make',
#   'available',
#   'push',
#   'several',
#   'day',
#   'even'],
#  ['arrive',
#   'little',
#   'cockroach',
#   'bed',
#   'bedroom',
#   'light',
#   'work',
#   'music',
#   'vibrate',
#   'wall',
#   'love',
#   'party',
#   'come_back',
#   'clean',
#   'room',
#   'able',
#   'go',
#   'sleep',
#   'want',
#   'say',
#   'lady',
#   'incredibly',
#   'helpful',
#   'apologetic',
#   'ask',
#   'help',
#   'find',
#   'new',
#   'hotel',
#   'pm',
#   'night',
#   'decide',
#   'enough',
#   'enough',
#   'call',
#   'around',
#   'get',
#   'somewhere',
#   'road',
#   'know',
#   'place',
#   'high',
#   'trip_advisor'],
#  ['place',
#   'student',
#   'interested',
#   'party',
#   'get',
#   'waste',
#   'meet',
#   'student',
#   'good',
#   'night',
#   'sleep',
#   'many',
#   'people',
#   'come',
#   'time',
#   'scream',
#   'loudly',
#   'hall',
#   'drunk',
#   'try',
#   'open',
#   'door',
#   'hostel',
#   'fall',
#   'apart',
#   'let',
#   'mention',
#   'hygiene',
#   'bathroom',
#   'shower',
#   'share',
#   'many',
#   'people',
#   'quality',
#   'mattress',
#   'feel',
#   'spring',
#   'back',
#   'sleep',
#   'tiny',
#   'cramped',
#   'room',
#   'synthetic',
#   'linen',
#   'leave',
#   'today'],
#  ['much',
#   'may',
#   'even',
#   'forget',
#   'believe',
#   'staff',
#   'incredibly',
#   'sweet',
#   'helpful',
#   'however',
#   'initial',
#   'love',
#   'place',
#   'soon',
#   'replace',
#   'incredible',
#   'annoyance',
#   'frustration',
#   'hammer',
#   'noise',
#   'intense',
#   'wake',
#   'hammer',
#   'sound',
#   'worker',
#   'top',
#   'room',
#   'also',
#   'mean',
#   'wake',
#   'sunrise',
#   'maybe',
#   'early_morne',
#   'would',
#   'problem',
#   'party',
#   'late',
#   'previous',
#   'night',
#   'initially',
#   'love',
#   'place',
#   'quite',
#   'disappointed',
#   'outcome',
#   'seek'],
#  ['reason',
#   'rate',
#   'rooftop',
#   'patio',
#   'view',
#   'fellow',
#   'traveller',
#   'would',
#   'congregate',
#   'bottle',
#   'wine',
#   'end',
#   'day',
#   'watch',
#   'sunset',
#   'volcano',
#   'room',
#   'nice',
#   'large',
#   'clean',
#   'bathroom',
#   'breakfast_buffet',
#   'bad',
#   'beef',
#   'slow',
#   'response',
#   'room',
#   'light',
#   'bulb',
#   'expire',
#   'take',
#   'hour',
#   'person',
#   'come',
#   'ladder',
#   'install',
#   'new',
#   'bulb',
#   'breakfast'],
#  ['stay',
#   'location',
#   'fantastic',
#   'room',
#   'basic',
#   'tv',
#   'simple',
#   'furniture',
#   'room',
#   'maintenance',
#   'issue',
#   'room',
#   'rather',
#   'small',
#   'clean',
#   'free_wifi',
#   'available',
#   'staff_member',
#   'great',
#   'attitude',
#   'manner',
#   'clearly',
#   'compensate',
#   'shortcoming',
#   'room',
#   'breakfast',
#   'available',
#   'understand',
#   'own',
#   'hotel',
#   'offer',
#   'great',
#   'breakfast',
#   'coffee',
#   'bite',
#   'put',
#   'rather',
#   'excessive',
#   'price',
#   'hotel',
#   'may',
#   'fact',
#   'stay',
#   'busy',
#   'day',
#   'year',
#   'charge',
#   'night',
#   'double',
#   'hotel',
#   'class',
#   'charge',
#   'hotel',
#   'good',
#   'option',
#   'basic'],
#  ['spend',
#   'actually',
#   'plane',
#   'hike',
#   'trek',
#   'volcano',
#   'night',
#   'really',
#   'need',
#   'sleep',
#   'trerrible',
#   'speak',
#   'guide',
#   'reception',
#   'many_time',
#   'continue',
#   'pm',
#   'party',
#   'hotel',
#   'day',
#   'take',
#   'also',
#   'disappointment',
#   'local',
#   'guide',
#   'never',
#   'look',
#   'behind',
#   'fast',
#   'group',
#   'lose',
#   'even',
#   'warn',
#   'guide',
#   'change',
#   'behavior',
#   'morning',
#   'wake',
#   'early',
#   'guide',
#   'sleep',
#   'chance',
#   'wake',
#   'time',
#   'try',
#   'wake'],
#  ['offer',
#   'tourist',
#   'traveler',
#   'enjoy',
#   'vice',
#   'night',
#   'life',
#   'location',
#   'pretty',
#   'great',
#   'couple_block',
#   'central_park',
#   'several',
#   'fun',
#   'option',
#   'night',
#   'club',
#   'block',
#   'even',
#   'want',
#   'stay',
#   'dining',
#   'drinking',
#   'dance',
#   'mainstream',
#   'music',
#   'last',
#   'night',
#   'around_pm',
#   'also',
#   'quaint',
#   'jacuzzi',
#   'back',
#   'guest',
#   'close',
#   'pm',
#   'wish',
#   'open',
#   'later',
#   'private',
#   'room',
#   'look',
#   'dank',
#   'hell',
#   'share',
#   'dorm',
#   'opinion',
#   'lack',
#   'provide',
#   'locker',
#   'bunk',
#   'absent',
#   'personal',
#   'light',
#   'electric',
#   'outlet',
#   'assign',
#   'dorm',
#   'bed',
#   'entire',
#   'room',
#   'electrical'],
#  ['hotel',
#   'use',
#   'lot',
#   'adventure',
#   'group',
#   'look',
#   'quiet',
#   'place',
#   'sleep',
#   'place',
#   'may',
#   'lucky',
#   'avoid',
#   'group',
#   'chance',
#   'group',
#   'quite',
#   'pleased',
#   'place',
#   'wifi_work',
#   'lobby',
#   'room',
#   'clean',
#   'room',
#   'shower',
#   'whole',
#   'hotel',
#   'decide',
#   'shower',
#   'time',
#   'concrete',
#   'helpful',
#   'staff',
#   'breakfast',
#   'ant',
#   'bathroom'],
#  ['stay',
#   'part',
#   'tour',
#   'organise',
#   'contact',
#   'staff',
#   'situate',
#   'hotel',
#   'basic',
#   'comfortable'],
#  ['decide',
#   'hotel',
#   'aviod',
#   'ruthless',
#   'drunk',
#   'loud',
#   'people',
#   'crowd',
#   'however',
#   'manage',
#   'find',
#   'room',
#   'noice',
#   'start',
#   'end',
#   'repeatetly',
#   'ask',
#   'noisy',
#   'guest',
#   'politely',
#   'quiet',
#   'respect',
#   'tell',
#   'guard',
#   'trouble',
#   'first',
#   'time',
#   'talk',
#   'work',
#   'second',
#   'time',
#   'neighbour',
#   'keep',
#   'talk',
#   'guard',
#   'even',
#   'come',
#   'room',
#   'nice',
#   'building',
#   'loud',
#   'neighbour',
#   'ruin',
#   'stay'],
#  ['room',
#   'lock',
#   'good',
#   'travel',
#   'desk',
#   'breakfast',
#   'bean',
#   'coffee',
#   'english_speake',
#   'staff',
#   'tell',
#   'website',
#   'also',
#   'can',
#   'pay',
#   'card',
#   'room',
#   'rather',
#   'grim',
#   'lock',
#   'window',
#   'together',
#   'muxh',
#   'overpriced'],
#  ['sure',
#   'hotel',
#   'describe',
#   'charming',
#   'maybe',
#   'old',
#   'gentleman',
#   'work',
#   'would',
#   'say',
#   'stop',
#   'grant',
#   'nice',
#   'want',
#   'cancel',
#   'second_night',
#   'originally_booke',
#   'positive',
#   'hotel',
#   'quiet',
#   'read',
#   'countless',
#   'review',
#   'place',
#   'seem',
#   'struggle',
#   'noise',
#   'hotel',
#   'least',
#   'quiet',
#   'room',
#   'tiny',
#   'dingy',
#   'dark',
#   'suspicious',
#   'shower',
#   'electrocute',
#   'husband',
#   'place',
#   'atmosphere',
#   'ever',
#   'kind',
#   'place',
#   'leave',
#   'feel',
#   'dirty',
#   'stay',
#   'leave',
#   'morning',
#   'comment',
#   'breakfast',
#   'want',
#   'leave',
#   'quickly',
#   'possible'],
#  ['recently',
#   'stay',
#   'route',
#   'hotel',
#   'strangely',
#   'arrange',
#   'pool_table',
#   'awkwardly',
#   'middle',
#   'way',
#   'check',
#   'suggestion',
#   'food',
#   'guest',
#   'step',
#   'offer',
#   'suggestion',
#   'american',
#   'owner',
#   'presumably',
#   'right',
#   'desk',
#   'remain',
#   'silent',
#   'try',
#   'communicate',
#   'staff',
#   'little',
#   'english',
#   'assist',
#   'stilted',
#   'communication',
#   'room',
#   'shared_bathroom',
#   'close',
#   'room',
#   'room',
#   'cramp',
#   'double_bed',
#   'room',
#   'bed',
#   'ceile',
#   'low',
#   'combination',
#   'bed',
#   'make',
#   'room',
#   'feel',
#   'claustrophobic',
#   'get',
#   'bed'],
#  ['anywhere',
#   'stay',
#   'expectation',
#   'heavily',
#   'influence',
#   'impression',
#   'review',
#   'place',
#   'expect',
#   'budget',
#   'hotel',
#   'locate',
#   'multiple',
#   'bar',
#   'nearby',
#   'think',
#   'people',
#   'would',
#   'ok',
#   'enough',
#   'book',
#   'know',
#   'bar',
#   'hotel',
#   'expect',
#   'hear',
#   'noise',
#   'night',
#   'choose',
#   'seem',
#   'optimally',
#   'locate',
#   'aim',
#   'location',
#   'block',
#   'right',
#   'centre',
#   'thing',
#   'say',
#   'realize',
#   'arrive',
#   'small',
#   'block',
#   'tiny',
#   'place',
#   'discount',
#   'extra',
#   'minute',
#   'walk',
#   'room',
#   'small',
#   'basic',
#   'little',
#   'dark',
#   'nice',
#   'touch'],
#  ['stay',
#   'wedding',
#   'really',
#   'want',
#   'place',
#   'sleep',
#   'unfortunately',
#   'room',
#   'close',
#   'street',
#   'bite',
#   'noisy',
#   'clean',
#   'centric',
#   'would',
#   'stay',
#   'option',
#   'would',
#   'look',
#   'first'],
#  ['stay',
#   'weekend',
#   'private',
#   'double',
#   'ok',
#   'quality',
#   'good',
#   'value_money',
#   'compare',
#   'similar',
#   'room',
#   'hostel',
#   'area',
#   'weekend',
#   'expect',
#   'bit',
#   'expect',
#   'terrace_bar',
#   'quite',
#   'noisy',
#   'day',
#   'room',
#   'right',
#   'bar',
#   'kitchen',
#   'could_hear',
#   'music',
#   'box',
#   'bottle',
#   'drag',
#   'around',
#   'midnight',
#   'need',
#   'power',
#   'nap',
#   'nasty',
#   'night',
#   'bus',
#   'want',
#   'sleep',
#   'lot',
#   'local',
#   'people',
#   'hostel',
#   'seem',
#   'visit',
#   'bar',
#   'tend',
#   'hog',
#   'upstairs',
#   'bathroom',
#   'whole',
#   'hostel',
#   'shower',
#   'little',
#   'tricky'],
#  ['mistaken',
#   'definitely',
#   'price',
#   'charge',
#   'much',
#   'say',
#   'thing',
#   'average',
#   'hotel',
#   'location',
#   'price',
#   'rest',
#   'room',
#   'bed',
#   'bathroom',
#   'say',
#   'even',
#   'hostel',
#   'even',
#   'room',
#   'locate',
#   'hotel',
#   'restaurant',
#   'noise',
#   'definitely',
#   'good',
#   'place'],
#  ['stayed_night',
#   'comfortable',
#   'room',
#   'bed',
#   'good',
#   'garden',
#   'look',
#   'good',
#   'comfortable',
#   'seat',
#   'plenty',
#   'insect',
#   'bite',
#   'average',
#   'breakfast',
#   'give',
#   'go',
#   'breakfast',
#   'place',
#   'well',
#   'away',
#   'block',
#   'km',
#   'quiet',
#   'street',
#   'want',
#   'walk',
#   'back',
#   'fact',
#   'place',
#   'lock',
#   'armed',
#   'tell',
#   'nee',
#   'know',
#   'security',
#   'concern'],
#  ['work',
#   'tourism',
#   'industry',
#   'stay',
#   'hotel',
#   'try',
#   'speak',
#   'people',
#   'manage',
#   'property',
#   'order',
#   'know',
#   'wrong',
#   'show',
#   'improve',
#   'unfortunately',
#   'case',
#   'hotel',
#   'bad',
#   'experience',
#   'ever',
#   'hotel',
#   'club',
#   'hotel',
#   'keep',
#   'room',
#   'small',
#   'picture',
#   'show',
#   'finish',
#   'thing',
#   'wake',
#   'sound',
#   'people',
#   'work',
#   'restaurant',
#   'prepare',
#   'breakfast',
#   'happen',
#   'stay',
#   'next_day',
#   'try',
#   'explain',
#   'case',
#   'agent',
#   'even',
#   'care',
#   'general',
#   'manager',
#   'never'],
#  ['small',
#   'establishment',
#   'kid',
#   'friendly',
#   'nice',
#   'playground',
#   'kid',
#   'loud',
#   'small',
#   'windows_open',
#   'get',
#   'air',
#   'hear',
#   'noise',
#   'courtyard',
#   'room',
#   'room',
#   'get',
#   'hot',
#   'beds_comfortable',
#   'room',
#   'big',
#   'small',
#   'bathroom',
#   'room',
#   'put',
#   'anywhere',
#   'time',
#   'take',
#   'breakfast_include',
#   'take',
#   'almost',
#   'hour',
#   'breakfast',
#   'many',
#   'day',
#   'thing',
#   'get',
#   'old',
#   'week',
#   'hotel',
#   'pretty',
#   'nice',
#   'many',
#   'place',
#   'stay',
#   'provide',
#   'well',
#   'value'],
#  ['book',
#   'book',
#   'double',
#   'triple',
#   'room',
#   'twin',
#   'switch',
#   'triple',
#   'tiny',
#   'room',
#   'double_bed',
#   'arrive',
#   'room',
#   'locate',
#   'back',
#   'next',
#   'laundry',
#   'quite',
#   'noisy',
#   'get',
#   'bad',
#   'start',
#   'also',
#   'room',
#   'available',
#   'outlet',
#   'phone',
#   'charging',
#   'different',
#   'circumstance',
#   'may',
#   'like',
#   'stay',
#   'serve',
#   'nice',
#   'breakfast',
#   'coffee',
#   'available',
#   'early',
#   'riser',
#   'well_situate',
#   'town'],
#  ['minute',
#   'walk',
#   'many',
#   'shops_restaurant',
#   'bar',
#   'pleasant',
#   'well',
#   'restore',
#   'traditional',
#   'hotel',
#   'good',
#   'room',
#   'queen',
#   'sized',
#   'bed',
#   'old',
#   'style',
#   'tv',
#   'roof',
#   'light',
#   'blind',
#   'wake',
#   'quite',
#   'early',
#   'light',
#   'problem',
#   'need',
#   'good',
#   'free',
#   'wi_fi',
#   'room',
#   'good',
#   'shower',
#   'shower',
#   'room',
#   'courtyard',
#   'supermarket'],
#  ['room',
#   'clean',
#   'building',
#   'nice',
#   'unfortunately',
#   'atmosphere',
#   'bit',
#   'cold',
#   'much',
#   'light',
#   'whole',
#   'building',
#   'staff',
#   'around',
#   'arrive',
#   'may',
#   'better_place'],
#  ['take',
#   'long',
#   'reach',
#   'downtown',
#   'advantage',
#   'hotel',
#   'small',
#   'bakery',
#   'nearby',
#   'min',
#   'walk',
#   'expensive',
#   'taste',
#   'good',
#   'convenient',
#   'next',
#   'hotel',
#   'pretty',
#   'good_location',
#   'shop',
#   'nearby',
#   'sick',
#   'travel',
#   'go',
#   'travel',
#   'day',
#   'take',
#   'rest',
#   'hotel',
#   'go',
#   'pastry',
#   'shop',
#   'lot',
#   'enough',
#   'power',
#   'walk',
#   'faraway',
#   'hotel',
#   'say',
#   'bread',
#   'save',
#   'life',
#   'old',
#   'town',
#   'beautiful',
#   'landscape',
#   'volcano',
#   'city'],
#  ['stay',
#   'part',
#   'adventure',
#   'tour',
#   'room',
#   'small',
#   'basic',
#   'hotel',
#   'great',
#   'hotel',
#   'shop',
#   'buy',
#   'drink',
#   'snack',
#   'nice',
#   'bakery',
#   'also',
#   'tasty',
#   'breakfast',
#   'nice',
#   'room',
#   'see',
#   'invite',
#   'hotel'],
#  ['place',
#   'type',
#   'place',
#   'get',
#   'pay',
#   'much',
#   'quite',
#   'simple',
#   'daunting',
#   'entrance',
#   'timber',
#   'door',
#   'open',
#   'nice',
#   'venue',
#   'hotel',
#   'different',
#   'room',
#   'quite_dark',
#   'eery',
#   'bathroom',
#   'basic',
#   'large',
#   'room',
#   'safe',
#   'air',
#   'conditioner',
#   'much',
#   'problem',
#   'quite',
#   'safe',
#   'high',
#   'brick',
#   'wall',
#   'solid',
#   'timber',
#   'gate',
#   'expose',
#   'concrete',
#   'brick',
#   'render',
#   'wall',
#   'act',
#   'good',
#   'insulator',
#   'keep',
#   'heat',
#   'invite',
#   'place',
#   'blink',
#   'door',
#   'convenience',
#   'store',
#   'purchase',
#   'snack',
#   'drink',
#   'smoke',
#   'next_door',
#   'side',
#   'find',
#   'nice',
#   'bakery',
#   'make',
#   'nice'],
#  ['fine',
#   'room',
#   'next',
#   'occupy',
#   'fart',
#   'could',
#   'smell',
#   'dorm',
#   'living',
#   'price',
#   'otherwise',
#   'clean',
#   'helpful',
#   'staff'],
#  ...]

# %%
[[a,b],[d,c]] -> [a, b, c, d]

# %%
entire_corpus = negative_docs + positive_docs

# %%
entire_corpus
# Out:
# [['town',
#   'especially',
#   'be',
#   'go',
#   'antiguena',
#   'good',
#   'sized',
#   'private',
#   'twin',
#   'room',
#   'shared_bathroom',
#   'great',
#   'price',
#   'nice',
#   'ish',
#   'garden',
#   'swing',
#   'basic',
#   'bathroom',
#   'tatty',
#   'hot',
#   'shower',
#   'always',
#   'keep',
#   'water',
#   'flow',
#   'slow',
#   'super',
#   'basic',
#   'pretty',
#   'dirty',
#   'kitchenette',
#   'load',
#   'cat',
#   'dog',
#   'cheap',
#   'basic',
#   's'],
#  ['go',
#   'hotel',
#   'directly',
#   'book',
#   'room',
#   'receptionist',
#   'first',
#   'really',
#   'high',
#   'price',
#   'lower',
#   'ask',
#   'much',
#   'cost',
#   'qetale',
#   'comission',
#   'rate',
#   'dollar',
#   'know',
#   'randomly',
#   'gove',
#   'non',
#   'exist',
#   'rate',
#   'lower',
#   'real',
#   'rate',
#   'agree',
#   'price',
#   'include',
#   'breakfast',
#   'follow',
#   'morning',
#   'get',
#   'breakfast',
#   'receive',
#   'plain',
#   'piece',
#   'toast',
#   'fruit',
#   'theother',
#   'table',
#   'receive',
#   'also',
#   'egg',
#   'ask',
#   'also',
#   'egg',
#   'reply',
#   'come',
#   'breakfast',
#   'pay',
#   'good',
#   'experience',
#   'hotel',
#   'place',
#   'stay'],
#  ['go',
#   'break',
#   'good',
#   'bad',
#   'good_location',
#   'free_breakfast',
#   'warm',
#   'helpful',
#   'staff',
#   'hour',
#   'massage',
#   'bad',
#   'small',
#   'room',
#   'great',
#   'air_circulation',
#   'awful',
#   'quality',
#   'bed',
#   'noisy',
#   'dog',
#   'let',
#   'decide',
#   'important',
#   'awful',
#   'bed',
#   'kill',
#   'massage',
#   'make',
#   'feel',
#   'well',
#   'choice',
#   'sure',
#   'come_back',
#   'back',
#   'handle',
#   'way',
#   'night',
#   'advertise',
#   'totally',
#   'wrong',
#   'end',
#   'night',
#   'triple',
#   'room',
#   'really',
#   'worth',
#   'many',
#   'choice'],
#  ['night',
#   'delay',
#   'bus',
#   'journey',
#   'original',
#   'accommodation',
#   'give',
#   'away',
#   'place',
#   'could',
#   'find',
#   'could',
#   'accommodate',
#   'grateful',
#   'price',
#   'wifi',
#   'seem',
#   'decent',
#   'value',
#   'however',
#   'room',
#   'incredibly',
#   'basic',
#   'unclean',
#   'mosquito',
#   'everywhere',
#   'insect',
#   'floor',
#   'bathroom',
#   'key',
#   'door',
#   'apparently',
#   'however',
#   'lock',
#   'inside',
#   'feel',
#   'secure',
#   'place',
#   'stay',
#   'night_guard',
#   'big',
#   'lock',
#   'night',
#   'staff',
#   'limit',
#   'test',
#   'see',
#   'much',
#   'else',
#   'bathroom',
#   'bedroom',
#   'morning',
#   'come'],
#  [],
#  ['dirty',
#   'offer',
#   'towel',
#   'sheet',
#   'nasty',
#   'bathroom',
#   'gross',
#   'owner',
#   'take',
#   'dollar',
#   'give',
#   'receipt',
#   'terrible'],
#  ['use',
#   'tourist',
#   'shuttle',
#   'get',
#   'back_forth',
#   'country',
#   'pretty',
#   'often',
#   'book',
#   'shuttle',
#   'shuttle',
#   'woman',
#   'sit',
#   'phone',
#   'look',
#   'time',
#   'tell',
#   'come',
#   'minute',
#   'standard',
#   'sometimes',
#   'bus',
#   'pick',
#   'early',
#   'sometimes',
#   'pick',
#   'minute',
#   'late',
#   'today',
#   'bus',
#   'minute',
#   'late',
#   'still',
#   'wait',
#   'front',
#   'woman',
#   'say',
#   'fault',
#   'true',
#   'charge',
#   'inflated',
#   'price',
#   'later',
#   'shuttle',
#   'say',
#   'less',
#   'people',
#   'shuttle',
#   'price',
#   'expensive',
#   'finally',
#   'call',
#   'shuttle',
#   'company',
#   'say',
#   'pick',
#   'people'],
#  ['stay',
#   'home',
#   'last',
#   'weekend',
#   'want',
#   'room',
#   'nice',
#   'hotel',
#   'already',
#   'want',
#   'see',
#   'hotel',
#   'maybe',
#   'even',
#   'look',
#   'room',
#   'meeting',
#   'friend',
#   'take',
#   'look',
#   'arrive',
#   'early',
#   'clerk',
#   'personal',
#   'call',
#   'refuse',
#   'acknowledge',
#   'even',
#   'look',
#   'minute',
#   'early',
#   'take',
#   'look',
#   'lobby',
#   'pool',
#   'use',
#   'man',
#   'room',
#   'go',
#   'wild',
#   'start',
#   'scream',
#   'man',
#   'room',
#   'guest',
#   'scream',
#   'embarrassing',
#   'basically',
#   'kick',
#   'hotel',
#   'group'],
#  ['book',
#   'hotel',
#   'pool',
#   'parking',
#   'good',
#   'review',
#   'request',
#   'upstairs',
#   'room',
#   'balcony',
#   'get',
#   'room',
#   'clean',
#   'however',
#   'way',
#   'overpriced',
#   'get',
#   'tiny',
#   'quaint',
#   'rather',
#   'charming',
#   'room',
#   'big',
#   'drawback',
#   'noise',
#   'venue',
#   'bar',
#   'loud_music',
#   'reverberate',
#   'wall',
#   'way',
#   'go',
#   'able',
#   'sleep',
#   'credit',
#   'management',
#   'ring',
#   'bar',
#   'ask',
#   'turn',
#   'still',
#   'terribly',
#   'loud',
#   'manager',
#   'come',
#   'offer',
#   'room',
#   'hotel',
#   'happy'],
#  ['arrive',
#   'hotel',
#   'around',
#   'already',
#   'read',
#   'previous',
#   'review',
#   'want',
#   'charge',
#   'early',
#   'check',
#   'expect',
#   'bad',
#   'first',
#   'tell',
#   'room',
#   'available',
#   'wait',
#   'couple',
#   'hour',
#   'minute',
#   'wait',
#   'receptionist',
#   'call',
#   'say',
#   'room',
#   'available',
#   'charging',
#   'hour',
#   'early',
#   'check',
#   'standard',
#   'checking',
#   'time',
#   'pm',
#   'ask',
#   'additional',
#   'order',
#   'check',
#   'disappoint',
#   'upset',
#   'treated',
#   'way',
#   'specially',
#   'explain',
#   'already',
#   'pay',
#   'almost',
#   'red',
#   'eye',
#   'fly',
#   'want',
#   'rest',
#   'somehow',
#   'negotiate',
#   'still',
#   'rip',
#   'disgusting',
#   'decided_stay',
#   'additional',
#   'night'],
#  ['stay',
#   'total',
#   'nearly',
#   'week',
#   'visit',
#   'visit',
#   'already',
#   'reserve',
#   'family',
#   'friend',
#   'stranger',
#   'become',
#   'friend',
#   'slap',
#   'dash',
#   'haphazard',
#   'time',
#   'much',
#   'wifi',
#   'wonky',
#   'back',
#   'recommend',
#   'friend',
#   'oasis',
#   'expectation',
#   'courtyard',
#   'walk',
#   'way',
#   'hang',
#   'dense',
#   'flower',
#   'vine',
#   'spring',
#   'summer',
#   'add',
#   'flowering',
#   'shrub',
#   'tree',
#   'perfume',
#   'small',
#   'aspire',
#   'main',
#   'courtyard',
#   'add',
#   'bouquet',
#   'soundtrack',
#   'splash',
#   'water',
#   'perfect',
#   'place',
#   'sip',
#   'beer',
#   'read',
#   'book',
#   'fall'],
#  ['hotel',
#   'medium',
#   'size',
#   'make',
#   'big',
#   'effort',
#   'give',
#   'feel',
#   'colonial',
#   'town',
#   'feel',
#   'authentic',
#   'walkable',
#   'distance',
#   'central_park',
#   'block',
#   'food',
#   'good',
#   'coffee',
#   'however',
#   'people',
#   'bite',
#   'cold',
#   'make',
#   'eye',
#   'contact',
#   'bathroom',
#   'design',
#   'smart',
#   'step',
#   'open',
#   'door',
#   'light',
#   'switch',
#   'step',
#   'easily',
#   'trip',
#   'dark',
#   'shower',
#   'partial',
#   'wall',
#   'water',
#   'get',
#   'floor',
#   'make',
#   'slippery',
#   'pool',
#   'pretty',
#   'warmish',
#   'water',
#   'area',
#   'well',
#   'take',
#   'care'],
#  ['room',
#   'front',
#   'entrance',
#   'squeaky',
#   'gate',
#   'drop',
#   'oil',
#   'would',
#   'sort',
#   'problem',
#   'second',
#   'come',
#   'go',
#   'also',
#   'people',
#   'tend',
#   'stop',
#   'front',
#   'room',
#   'talk',
#   'could',
#   'look',
#   'window',
#   'closed',
#   'shutter',
#   'however',
#   'room',
#   'dark',
#   'maybe',
#   'room',
#   'upstairs',
#   'well',
#   'old',
#   'look',
#   'worn',
#   'fit',
#   'double',
#   'mattress',
#   'also',
#   'pillow',
#   'pretty',
#   'horrendous',
#   'towel',
#   'bite',
#   'threadbare',
#   'plus_side',
#   'shower',
#   'good',
#   'room',
#   'clean',
#   'could',
#   'decent',
#   'place',
#   'need',
#   'look',
#   'certainly',
#   'overpriced'],
#  ['place',
#   'dump',
#   'day',
#   'evening',
#   'day',
#   'shower',
#   'disgusting',
#   'waste',
#   'money',
#   'less',
#   'money',
#   'stay',
#   'hotstel'],
#  ['hotel',
#   'terrible',
#   'measureable',
#   'way',
#   'entire',
#   'stay',
#   'people',
#   'hotel',
#   'order',
#   'door',
#   'lock',
#   'properly',
#   'take',
#   'nearly',
#   'go',
#   'shower',
#   'extremely',
#   'cold',
#   'lock',
#   'big',
#   'issue',
#   'travel',
#   'girl',
#   'sit',
#   'shower',
#   'overall',
#   'stay',
#   'hotel',
#   'ruin',
#   'visit',
#   'beautiful',
#   'town'],
#  ['friendly',
#   'staff',
#   'room',
#   'amenity',
#   'close',
#   'town',
#   'centre',
#   'unlucky',
#   'apartment',
#   'own',
#   'really',
#   'like',
#   'sound',
#   'voice',
#   'like',
#   'drink',
#   'lot',
#   'make',
#   'stay',
#   'unpleasant'],
#  ['fairly',
#   'affordable',
#   'location',
#   'good',
#   'fairly',
#   'busy',
#   'loud',
#   'street',
#   'basic',
#   'amenity',
#   'work',
#   'clean',
#   'safe',
#   'place',
#   'nice',
#   'little',
#   'courtyard',
#   'hairdryer',
#   'overall',
#   'decent',
#   'place',
#   'picky'],
#  ['former',
#   'hotel',
#   'other',
#   'say',
#   'review',
#   'room',
#   'super',
#   'clean',
#   'bathroom',
#   'nice',
#   'flat',
#   'screen',
#   'tv',
#   'room',
#   'truly',
#   'cute',
#   'little',
#   'hotel',
#   'exceptional',
#   'nice',
#   'kind',
#   'super',
#   'friendly',
#   'owner',
#   'son',
#   's',
#   'make',
#   'review',
#   'little',
#   'difficult',
#   'want',
#   'love',
#   'hotel',
#   'support',
#   'hotel',
#   'owner',
#   'thing',
#   'likely',
#   'struggle',
#   'stay',
#   'kinda',
#   'noisey',
#   'parking',
#   'inside',
#   'literally',
#   'bed',
#   'asleep',
#   'pm',
#   'awaken',
#   'sound',
#   'car',
#   'backing',
#   'downstairs',
#   'noise',
#   'loud',
#   'enough',
#   'sound',
#   'sleep',
#   'garage'],
#  ['great',
#   'set',
#   'relax',
#   'lot',
#   'really',
#   'positive',
#   'stuff',
#   'resort',
#   'gym',
#   'good',
#   'pool',
#   'area',
#   'great',
#   'kid',
#   'playground',
#   'room',
#   'recently',
#   'renovate',
#   'smart',
#   'dinner',
#   'restaurant',
#   'good',
#   'staff',
#   'also',
#   'lovely',
#   'friendly_helpful',
#   'relaxed',
#   'vibe',
#   'negative',
#   'stuff',
#   'mainly',
#   'hinge',
#   'reception',
#   'experience',
#   'honest',
#   'arrive',
#   'pm',
#   'guy',
#   'reception',
#   'large',
#   'wedding',
#   'party',
#   'take',
#   'place',
#   'probably',
#   'bit',
#   'stressed',
#   'however',
#   'welcome',
#   'quite',
#   'dismissive',
#   'want',
#   'sign',
#   'various',
#   'paperwork',
#   'key',
#   'send',
#   'way',
#   'travel',
#   'hour',
#   'say'],
#  ['seem',
#   'new',
#   'good',
#   'working',
#   'order',
#   'impecable',
#   'breakfast',
#   'good',
#   'far',
#   'negative',
#   'parking',
#   'nightmare',
#   'parking',
#   'send',
#   'sketchy',
#   'place',
#   'parking',
#   'attendant',
#   'seem',
#   'confused',
#   'hotel',
#   'come',
#   'car',
#   'would',
#   'block',
#   'exit',
#   'end',
#   'work',
#   'well',
#   'also',
#   'bathroom',
#   'small',
#   'place',
#   'put',
#   'toiletry',
#   'bag',
#   'finally',
#   'hotel',
#   'heavy',
#   'traffic',
#   'time',
#   'weekend'],
#  ['friend',
#   'book',
#   'online',
#   'online',
#   'say',
#   'room',
#   'leave',
#   'book',
#   'show',
#   'hotel',
#   'receptionist',
#   'lady',
#   'turn',
#   'away',
#   'room',
#   'available',
#   'say',
#   'small',
#   'room',
#   'small',
#   'room',
#   'would',
#   'put',
#   'extra',
#   'bed',
#   'would',
#   'tight',
#   'look',
#   'accommodation',
#   'ask',
#   'cancel',
#   'reservation',
#   'charge',
#   'card',
#   'say',
#   'would',
#   'cancel',
#   'stay',
#   'night',
#   'hotel',
#   'card',
#   'still',
#   'get',
#   'charge',
#   'go',
#   'back',
#   'ask',
#   'stay',
#   'get',
#   'refund',
#   'night',
#   'suppose',
#   'reservation',
#   'come',
#   'office',
#   'card',
#   'charge',
#   'could',
#   'cancel',
#   'lady'],
#  ['stayed_night',
#   'aware',
#   'high',
#   'rating',
#   'hotel',
#   'agree',
#   'point',
#   'mention',
#   'clean',
#   'good',
#   'service',
#   'book',
#   'transportation',
#   'fast',
#   'efficient',
#   'however',
#   'room',
#   'small',
#   'put',
#   'stuff',
#   'closet',
#   'fast',
#   'internet',
#   'small',
#   'tv',
#   'english',
#   'channel',
#   'room',
#   'safe',
#   'visit',
#   'city',
#   'take',
#   'passport',
#   'money',
#   'privacy',
#   'also',
#   'question',
#   'shut',
#   'window',
#   'light',
#   'pass',
#   'would',
#   'see',
#   'room'],
#  ['bed_comfortable',
#   'bite',
#   'short',
#   'foot',
#   'almost',
#   'stick',
#   'bed',
#   'pillow',
#   'thin',
#   'stack',
#   'together',
#   'make',
#   'pillow',
#   'noisy',
#   'use',
#   'earplug',
#   'paint',
#   'bathroom',
#   'peel',
#   'old',
#   'miss',
#   'ring',
#   'hole',
#   'would',
#   'stay',
#   'everywhere',
#   'else',
#   'book',
#   'pay',
#   'night'],
#  ['book',
#   'printout',
#   'confirmation',
#   'arrive',
#   'tourist',
#   'shuttle',
#   'eve',
#   'soon',
#   'mention',
#   'hotel',
#   'name',
#   'driver',
#   'couple',
#   'front',
#   'book',
#   'hotel',
#   'day',
#   'prior',
#   'use',
#   'honor',
#   'think',
#   'bad',
#   'incident',
#   'wrong',
#   'manager',
#   'refuse',
#   'look',
#   'booking_com',
#   'printout',
#   'room',
#   'normally',
#   'problem',
#   'know',
#   'hotel',
#   'tend',
#   'full',
#   'time',
#   'even',
#   'one',
#   'room',
#   'charge',
#   'much',
#   'high',
#   'normal',
#   'rate',
#   'reason',
#   'book',
#   'advance',
#   'luckily',
#   'find'],
#  ['good',
#   'view',
#   'obligingly',
#   'spew',
#   'cloud',
#   'smoke',
#   'dust',
#   'breakfast',
#   'time',
#   'day',
#   'room',
#   'poor',
#   'lighting',
#   'window_opene',
#   'internal',
#   'street',
#   'rather',
#   'useless',
#   'main',
#   'problem',
#   'hotel',
#   'situation',
#   'long',
#   'way',
#   'minute',
#   'walk_centre',
#   'many',
#   'uneven',
#   'surface',
#   'pothole',
#   'route',
#   'dimly',
#   'light',
#   'street',
#   'dark',
#   'necessitate',
#   'taxi',
#   'ride',
#   'especially',
#   'concerned',
#   'safety',
#   'evening',
#   'go',
#   'town',
#   'tend',
#   'stay',
#   'return',
#   'tend',
#   'go_back',
#   'inconvenient',
#   'problem',
#   'breakfast',
#   'absolutely',
#   'disgusting',
#   'coffee',
#   'merely',
#   'poor',
#   'nearest'],
#  ['want',
#   'much',
#   'hotel',
#   'nice',
#   'place',
#   'price',
#   'point',
#   'hotel',
#   'quite',
#   'lovely',
#   'centrally_located',
#   'nice',
#   'garden',
#   'clean',
#   'fantastic',
#   'view',
#   'room',
#   'great',
#   'apart',
#   'soft',
#   'bed',
#   'breakfast',
#   'parking',
#   'site',
#   'inconvenient',
#   'square',
#   'min',
#   'shape',
#   'deal',
#   'would',
#   'overlook',
#   'fact',
#   'first',
#   'day',
#   'constant',
#   'clanging',
#   'bell',
#   'nearby',
#   'church',
#   'complaint',
#   'unfortunately',
#   'loud',
#   'bar',
#   'playing',
#   'music'],
#  ['hate',
#   'write',
#   'arrive',
#   'hotel',
#   'truly',
#   'beautiful',
#   'staff',
#   'lovely',
#   'food',
#   'stay',
#   'friend',
#   'travel',
#   'arrival',
#   'wake',
#   'cover',
#   'way',
#   'spend',
#   'vacation',
#   'horrible',
#   'hotel',
#   'ask',
#   'proof',
#   'provide',
#   'clothe',
#   'change',
#   'room',
#   'appreciate',
#   'bad',
#   'rented',
#   'room',
#   'next',
#   'night',
#   'take',
#   'quickly',
#   'check',
#   'wonderful',
#   'city',
#   'would',
#   'stay'],
#  ['discover',
#   'reservation',
#   'fall',
#   'gain',
#   'room',
#   'generous',
#   'sized',
#   'bathroom',
#   'roomy',
#   'parking',
#   'need',
#   'owner',
#   'lovely',
#   'people',
#   'hotel',
#   'within_walke',
#   'distance',
#   'la_merce',
#   'restaurant',
#   'internet',
#   'service',
#   'close'],
#  ['disappointment',
#   'hotel',
#   'start',
#   'fact',
#   'reservation',
#   'want',
#   'send',
#   'hotel',
#   'complaie',
#   'mention',
#   'day',
#   'exchange',
#   'mail',
#   'own',
#   'confirm',
#   'transfer',
#   'airport',
#   'hotel',
#   'take',
#   'know',
#   'come',
#   'say',
#   'reservation',
#   'end',
#   'gave_us',
#   'room',
#   'discover',
#   'dirty',
#   'noisy',
#   'place',
#   'commune',
#   'photo',
#   'web',
#   'site',
#   'end',
#   'trip',
#   'use',
#   'hotel',
#   'much',
#   'clean',
#   'comfortable',
#   'nicer',
#   'also',
#   'none',
#   'people',
#   'reception',
#   'train',
#   'idea',
#   'accept',
#   'payment'],
#  ['stay',
#   'previously',
#   'decide',
#   'book',
#   'upmarket',
#   'hotel',
#   'final',
#   'night',
#   'flight',
#   'hotel',
#   'decent',
#   'location',
#   'dirty',
#   'comfortable',
#   'compare',
#   'cheap',
#   'hotel',
#   'previously',
#   'stay',
#   'arrive',
#   'ask',
#   'sheet',
#   'change',
#   'due',
#   'dirty',
#   'stay',
#   'also',
#   'notice',
#   'mug',
#   'old',
#   'lipstick',
#   'towel',
#   'dirty',
#   'pillowcase',
#   'first',
#   'time',
#   'consider',
#   'use',
#   'sleep',
#   'bag',
#   'inner',
#   'sleep',
#   'bed',
#   'staff',
#   'offer',
#   'solution',
#   'problem',
#   'walkable',
#   'location',
#   'relevant',
#   'definitely',
#   'much_better',
#   'stay',
#   'clean'],
#  ['night',
#   'previous',
#   'visit',
#   'stay',
#   'hotel',
#   'time',
#   'try',
#   'book',
#   'single',
#   'room',
#   'online',
#   'discount',
#   'bring',
#   'price',
#   'night',
#   'gtq',
#   'include',
#   'additional',
#   'taxis',
#   'come',
#   'room',
#   'small',
#   'come',
#   'ensuite',
#   'daily',
#   'housekeeping',
#   'hot_shower',
#   'cable',
#   'tv',
#   'breakfast',
#   'room',
#   'excellent',
#   'value',
#   'gtq',
#   'worth',
#   'rack',
#   'rate',
#   'night',
#   'list',
#   'worth',
#   'night',
#   'include',
#   'breakfast',
#   'host',
#   'nice',
#   'people',
#   'comfy',
#   'probably',
#   'little',
#   'much',
#   'edge',
#   'town',
#   'centre',
#   'people',
#   'decent'],
#  ['book',
#   'young',
#   'male',
#   'attempt',
#   'charge',
#   'tell',
#   'breakfast',
#   'include',
#   'other',
#   'egg',
#   'include',
#   'non',
#   'included_breakfast',
#   'want',
#   'egg',
#   'check',
#   'tell',
#   'woman',
#   'nee',
#   'pay',
#   'breakfast',
#   'correct',
#   'say',
#   'breakfast_include',
#   'catch',
#   'previous',
#   'man',
#   'lie',
#   'otherwise',
#   'like',
#   'pay',
#   'top',
#   'dollar',
#   'peak',
#   'time',
#   'accept',
#   'visa',
#   'cash',
#   'believe',
#   'man',
#   'lie',
#   'breakfast'],
#  ['basic',
#   'hotel',
#   'staff',
#   'nice',
#   'friendly',
#   'location',
#   'slightly',
#   'fringe',
#   'street',
#   'light',
#   'bright',
#   'area',
#   'happen',
#   'bedroom',
#   'back',
#   'hotel',
#   'open_air',
#   'market',
#   'start',
#   'really',
#   'early',
#   'noisy',
#   'light',
#   'sleeper',
#   'otherwise',
#   'ok',
#   'look',
#   'cheap',
#   'clean',
#   'place',
#   'stay'],
#  ['make',
#   'reservation',
#   'ask',
#   'pay',
#   'hotel',
#   'night',
#   'charge',
#   'night',
#   'credit_card',
#   'week',
#   'week',
#   'ask',
#   'refund',
#   'waste',
#   'time',
#   'polite',
#   'whatsapp',
#   'end',
#   'take',
#   'money',
#   'twice',
#   'never',
#   'get',
#   'refund',
#   'thief',
#   'avoid',
#   'cost',
#   'bad',
#   'experience',
#   'ever'],
#  ['room',
#   'majority',
#   'share',
#   'many',
#   'super',
#   'small',
#   'toilet',
#   'careful',
#   'price',
#   'quote',
#   'online',
#   'add',
#   'tourist',
#   'tax',
#   'represent',
#   'budget',
#   'hotel',
#   'experience',
#   'quality',
#   'definitely',
#   'high',
#   'hostel'],
#  ['hotel',
#   'bad',
#   'cute',
#   'style',
#   'room',
#   'decent',
#   'clean',
#   'linen',
#   'towel',
#   'wifi',
#   'water',
#   'lukewarm',
#   'gorgeous',
#   'location',
#   'pretty',
#   'good',
#   'quiet',
#   'place',
#   'stay',
#   'big',
#   'issue',
#   'put',
#   'room',
#   'night',
#   'room',
#   'occupy',
#   'need',
#   'move',
#   'next',
#   'night',
#   'room',
#   'able',
#   'fit',
#   'bed',
#   'large',
#   'group',
#   'huge',
#   'inconvenience',
#   'plan',
#   'well',
#   'could',
#   'avoid',
#   'otherwise',
#   'pretty',
#   'cute',
#   'place'],
#  ['first',
#   'good',
#   'common',
#   'space',
#   'nice',
#   'enough',
#   'staff_friendly',
#   'bed',
#   'ok',
#   'great',
#   'noise',
#   'shower',
#   'cleanliness',
#   'could',
#   'spend',
#   'little',
#   'add',
#   'fresh',
#   'paint',
#   'curtain',
#   'need',
#   'clean',
#   'place',
#   'old',
#   'run'],
#  ['room',
#   'invite',
#   'relax',
#   'want',
#   'room',
#   'sleep',
#   'fine',
#   'share',
#   'space',
#   'nice',
#   'balcony',
#   'watch',
#   'firework',
#   'amazing',
#   'kind',
#   'although',
#   'mix',
#   'online',
#   'payment',
#   'result',
#   'take',
#   'quetzale',
#   'later',
#   'need',
#   'room',
#   'push',
#   'wall',
#   'quite',
#   'cramped',
#   'even',
#   'couple',
#   'window',
#   'appear',
#   'storage',
#   'area',
#   'cleaning',
#   'supply',
#   'mean',
#   'get',
#   'hear',
#   'lot',
#   'morning',
#   'conversation',
#   'housekeeping',
#   'staff',
#   'hallway',
#   'pretty',
#   'loud',
#   'seem',
#   'room',
#   'exterior',
#   'window',
#   'glad'],
#  ['advertise',
#   'hotel',
#   'euro_maya',
#   'suite',
#   'real',
#   'name',
#   'hotel',
#   'select',
#   'hotel',
#   'due',
#   'nice',
#   'review',
#   'read',
#   'question',
#   'review',
#   'real',
#   'people',
#   'opinion',
#   'service',
#   'kind',
#   'crazy',
#   'standard',
#   'high',
#   'hotel',
#   'website',
#   'picture',
#   'well',
#   'do',
#   'real',
#   'hotel',
#   'totally',
#   'different',
#   'form',
#   'reality',
#   'pay',
#   'dollar',
#   'night',
#   'quetzal',
#   'breakfast_include',
#   'room',
#   'terrible',
#   'poor',
#   'clean',
#   'nasty',
#   'towel',
#   'really',
#   'old',
#   'almost',
#   'useless',
#   'location',
#   'far',
#   'central_square',
#   'convenience',
#   'location',
#   'review',
#   'say',
#   'love',
#   'cultural',
#   'site',
#   'many',
#   'thing',
#   'learn',
#   'colonial',
#   'time'],
#  ['euro_maya',
#   'nice',
#   'small',
#   'hotel',
#   'staff_friendly',
#   'helpful',
#   'room',
#   'clean',
#   'breakfast',
#   'thing',
#   'go',
#   'roof_top',
#   'terrace',
#   'great',
#   'spot',
#   'breakfast',
#   'enjoy',
#   'volcano',
#   'view',
#   'block',
#   'central_park',
#   'look',
#   'posh',
#   'place',
#   'top',
#   'line',
#   'sheet',
#   'towel',
#   'service',
#   'look',
#   'clean',
#   'friendly',
#   'affordable',
#   'place',
#   'lie',
#   'head',
#   'fit',
#   'bill'],
#  ['book',
#   'return',
#   'mainly',
#   'mistakenly',
#   'list',
#   'book',
#   'hotel',
#   'fact',
#   'hotel',
#   'travel_agency',
#   'happen',
#   'rent',
#   'room',
#   'could',
#   'tell',
#   'property',
#   'sign',
#   'location',
#   'superb',
#   'problem',
#   'disgraceful',
#   'service',
#   'begin',
#   'even',
#   'step',
#   'foot',
#   'hotel',
#   'charge',
#   'issue',
#   'get',
#   'lousy',
#   'ask',
#   'arrive',
#   'suppose',
#   'check',
#   'time',
#   'complain',
#   'talk',
#   'policy',
#   'mention',
#   'employee',
#   'suppose',
#   'probably',
#   'could',
#   'hardly',
#   'speak'],
#  ['birthday',
#   'celebration',
#   'book',
#   'hotel',
#   'think',
#   'centrally_locate',
#   'price',
#   'ok',
#   'hotel',
#   'locate',
#   'town',
#   'central',
#   'accessible',
#   'offer',
#   'parking',
#   'blocks_away',
#   'bad',
#   'thing',
#   'hotel',
#   'locate',
#   'next',
#   'alliance',
#   'weekend',
#   'stay',
#   'concert',
#   'bad',
#   'concert',
#   'last',
#   'ask',
#   'watchman',
#   'call',
#   'police',
#   'aware',
#   'pm',
#   'manager',
#   'leave',
#   'close',
#   'door',
#   'assist',
#   'also',
#   'establishment',
#   'sure',
#   'bar',
#   'restaurant',
#   'hotel',
#   'group',
#   'noisy',
#   'people',
#   'come',
#   'go',
#   'night',
#   'long',
#   'sleep',
#   'horrible'],
#  ['stay',
#   'first',
#   'hotel',
#   'full',
#   'last_night',
#   'stay',
#   'place',
#   'sorry',
#   'state',
#   'disrepair',
#   'look',
#   'unloved',
#   'room',
#   'general',
#   'appearance',
#   'bite',
#   'shabby',
#   'one',
#   'hotel',
#   'entire',
#   'town',
#   'full',
#   'big',
#   'event',
#   'service',
#   'obvious',
#   'place',
#   'seem',
#   'spooky',
#   'luckily',
#   'good',
#   'conscience',
#   'can',
#   'recommend'],
#  ['hotel',
#   'room',
#   'nice',
#   'wife',
#   'get',
#   'room',
#   'thing',
#   'bathroom',
#   'really',
#   'small',
#   'flush',
#   'toilet',
#   'water_pressure',
#   'super',
#   'super',
#   'slow',
#   'bathroom',
#   'toilet',
#   'really',
#   'small',
#   'nee',
#   'leave',
#   'use',
#   'really',
#   'important',
#   'party',
#   'super',
#   'cool',
#   'door',
#   'lot',
#   'people',
#   'visit',
#   'socialize',
#   'sleep',
#   'early',
#   'energize',
#   'tour',
#   'good',
#   'place',
#   'stay',
#   'noise',
#   'end',
#   'costumer',
#   'service',
#   'really',
#   'amazing',
#   'really',
#   'enjoy',
#   'service'],
#  ['stayed_night',
#   'hotel',
#   'could',
#   'sleep',
#   'staff_friendly',
#   'unfortunately',
#   'complain',
#   'noise',
#   'clock',
#   'evening',
#   'noise',
#   'movement',
#   'room',
#   'also',
#   'unlucky',
#   'client',
#   'hotel',
#   'care',
#   'client',
#   'want',
#   'sleep',
#   'recommend',
#   'hotel',
#   'want',
#   'peace',
#   'quiet'],
#  ['first',
#   'positive',
#   'hotel',
#   'look',
#   'great',
#   'ground',
#   'credit',
#   'team',
#   'responsible',
#   'location',
#   'restaurant',
#   'overlook',
#   'active',
#   'volcano',
#   'spectacular',
#   'imagine',
#   'dinner',
#   'backdrop',
#   'lava',
#   'spout',
#   'volcano',
#   'probably',
#   'daily',
#   'event',
#   'lucky',
#   'hotel',
#   'however',
#   'well',
#   'let',
#   'room',
#   'clean',
#   'lack_air',
#   'would',
#   'therefore',
#   'expect',
#   'able',
#   'ventilate',
#   'open',
#   'window',
#   'insect',
#   'screen',
#   'sensible',
#   'result',
#   'stuffy',
#   'room',
#   'room',
#   'also',
#   'room',
#   'safe',
#   'guest',
#   'place',
#   'valuable',
#   'security',
#   'box',
#   'reception',
#   'traveller',
#   'carry',
#   'tablet',
#   'laptop',
#   'camera',
#   'phone',
#   'suitable',
#   'practical',
#   'really',
#   'good',
#   'enough'],
#  ['lovely',
#   'position',
#   'nice',
#   'room',
#   'glad',
#   'courtyard',
#   'people',
#   'breakfast',
#   'right_outside',
#   'bedroom',
#   'window',
#   'sad',
#   'poor',
#   'attitude',
#   'staff',
#   'water',
#   'ration',
#   'attempt',
#   'offer',
#   'filtered_water',
#   'tea',
#   'service',
#   'room',
#   'morning',
#   'tea',
#   'fine',
#   'undrinkable',
#   'manager',
#   'provide',
#   'maybe',
#   'lack',
#   'also',
#   'good',
#   'enough',
#   'way',
#   'charge',
#   'effort',
#   'make',
#   'resolve',
#   'problem',
#   'plastic',
#   'flower',
#   'petal',
#   'towel',
#   'really',
#   'bother',
#   'turn',
#   'service',
#   'dirty',
#   'towel',
#   'cup',
#   'leave',
#   'night',
#   'would',
#   'call',
#   'average',
#   'hotel',
#   'label'],
#  ['stay',
#   'book',
#   'pay',
#   'cash',
#   'check',
#   'month',
#   'later',
#   'notice',
#   'charge',
#   'visa',
#   'card',
#   'well',
#   'refuse',
#   'refund',
#   'many',
#   'better_option',
#   'well',
#   'price',
#   'steer',
#   'clear'],
#  ['provide',
#   'bed',
#   'average',
#   'price',
#   'location',
#   'rather',
#   'decent',
#   'want',
#   'rather',
#   'problem',
#   'cold',
#   'night',
#   'quite',
#   'strong',
#   'smell',
#   'disinfectant',
#   'time',
#   'least',
#   'tell',
#   'cleaning',
#   'occur',
#   'little',
#   'way',
#   'social',
#   'atmosphere',
#   'certainly',
#   'lack',
#   'kind',
#   'usefulness',
#   'warmth',
#   'staff',
#   'friendly',
#   'knowledgeable',
#   'town',
#   'transport',
#   'importantly',
#   'stay',
#   'begin',
#   'suffer',
#   'virus',
#   'hostel',
#   'fault',
#   'concern',
#   'bed',
#   'several',
#   'day',
#   'moan',
#   'look',
#   'dreadful',
#   'staff',
#   'walk',
#   'past',
#   'unconcerned',
#   'would',
#   'value',
#   'social',
#   'responsibility'],
#  ['arrive',
#   'reserve',
#   'advance',
#   'room',
#   'show',
#   'picture',
#   'even',
#   'window',
#   'place',
#   'dirty',
#   'smell',
#   'damp',
#   'staff',
#   'insist',
#   'pay',
#   'full',
#   'amount',
#   'offer',
#   'use',
#   'try',
#   'resolve',
#   'problem',
#   'terrible',
#   'room',
#   'terrible',
#   'customer_service'],
#  ['stay',
#   'three_night',
#   'unfortunately',
#   'room',
#   'small',
#   'appear',
#   'picture',
#   'stuffy',
#   'air',
#   'keep',
#   'staircase',
#   'staff_friendly',
#   'enough',
#   'seem',
#   'bit',
#   'work',
#   'often',
#   'let',
#   'night',
#   'ring',
#   'clean',
#   'enough',
#   'decent',
#   'location',
#   'decent',
#   'shower',
#   'pretty',
#   'nice',
#   'upstairs',
#   'courtyard',
#   'place',
#   'offer',
#   'well',
#   'value_money',
#   'elsewhere'],
#  ['receptionist',
#   'provide',
#   'little',
#   'information',
#   'detail',
#   'hotel',
#   'prompt',
#   'room',
#   'clean',
#   'hear',
#   'may',
#   'make',
#   'noise',
#   'fan',
#   'hot',
#   'hot',
#   'breakfast_include',
#   'rate',
#   'say',
#   'hotel',
#   'confirmation',
#   'ask',
#   'staff',
#   'really',
#   'problem',
#   'meh',
#   'would',
#   'probably',
#   'next',
#   'time',
#   'deserve',
#   'well',
#   'experience'],
#  ['room',
#   'small',
#   'box',
#   'ventilation',
#   'even',
#   'fan',
#   'get',
#   'tiny',
#   'courtyard',
#   'view',
#   'shower',
#   'get',
#   'turn',
#   'water',
#   'periodically',
#   'night',
#   'say',
#   'staff',
#   'generally',
#   'nice',
#   'good',
#   'make',
#   'stay',
#   'pleasant',
#   'evening',
#   'flight',
#   'staff',
#   'keep',
#   'bag',
#   'hotel',
#   'checkout',
#   'luxury',
#   'place',
#   'decent',
#   'location',
#   'need',
#   'place',
#   'crash',
#   'may',
#   'ok',
#   'visit',
#   'thankfully',
#   'cold',
#   'night',
#   'imagine',
#   'would',
#   'impossible_sleep',
#   'temperature',
#   'hotter'],
#  ['people',
#   'nice',
#   'desk',
#   'get',
#   'fool',
#   'picture',
#   'window',
#   'window',
#   'give',
#   'hallway',
#   'noisy',
#   'lack',
#   'lousy',
#   'internet',
#   'bad',
#   'location',
#   'good',
#   'repeat'],
#  ['price',
#   'decent',
#   'value',
#   'screen',
#   'mosquiro',
#   'wake',
#   'night',
#   'onsite',
#   'bar',
#   'room',
#   'noisy',
#   'fan',
#   'room',
#   'turn',
#   'drip',
#   'night',
#   'stay',
#   'never'],
#  ['nice',
#   'decoration',
#   'terrace',
#   'overcharge',
#   'convert',
#   'price',
#   'currency',
#   'push',
#   'consume',
#   'difference',
#   'hotel',
#   'service',
#   'poor',
#   'price',
#   'pay',
#   'give_us',
#   'towel',
#   'clean',
#   'table',
#   'breakfast',
#   'also',
#   'book',
#   'morning',
#   'really',
#   'unfriendly',
#   'make',
#   'feel',
#   'unwelcome',
#   'would',
#   'never',
#   'come_back',
#   'place',
#   'money',
#   'pay',
#   'good',
#   'hostel',
#   'sure',
#   'attend',
#   'well'],
#  ['locate',
#   'site',
#   'middle',
#   'restaurant',
#   'shop',
#   'bar',
#   'view',
#   'balcony',
#   'breathtake',
#   'complaint',
#   'breakfast',
#   'fry',
#   'egg',
#   'toast',
#   'bean',
#   'think',
#   'well',
#   'even',
#   'guest',
#   'pay'],
#  ['nice',
#   'decor',
#   'breakfast_include',
#   'courtyard',
#   'sit',
#   'blanket',
#   'ask',
#   'little',
#   'wifi',
#   'drop',
#   'stay',
#   'room',
#   'reception',
#   'busy',
#   'road',
#   'bus',
#   'lorry',
#   'wake'],
#  ['room',
#   'small',
#   'clean',
#   'dusty',
#   'bed',
#   'uncomfortable',
#   'hardly',
#   'shower'],
#  ['pretty',
#   'really',
#   'cute',
#   'spacious',
#   'room',
#   'staff',
#   'nice',
#   'hotel',
#   'safe',
#   'quiet',
#   'downside',
#   'central',
#   'area',
#   'day',
#   'recommend',
#   'walk',
#   'night',
#   'plan',
#   'late',
#   'evening',
#   'recommend_staye',
#   'little',
#   'close',
#   'central',
#   'area',
#   'close',
#   'really',
#   'loud',
#   'even'],
#  ['book',
#   'afterwards',
#   'find',
#   'hotel',
#   'much',
#   'low',
#   'rate',
#   'expedia',
#   'would',
#   'cancel',
#   'first',
#   'hotel',
#   'room',
#   'show',
#   'extraordinary',
#   'usd_p',
#   'day',
#   'dark',
#   'dingy',
#   'bath',
#   'view',
#   'express',
#   'dismay',
#   'price',
#   'offer',
#   'move',
#   'upstairs',
#   'nice',
#   'room',
#   'breakfast',
#   'consist',
#   'coffee',
#   'toast',
#   'egg',
#   'refrie',
#   'bean',
#   'little_bit',
#   'cheese',
#   'complain',
#   'lack',
#   'fruit',
#   'monotony',
#   'menu',
#   'daily',
#   'arrive',
#   'take'],
#  ['say',
#   'hotel',
#   'nice',
#   'breakfast',
#   'splendid',
#   'view',
#   'terrace',
#   'unfortunately',
#   'room',
#   'one',
#   'wait',
#   'standard',
#   'room',
#   'book',
#   'tiny',
#   'sqm',
#   'advertise',
#   'sqm',
#   'suite',
#   'book',
#   'double',
#   'price',
#   'normal',
#   'room',
#   'sure',
#   'separate',
#   'bed',
#   'advertise',
#   'booking',
#   'site',
#   'separate',
#   'bed',
#   'suite',
#   'consider',
#   'public',
#   'seating',
#   'place',
#   'part',
#   'room',
#   'indeed',
#   'arriving_late',
#   'hotel',
#   'reason',
#   'give_us',
#   'leftover',
#   'book',
#   'month',
#   'advance'],
#  ['pro',
#   'friendly',
#   'staff',
#   'good',
#   'price',
#   'con',
#   'room',
#   'street',
#   'noisy',
#   'bring',
#   'sleep',
#   'medication',
#   'noise',
#   'continue',
#   'midnight',
#   'start',
#   'also',
#   'able',
#   'hear_people',
#   'room',
#   'breakfast',
#   'morning',
#   'toast',
#   'jam',
#   'fruit',
#   'next_morning',
#   'egg',
#   'fruit',
#   'third',
#   'morning',
#   'decide',
#   'go',
#   'restaurant',
#   'substantial',
#   'breakfast',
#   'give',
#   'coffee',
#   'produce',
#   'country',
#   'expect',
#   'good',
#   'coffee',
#   'morning',
#   'bad',
#   'coffee',
#   'ever',
#   'watery',
#   'weak'],
#  ['location',
#   'hotel',
#   'staff',
#   'make',
#   'feel',
#   'welcome',
#   'breakfast',
#   'nice',
#   'breakfast',
#   'fresh',
#   'fruit',
#   'room',
#   'spacious',
#   'dislike',
#   'super',
#   'thin_wall',
#   'hear',
#   'everything_goe',
#   'include',
#   'extracurricular',
#   'activity',
#   'include',
#   'music',
#   'could',
#   'provide',
#   'face',
#   'towel',
#   'verdict',
#   'hotel',
#   'get',
#   'endorsement',
#   'location',
#   'price',
#   'however',
#   'mindful',
#   'super',
#   'thin',
#   'paper',
#   'wall',
#   'hear',
#   'thing',
#   'want',
#   'hear'],
#  ['good',
#   'pool',
#   'nice',
#   'room',
#   'mattress',
#   'room',
#   'terrible',
#   'room',
#   'number',
#   'wor',
#   'thing',
#   'small',
#   'hotel',
#   'service',
#   'people',
#   'rude',
#   'even',
#   'look',
#   'face',
#   'never',
#   'ever',
#   'say',
#   'good',
#   'morning',
#   'incredible',
#   'small',
#   'hotel',
#   'can',
#   'train',
#   'employee',
#   'properly',
#   'hard',
#   'say',
#   'good',
#   'morning',
#   'never',
#   'back'],
#  ['somewhere',
#   'online',
#   'first',
#   'sure',
#   'last',
#   'time',
#   'check',
#   'write',
#   'already',
#   'hotel',
#   'massively',
#   'loud',
#   'fairness',
#   'ridiculous',
#   'loud',
#   'apart',
#   'standard',
#   'room',
#   'tiny',
#   'wardrobe',
#   'replace',
#   'toilet',
#   'shower',
#   'aware'],
#  ['staff',
#   'wonderful',
#   'girl',
#   'desk',
#   'could',
#   'helpful',
#   'horribly',
#   'noisy',
#   'place',
#   'stay',
#   'intermittent',
#   'machinery',
#   'noise',
#   'night',
#   'due',
#   'courtyard',
#   'also',
#   'room',
#   'courtyard_garden',
#   'people',
#   'sit',
#   'talk',
#   'noisy',
#   'night',
#   'room',
#   'nice',
#   'seem',
#   'better_place',
#   'stay'],
#  ['plus_side',
#   'hotel',
#   'conveniently_locate',
#   'many',
#   'business',
#   'around',
#   'keep',
#   'clean',
#   'employee',
#   'try',
#   'make',
#   'feel',
#   'good',
#   'negative',
#   'side',
#   'room',
#   'pack',
#   'small',
#   'location',
#   'easily',
#   'hear',
#   'outside',
#   'noise',
#   'night',
#   'get',
#   'late',
#   'listen',
#   'say',
#   'coffee',
#   'maker',
#   'room',
#   'keep',
#   'make',
#   'noise',
#   'night',
#   'recommend',
#   'place'],
#  ['room',
#   'really',
#   'small',
#   'lady',
#   'really',
#   'rude',
#   'family',
#   'good',
#   'think',
#   'boy',
#   'stay',
#   'night',
#   'rest',
#   'enjoy',
#   'time'],
#  ['always',
#   'come',
#   'hotel',
#   'day',
#   'service',
#   'change',
#   'alot',
#   'feel',
#   'welcome',
#   'price',
#   'change',
#   'well',
#   'month',
#   'thing',
#   'make',
#   'sence',
#   'room',
#   'people',
#   'room',
#   'people',
#   'choice'],
#  ['bad',
#   'definitely',
#   'top',
#   'notch',
#   'entire',
#   'week',
#   'free_wifi',
#   'terrible',
#   'often',
#   'cut',
#   'weak',
#   'signal',
#   'bed',
#   'ask',
#   'extra',
#   'pillow',
#   'say',
#   'thin_hear',
#   'neighbor',
#   'talk',
#   'sneeze',
#   'use',
#   'restroom',
#   'place',
#   'price',
#   'high',
#   'quality',
#   'staff',
#   'always',
#   'friendly',
#   'stay'],
#  ['room',
#   'room',
#   'large',
#   'bathroom',
#   'bed',
#   'firm',
#   'room',
#   'dark',
#   'comfortable',
#   'fridge',
#   'mini',
#   'bar',
#   'kettle',
#   'make',
#   'staff_friendly',
#   'helpful',
#   'especially',
#   'work',
#   'restaurant',
#   'give',
#   'exceptional',
#   'service',
#   'breakfast_include',
#   'stay',
#   'standard',
#   'victor',
#   'really',
#   'great',
#   'try',
#   'restaurant',
#   'food',
#   'average',
#   'room',
#   'overlook',
#   'beautiful',
#   'garden',
#   'ground',
#   'room',
#   'clean',
#   'room',
#   'story',
#   'walk',
#   'early_morne'],
#  ['cute',
#   'charming',
#   'staff',
#   'kind',
#   'professional',
#   'helpful',
#   'perk',
#   'hotel',
#   'breakfast_include',
#   'use',
#   'amenity',
#   'hotel',
#   'stay',
#   'daughter',
#   'upper',
#   'terrace',
#   'room',
#   'sadly',
#   'rough',
#   'night',
#   'sleep',
#   'noise',
#   'street',
#   'notify',
#   'beforehand',
#   'receptionist',
#   'agree',
#   'noisy',
#   'room',
#   'complaint',
#   'common',
#   'disappointed',
#   'value',
#   'room',
#   'lack',
#   'rest',
#   'perhaps',
#   'stay',
#   'room',
#   'bottom',
#   'floor',
#   'back',
#   'would',
#   'pleasant',
#   'experience'],
#  ['last_night',
#   'try',
#   'come',
#   'assume',
#   'drunk',
#   'get',
#   'room',
#   'girl',
#   'touch',
#   'inappropriately',
#   'ask',
#   'leave',
#   'minute',
#   'try',
#   'come',
#   'back',
#   'additional',
#   'guy',
#   'get',
#   'room',
#   'eventually',
#   'give',
#   'horrible',
#   'experience',
#   'specially',
#   'overnight',
#   'guard'],
#  ['arrive',
#   'hotel',
#   'early',
#   'start',
#   'long',
#   'travel',
#   'tell',
#   'immediately',
#   'room',
#   'due',
#   'overbooking',
#   'room',
#   'reserve',
#   'pay',
#   'full',
#   'least',
#   'month',
#   'previous',
#   'tell',
#   'upgrade',
#   'property',
#   'euro_maya',
#   'suite',
#   'room',
#   'nicer',
#   'apparently',
#   'quick',
#   'check',
#   'online',
#   'find',
#   'stay',
#   'euro_maya',
#   'suite',
#   'indeed',
#   'little_bit',
#   'expensive',
#   'reason',
#   'book',
#   'euro_maya',
#   'location',
#   'rooftop_terrace',
#   'girl_reception',
#   'nice',
#   'small',
#   'discount',
#   'excursion',
#   'room',
#   'suite',
#   'lovely',
#   'room',
#   'great',
#   'time'],
#  ['stayed_night',
#   'change',
#   'book',
#   'apparently',
#   'issue',
#   'room',
#   'other',
#   'available',
#   'move',
#   'nice',
#   'spacious',
#   'triple',
#   'room',
#   'double',
#   'single',
#   'fan',
#   'evening',
#   'fan',
#   'adequate',
#   'room',
#   'get',
#   'quite',
#   'stuffy',
#   'open',
#   'window',
#   'whenever',
#   'room',
#   'air',
#   'shower',
#   'would',
#   'quickly',
#   'lose',
#   'still',
#   'good',
#   'pressure',
#   'various',
#   'receptionist',
#   'see',
#   'night',
#   'speak',
#   'little',
#   'luckily',
#   'really',
#   'nee',
#   'speak',
#   'much',
#   'breakfast_include',
#   'head',
#   'food',
#   'slow',
#   'occasionally'],
#  ['pro',
#   'fantastic',
#   'location',
#   'nice',
#   'courtyard',
#   'kitchen',
#   'great',
#   'could',
#   'make',
#   'breakfast',
#   'con',
#   'unfortunately',
#   'none',
#   'really',
#   'matter',
#   'wall',
#   'hotel',
#   'room',
#   'thin',
#   'barely',
#   'sleep',
#   'guest',
#   'hotel',
#   'night',
#   'clearly',
#   'impossible',
#   'awoken',
#   'finally_got',
#   'quiet',
#   'noise',
#   'start',
#   'guest',
#   'wake',
#   'presumably',
#   'early_morne',
#   'pick',
#   'up',
#   'hike',
#   'expensive',
#   'fail',
#   'provide',
#   'decent',
#   'sleep',
#   'addition',
#   'wifi',
#   'really',
#   'poor',
#   'time',
#   'finally',
#   'provide',
#   'free_coffee',
#   'coffee',
#   'rubbish',
#   'cup',
#   'taste',
#   'chlorine',
#   'small',
#   'thing',
#   'generally',
#   'really',
#   'disappointing'],
#  ['stay',
#   'week',
#   'solo',
#   'female',
#   'traveler',
#   'positive',
#   'hotel',
#   'apartment',
#   'photo',
#   'nice',
#   'look',
#   'cozy',
#   'housekeeping',
#   'good',
#   'never',
#   'come',
#   'say',
#   'come',
#   'security',
#   'beds_comfortable',
#   'good',
#   'safe',
#   'room',
#   'great',
#   'sure',
#   'could',
#   'fit',
#   'full',
#   'sized',
#   'lap',
#   'top',
#   'pad',
#   'perfect',
#   'wireless',
#   'access',
#   'pretty',
#   'reliable',
#   'even',
#   'lose',
#   'access',
#   'quickly',
#   'negative',
#   'noisy',
#   'side',
#   'okay',
#   'otherwise',
#   'hear_everythe',
#   'several_time',
#   'people',
#   'party',
#   'quite',
#   'loudly',
#   'go',
#   'speak',
#   'speak',
#   'tenant',
#   'change'],
#  ['second',
#   'time',
#   'come',
#   'back',
#   'recent',
#   'experience',
#   'hotel',
#   'barely',
#   'space',
#   'bag',
#   'book',
#   'triple',
#   'room',
#   'book',
#   'room',
#   'price',
#   'dollar',
#   'night',
#   'eve',
#   'good_location',
#   'many_restaurant',
#   'friendly',
#   'staff',
#   'however',
#   'try',
#   'good',
#   'understand',
#   'room',
#   'upper',
#   'floor',
#   'housekeeping',
#   'room',
#   'night',
#   'hear',
#   'laundry',
#   'machine',
#   'turn',
#   'bother',
#   'good',
#   'sleeper',
#   'room',
#   'mold',
#   'ceile',
#   'good',
#   'free_wifi',
#   'bathroom',
#   'small',
#   'clean',
#   'difficult',
#   'regulate',
#   'shower',
#   'airport',
#   'pick',
#   'book'],
#  ['secure',
#   'centrally_locate',
#   'beds_comfortable',
#   'cleanliness',
#   'sheet',
#   'questionable',
#   'stain',
#   'hair',
#   'window',
#   'room',
#   'look',
#   'garden',
#   'common',
#   'space',
#   'airflow',
#   'room',
#   'limited',
#   'fan',
#   'provide',
#   'water_pressure',
#   'good',
#   'day',
#   'next_day',
#   'run',
#   'water',
#   'sure',
#   'freak',
#   'accident',
#   'common',
#   'occurrence',
#   'hour',
#   'job',
#   'memorable'],
#  ['share',
#   'room',
#   'bed',
#   'clean',
#   'basic',
#   'bathroom',
#   'tight',
#   'fit',
#   'mirror',
#   'turn',
#   'pressure',
#   'high',
#   'staff',
#   'kind',
#   'accommodate',
#   'ask',
#   'move',
#   'room',
#   'downstairs',
#   'carry',
#   'luggage',
#   'narrow',
#   'stair',
#   'enough',
#   'place',
#   'eat',
#   'shop',
#   'great',
#   'walking',
#   'everywhere'],
#  ['bad',
#   'allow',
#   'audio',
#   'upload',
#   'review',
#   'owner',
#   'place',
#   'make',
#   'much',
#   'noise',
#   'night',
#   'talk',
#   'loud',
#   'courtyard',
#   'listen',
#   'want',
#   'good',
#   'night',
#   'rest',
#   'look'],
#  ['big',
#   'disappointment',
#   'see',
#   'room',
#   'think',
#   'nice',
#   'close',
#   'inspection',
#   'soon',
#   'realise',
#   'place',
#   'dirty',
#   'hotel',
#   'make',
#   'look',
#   'nice',
#   'painting',
#   'wall',
#   'add',
#   'mood',
#   'light',
#   'nice',
#   'design',
#   'bed',
#   'sheet',
#   'take',
#   'nice',
#   'photo',
#   'see',
#   'fb',
#   'page',
#   'reality',
#   'room',
#   'dirty',
#   'looked_like',
#   'floor',
#   'clean',
#   'long_time',
#   'bathroom',
#   'also',
#   'bad',
#   'eventually',
#   'bite',
#   'warm',
#   'still',
#   'freeze',
#   'shower',
#   'also',
#   'noisy',
#   'main',
#   'street',
#   'room',
#   'furthest',
#   'away',
#   'talk',
#   'reception',
#   'noise',
#   'amplify',
#   'design',
#   'hotel',
#   'door',
#   'come',
#   'back',
#   'late',
#   'hear',
#   'loudly',
#   'corner'],
#  ['pro',
#   'beautiful',
#   'hotel',
#   'contra',
#   'horrible',
#   'check',
#   'experience',
#   'inflexible',
#   'policy',
#   'inform',
#   'arrival',
#   'solve',
#   'problem',
#   'hotel',
#   'beautiful',
#   'keep',
#   'mind',
#   'problem',
#   'nightmare',
#   'try',
#   'solve'],
#  ['large',
#   'clean',
#   'room',
#   'room',
#   'side',
#   'colorful',
#   'courtyard',
#   'lobby',
#   'staff',
#   'carry',
#   'luggage',
#   'hotel',
#   'garden',
#   'full',
#   'plant',
#   'flower',
#   'well',
#   'arrange',
#   'regular',
#   'breakfast',
#   'waiter',
#   'service',
#   'need',
#   'improvement'],
#  ['hard',
#   'wife',
#   'take',
#   'could',
#   'sleep',
#   'hard',
#   'double',
#   'lucky',
#   'endure',
#   'multiple',
#   'bed',
#   'bug',
#   'bite',
#   'get',
#   'away',
#   'still',
#   'itch',
#   'write',
#   'promise',
#   'room',
#   'size',
#   'thimble',
#   'great',
#   'staff',
#   'sort',
#   'next_day',
#   'thank',
#   'roof_top',
#   'great',
#   'breakfast',
#   'kitchen',
#   'good',
#   'basic',
#   'meal',
#   'good',
#   'price'],
#  ['overall',
#   'hotel',
#   'nice',
#   'service',
#   'great',
#   'however',
#   'want',
#   'iin',
#   'room',
#   'right',
#   'courtyard',
#   'use',
#   'breakfast',
#   'set',
#   'start',
#   'also',
#   'visitor',
#   'arrive',
#   'leave',
#   'night',
#   'wake',
#   'also',
#   'room',
#   'window',
#   'hotel',
#   'toilet',
#   'open',
#   'bathroom',
#   'noise',
#   'use',
#   'overnight',
#   'finally',
#   'live',
#   'rock',
#   'band',
#   'play',
#   'pub',
#   'effectively',
#   'side',
#   'wall',
#   'room',
#   'ask',
#   'move',
#   'tell',
#   'suitable',
#   'room',
#   'available',
#   'clearly',
#   'untrue',
#   'saw',
#   'room',
#   'come',
#   'go',
#   'suitable',
#   'quite',
#   'location',
#   'hotel',
#   'say',
#   'room'],
#  ['made_reservation',
#   'location',
#   'list',
#   'locate',
#   'arrive',
#   'gentleman',
#   'tell',
#   'driver',
#   'take',
#   'location',
#   'decent',
#   'location',
#   'bathroom',
#   'nice',
#   'breakfast',
#   'good',
#   'well',
#   'comfortable',
#   'frustration',
#   'location',
#   'want',
#   'center',
#   'charming'],
#  ['confusion',
#   'get',
#   'think',
#   'book',
#   'euro_maya',
#   'suite',
#   'end',
#   'location',
#   'call',
#   'confirm',
#   'fine',
#   'room',
#   'pretty',
#   'cramped',
#   'big',
#   'issue',
#   'ac',
#   'also',
#   'overhead',
#   'fan',
#   'hotel',
#   'fan',
#   'bring',
#   'stuff',
#   'even',
#   'leave',
#   'breeze',
#   'really',
#   'stuffy',
#   'nice',
#   'breakfast',
#   'roof',
#   'breakfast',
#   'super',
#   'plentiful',
#   'serve',
#   'lovely',
#   'staff',
#   'location',
#   'top'],
#  ['gorgeous',
#   'spacious',
#   'room',
#   'nice',
#   'breakfast_include',
#   'day',
#   'complimentary',
#   'coffee_tea',
#   'purify',
#   'water',
#   'convenient',
#   'centrally_locate',
#   'unfortunately',
#   'shower',
#   'water',
#   'cold',
#   'let',
#   'know',
#   'plan',
#   'return',
#   'late_night',
#   'lock',
#   'use',
#   'door',
#   'call',
#   'exhaust',
#   'find',
#   'alternate',
#   'accommodation',
#   'middle_night',
#   'explain',
#   'staff',
#   'next_morne',
#   'refund',
#   'fee',
#   'night'],
#  ['night',
#   'way',
#   'service',
#   'trip',
#   'location_close',
#   'market',
#   'square',
#   'concrete',
#   'design',
#   'wall',
#   'noise',
#   'would',
#   'travel',
#   'stairwell',
#   'night',
#   'long',
#   'lot',
#   'stay',
#   'seam',
#   'care',
#   'hot',
#   'much',
#   'noise',
#   'make',
#   'night',
#   'long',
#   'room',
#   'sparsely',
#   'decorate',
#   'could',
#   'use',
#   'upgrade',
#   'bed',
#   'bedding',
#   'pillow',
#   'public',
#   'area',
#   'pretty',
#   'wifi',
#   'work',
#   'room',
#   'area',
#   'stay'],
#  ['spend',
#   'would',
#   'return',
#   'downstairs',
#   'room',
#   'subject',
#   'noisy',
#   'chatter',
#   'patron',
#   'night',
#   'long',
#   'even',
#   'early_morne',
#   'charge',
#   'wifi',
#   'water',
#   'positive',
#   'supermarket',
#   'door',
#   'room',
#   'clean',
#   'spend',
#   'double',
#   'room',
#   'need'],
#  ['stay',
#   'property',
#   'night',
#   'big',
#   'mistake',
#   'old',
#   'place',
#   'dump',
#   'waste',
#   'money',
#   'bed',
#   'hard',
#   'nee',
#   'see',
#   'doctor',
#   'back',
#   'pain',
#   'trust',
#   'really',
#   'bad',
#   'old',
#   'towel',
#   'loud',
#   'night',
#   'bar',
#   'noise',
#   'stop',
#   'shower',
#   'old',
#   'sink',
#   'come',
#   'apart',
#   'old',
#   'pillow'],
#  ['month',
#   'work',
#   'leisure',
#   'stay',
#   'several',
#   'always',
#   'pleased',
#   'staff',
#   'service',
#   'accommodation',
#   'area',
#   'hotel',
#   'worst',
#   'stay',
#   'far',
#   'price_range',
#   'receptionist',
#   'accommodate',
#   'slightly',
#   'rude',
#   'definitely',
#   'friendly',
#   'personable',
#   'staff',
#   'act',
#   'know',
#   'time',
#   'stay',
#   'politely',
#   'ask',
#   'possible',
#   'change',
#   'room',
#   'first_night',
#   'room',
#   'locate',
#   'reception',
#   'desk',
#   'noisy',
#   'loud',
#   'people',
#   'check',
#   'day',
#   'night',
#   'could',
#   'sleep',
#   'first',
#   'room',
#   'comfortable'],
#  ['break',
#   'room',
#   'steal',
#   'cash',
#   'expensive',
#   'sunglass',
#   'staff',
#   'want',
#   'help',
#   'reluctant',
#   'inquire',
#   'staff',
#   'customer',
#   'incident',
#   'call',
#   'police',
#   'staff',
#   'actually',
#   'try',
#   'imply',
#   'lose',
#   'item',
#   'lock',
#   'door',
#   'fabricate',
#   'incident',
#   'lack',
#   'assistance',
#   'bad',
#   'invasion',
#   'privacy',
#   'particularly',
#   'young',
#   'solo',
#   'female',
#   'traveller',
#   'hotel',
#   'actually',
#   'large',
#   'house',
#   'room',
#   'rent',
#   'tell',
#   'else',
#   'room',
#   'staff',
#   'later',
#   'admit',
#   'owner',
#   'key',
#   'local',
#   'authority',
#   'tourism',
#   'police',
#   'helpful'],
#  ['room',
#   'clean',
#   'nice',
#   'however',
#   'walk',
#   'kitchen',
#   'get',
#   'shower',
#   'also',
#   'family',
#   'daily',
#   'live',
#   'believe',
#   'always',
#   'kitchen',
#   'also',
#   'reception',
#   'keep',
#   'people',
#   'child',
#   'talking_loudly',
#   'night',
#   'pm',
#   'family',
#   'feel',
#   'hotel',
#   'also',
#   'kitchen',
#   'fridge',
#   'clean',
#   'staff',
#   'owner',
#   'friendly',
#   'also',
#   'advertise',
#   'quite',
#   'distance',
#   'central',
#   'least',
#   'much',
#   'close',
#   'would',
#   'stay'],
#  ['good_location',
#   'check',
#   'clerk',
#   'show',
#   'old',
#   'rip',
#   'hand',
#   'towel',
#   'say',
#   'find',
#   'room',
#   'must',
#   'pay',
#   'rip',
#   'towel',
#   'charge',
#   'anyway',
#   'stay'],
#  ['stay',
#   'night',
#   'hotel',
#   'room',
#   'twin',
#   'bed',
#   'room',
#   'change',
#   'room',
#   'nice',
#   'little_bit',
#   'hard',
#   'regulate',
#   'shower',
#   'first_night',
#   'quiet',
#   'second_night',
#   'big',
#   'group',
#   'volunteer',
#   'stay',
#   'hotel',
#   'make',
#   'early_morne',
#   'location',
#   'hotel',
#   'good',
#   'central_park'],
#  ['really',
#   'clean',
#   'hotel',
#   'smell',
#   'bad',
#   'noisy',
#   'night',
#   'quite',
#   'close',
#   'guardian',
#   'friendly',
#   'price',
#   'possible',
#   'find',
#   'much_better',
#   'address'],
#  ['outside',
#   'town',
#   'mean',
#   'large',
#   'coach',
#   'stop',
#   'group',
#   'night',
#   'whole',
#   'quiet',
#   'sleep',
#   'town',
#   'also',
#   'cater',
#   'function',
#   'evening',
#   'disturbed',
#   'band',
#   'quite',
#   'late_night',
#   'add',
#   'tour',
#   'group',
#   'arrive',
#   'depart',
#   'nighttime',
#   'hour',
#   'voice',
#   'suitcase',
#   'bump',
#   'cobble',
#   'reverberate',
#   'complex',
#   'always',
#   'make',
#   'peaceful',
#   'sleep',
#   'look',
#   'ok',
#   'surface',
#   'tastefully',
#   'do',
#   'old',
#   'colonial',
#   'town',
#   'nice',
#   'area',
#   'lack',
#   'charm',
#   'personality',
#   'staff',
#   'particularly',
#   'friendly',
#   'room',
#   'rather',
#   'date',
#   'certainly',
#   'one',
#   'smell',
#   'damp',
#   'need',
#   'air',
#   'bed'],
#  ['end',
#   'awake',
#   'sound',
#   'room',
#   'alarm',
#   'noisy',
#   'guest',
#   'check',
#   'room',
#   'sound',
#   'control',
#   'poor',
#   'ventilation',
#   'get',
#   'quite',
#   'warm',
#   'vent',
#   'bed',
#   'squeaky',
#   'confortable',
#   'bathroom',
#   'horribly',
#   'decorate',
#   'overall',
#   'price',
#   'usd',
#   'sure',
#   'well',
#   'choice'],
#  ['lovely',
#   'grear',
#   'coffee',
#   'first',
#   'room',
#   'get',
#   'give',
#   'absolutely',
#   'stong',
#   'chemical',
#   'smell',
#   'imagine',
#   'floor',
#   'cleaner',
#   'ask',
#   'move',
#   'minute',
#   'make',
#   'nauseous',
#   'next',
#   'room',
#   'also',
#   'smell',
#   'old',
#   'run',
#   'road',
#   'noise',
#   'loud',
#   'mattress',
#   'mattress',
#   'protector',
#   'thin',
#   'fitted',
#   'sheet',
#   'go',
#   'straight',
#   'matress',
#   'gross',
#   'thumb'],
#  ['conveniently_locate',
#   'block',
#   'first',
#   'time',
#   'visit',
#   'select',
#   'mainly',
#   'basis',
#   'review',
#   'retrospect',
#   'may',
#   'safe',
#   'stay',
#   'night',
#   'give',
#   'location',
#   'search',
#   'alternative',
#   'meet',
#   'satisfaction',
#   'location',
#   'excellent',
#   'capable',
#   'walk',
#   'flight',
#   'steep',
#   'place',
#   'may',
#   'pose',
#   'challenge',
#   'help',
#   'assist',
#   'bag',
#   'maybe',
#   'much',
#   'early',
#   'check',
#   'next_morne',
#   'simply',
#   'furnish',
#   'hotel',
#   'many',
#   'similar',
#   'offering',
#   'thing',
#   'note',
#   'price',
#   'drop',
#   'considerably',
#   'made_reservation',
#   'line',
#   'several',
#   'month',
#   'ago',
#   'sometimes',
#   'inclined'],
#  ['right',
#   'market',
#   'grocery',
#   'store',
#   'employee',
#   'great',
#   'courteous',
#   'room',
#   'grand',
#   'special',
#   'hotel',
#   'old',
#   'look',
#   'room',
#   'hot',
#   'ask',
#   'second',
#   'fan',
#   'sauna',
#   'temperature',
#   'cool',
#   'deck',
#   'patio',
#   'cheap',
#   'charge',
#   'day',
#   'wifi',
#   'disappointment',
#   'hotel',
#   'include',
#   'level',
#   'dining',
#   'living_room',
#   'area',
#   'fountain',
#   'nice',
#   'chill',
#   'patio',
#   'nice',
#   'well',
#   'great_views',
#   'lot',
#   'seating'],
#  ['find',
#   'pet',
#   'friendly',
#   'hotel',
#   'blocks_main',
#   'able',
#   'visit',
#   'lot',
#   'landmark',
#   'small',
# ...
#   'could',
#   'clean',
#   'price',
#   'would',
#   'expect',
#   'bit',
#   'tip',
#   'go',
#   'pancake',
#   'breakfast'],
#  ['hotel',
#   'wet',
#   'room',
#   'could',
#   'smell',
#   'time',
#   'may',
#   'hard',
#   'sleep',
#   'room',
#   'hand',
#   'room',
#   'clean',
#   'receptionist',
#   'speak',
#   'good',
#   'willing',
#   'help',
#   'water',
#   'coffee',
#   'free',
#   'day',
#   'long'],
#  ['disappoint',
#   'lack',
#   'ambience',
#   'intermittent',
#   'music',
#   'table',
#   'decorate',
#   'normally',
#   'food',
#   'serve',
#   'room',
#   'temperature',
#   'quickly',
#   'go',
#   'cold',
#   'disappointing',
#   'experience',
#   'whole',
#   'entrance',
#   'area',
#   'need',
#   'revamp',
#   'previously',
#   'stay',
#   'years_ago',
#   'lovely',
#   'memory',
#   'choose',
#   'lunch',
#   'disappoint',
#   'find',
#   'aged',
#   'staff',
#   'welcome'],
#  ['stayed_night',
#   'staff_friendly',
#   'restaurant',
#   'great',
#   'breakfast',
#   'also',
#   'adjoin',
#   'bakery',
#   'location',
#   'hotel',
#   'area',
#   'unfortunately',
#   'bed',
#   'rather',
#   'hard',
#   'uncomfortable',
#   'room',
#   'hot',
#   'rather',
#   'noisy',
#   'could_hear',
#   'people',
#   'clearly',
#   'make',
#   'somewhat',
#   'difficult',
#   'sleep',
#   'time'],
#  ['night',
#   'budget',
#   'establishment',
#   'nice',
#   'proprietor',
#   'helpful',
#   'need',
#   'pro',
#   'relatively',
#   'quiet',
#   'first',
#   'room',
#   'see',
#   'review',
#   'convenient',
#   'excellent',
#   'breakfast',
#   'lunch_dinner',
#   'first',
#   'place',
#   'get',
#   'size',
#   'bed',
#   'con',
#   'room',
#   'bite',
#   'dark',
#   'well',
#   'use',
#   'bit',
#   'dusty',
#   'noisy',
#   'tenant',
#   'courtyard',
#   'late',
#   'loud',
#   'nice',
#   'aware',
#   'noisy',
#   'loud',
#   'singe',
#   'entertainment',
#   'weekend',
#   'room',
#   'back',
#   'wall',
#   'luckily',
#   'seem',
#   'stop',
#   'keep',
#   'second'],
#  ['couple',
#   'year',
#   'old',
#   'stay',
#   'room',
#   'small',
#   'clean',
#   'private_bathroom',
#   'also',
#   'clean',
#   'however',
#   'small',
#   'open',
#   'bathroom',
#   'hallway',
#   'high',
#   'wall',
#   'bar',
#   'roof',
#   'noisy',
#   'staff',
#   'shut',
#   'pm',
#   'hostel',
#   'quiet',
#   'night',
#   'staff',
#   'insist',
#   'hold',
#   'passport',
#   'ensure',
#   'payment',
#   'even_though',
#   'pay',
#   'cash',
#   'advance',
#   'claim',
#   'never',
#   'encounter',
#   'practice',
#   'would',
#   'good',
#   'place',
#   'young',
#   'traveler',
#   'look',
#   'socialize',
#   'party'],
#  ['noise',
#   'place',
#   'crazy',
#   'church_bell',
#   'ring',
#   'hotel',
#   'loudspeaker',
#   'play',
#   'mariachi',
#   'full',
#   'volume',
#   'pm',
#   'pm',
#   'traffic',
#   'definitely',
#   'pick',
#   'night',
#   'leave',
#   'torture',
#   'ear',
#   'violate',
#   'mind',
#   'advertisement',
#   'play',
#   'imagination',
#   'regard',
#   'place',
#   'reality',
#   'however',
#   'different'],
#  ['good',
#   'thing',
#   'come',
#   'stay',
#   'terrace',
#   'fellow',
#   'traveler',
#   'friend',
#   'meet',
#   'make',
#   'far',
#   'expensive',
#   'variety',
#   'hostel',
#   'option',
#   'would',
#   'also',
#   'poor',
#   'service',
#   'noisy',
#   'day',
#   'morning',
#   'view',
#   'volcano',
#   'terrace',
#   'save',
#   'grace',
#   'actually',
#   'enjoy',
#   'included_breakfast',
#   'include',
#   'beverage',
#   'drink',
#   'breakfast',
#   'price',
#   'pay',
#   'criminal',
#   'speak',
#   'criminal',
#   'friend',
#   'also',
#   'camera',
#   'steal',
#   'hostel',
#   'footage',
#   'make',
#   'available',
#   'push',
#   'several',
#   'day',
#   'even'],
#  ['arrive',
#   'little',
#   'cockroach',
#   'bed',
#   'bedroom',
#   'light',
#   'work',
#   'music',
#   'vibrate',
#   'wall',
#   'love',
#   'party',
#   'come_back',
#   'clean',
#   'room',
#   'able',
#   'go',
#   'sleep',
#   'want',
#   'say',
#   'lady',
#   'incredibly',
#   'helpful',
#   'apologetic',
#   'ask',
#   'help',
#   'find',
#   'new',
#   'hotel',
#   'pm',
#   'night',
#   'decide',
#   'enough',
#   'enough',
#   'call',
#   'around',
#   'get',
#   'somewhere',
#   'road',
#   'know',
#   'place',
#   'high',
#   'trip_advisor'],
#  ['place',
#   'student',
#   'interested',
#   'party',
#   'get',
#   'waste',
#   'meet',
#   'student',
#   'good',
#   'night',
#   'sleep',
#   'many',
#   'people',
#   'come',
#   'time',
#   'scream',
#   'loudly',
#   'hall',
#   'drunk',
#   'try',
#   'open',
#   'door',
#   'hostel',
#   'fall',
#   'apart',
#   'let',
#   'mention',
#   'hygiene',
#   'bathroom',
#   'shower',
#   'share',
#   'many',
#   'people',
#   'quality',
#   'mattress',
#   'feel',
#   'spring',
#   'back',
#   'sleep',
#   'tiny',
#   'cramped',
#   'room',
#   'synthetic',
#   'linen',
#   'leave',
#   'today'],
#  ['much',
#   'may',
#   'even',
#   'forget',
#   'believe',
#   'staff',
#   'incredibly',
#   'sweet',
#   'helpful',
#   'however',
#   'initial',
#   'love',
#   'place',
#   'soon',
#   'replace',
#   'incredible',
#   'annoyance',
#   'frustration',
#   'hammer',
#   'noise',
#   'intense',
#   'wake',
#   'hammer',
#   'sound',
#   'worker',
#   'top',
#   'room',
#   'also',
#   'mean',
#   'wake',
#   'sunrise',
#   'maybe',
#   'early_morne',
#   'would',
#   'problem',
#   'party',
#   'late',
#   'previous',
#   'night',
#   'initially',
#   'love',
#   'place',
#   'quite',
#   'disappointed',
#   'outcome',
#   'seek'],
#  ['reason',
#   'rate',
#   'rooftop',
#   'patio',
#   'view',
#   'fellow',
#   'traveller',
#   'would',
#   'congregate',
#   'bottle',
#   'wine',
#   'end',
#   'day',
#   'watch',
#   'sunset',
#   'volcano',
#   'room',
#   'nice',
#   'large',
#   'clean',
#   'bathroom',
#   'breakfast_buffet',
#   'bad',
#   'beef',
#   'slow',
#   'response',
#   'room',
#   'light',
#   'bulb',
#   'expire',
#   'take',
#   'hour',
#   'person',
#   'come',
#   'ladder',
#   'install',
#   'new',
#   'bulb',
#   'breakfast'],
#  ['stay',
#   'location',
#   'fantastic',
#   'room',
#   'basic',
#   'tv',
#   'simple',
#   'furniture',
#   'room',
#   'maintenance',
#   'issue',
#   'room',
#   'rather',
#   'small',
#   'clean',
#   'free_wifi',
#   'available',
#   'staff_member',
#   'great',
#   'attitude',
#   'manner',
#   'clearly',
#   'compensate',
#   'shortcoming',
#   'room',
#   'breakfast',
#   'available',
#   'understand',
#   'own',
#   'hotel',
#   'offer',
#   'great',
#   'breakfast',
#   'coffee',
#   'bite',
#   'put',
#   'rather',
#   'excessive',
#   'price',
#   'hotel',
#   'may',
#   'fact',
#   'stay',
#   'busy',
#   'day',
#   'year',
#   'charge',
#   'night',
#   'double',
#   'hotel',
#   'class',
#   'charge',
#   'hotel',
#   'good',
#   'option',
#   'basic'],
#  ['spend',
#   'actually',
#   'plane',
#   'hike',
#   'trek',
#   'volcano',
#   'night',
#   'really',
#   'need',
#   'sleep',
#   'trerrible',
#   'speak',
#   'guide',
#   'reception',
#   'many_time',
#   'continue',
#   'pm',
#   'party',
#   'hotel',
#   'day',
#   'take',
#   'also',
#   'disappointment',
#   'local',
#   'guide',
#   'never',
#   'look',
#   'behind',
#   'fast',
#   'group',
#   'lose',
#   'even',
#   'warn',
#   'guide',
#   'change',
#   'behavior',
#   'morning',
#   'wake',
#   'early',
#   'guide',
#   'sleep',
#   'chance',
#   'wake',
#   'time',
#   'try',
#   'wake'],
#  ['offer',
#   'tourist',
#   'traveler',
#   'enjoy',
#   'vice',
#   'night',
#   'life',
#   'location',
#   'pretty',
#   'great',
#   'couple_block',
#   'central_park',
#   'several',
#   'fun',
#   'option',
#   'night',
#   'club',
#   'block',
#   'even',
#   'want',
#   'stay',
#   'dining',
#   'drinking',
#   'dance',
#   'mainstream',
#   'music',
#   'last',
#   'night',
#   'around_pm',
#   'also',
#   'quaint',
#   'jacuzzi',
#   'back',
#   'guest',
#   'close',
#   'pm',
#   'wish',
#   'open',
#   'later',
#   'private',
#   'room',
#   'look',
#   'dank',
#   'hell',
#   'share',
#   'dorm',
#   'opinion',
#   'lack',
#   'provide',
#   'locker',
#   'bunk',
#   'absent',
#   'personal',
#   'light',
#   'electric',
#   'outlet',
#   'assign',
#   'dorm',
#   'bed',
#   'entire',
#   'room',
#   'electrical'],
#  ['hotel',
#   'use',
#   'lot',
#   'adventure',
#   'group',
#   'look',
#   'quiet',
#   'place',
#   'sleep',
#   'place',
#   'may',
#   'lucky',
#   'avoid',
#   'group',
#   'chance',
#   'group',
#   'quite',
#   'pleased',
#   'place',
#   'wifi_work',
#   'lobby',
#   'room',
#   'clean',
#   'room',
#   'shower',
#   'whole',
#   'hotel',
#   'decide',
#   'shower',
#   'time',
#   'concrete',
#   'helpful',
#   'staff',
#   'breakfast',
#   'ant',
#   'bathroom'],
#  ['stay',
#   'part',
#   'tour',
#   'organise',
#   'contact',
#   'staff',
#   'situate',
#   'hotel',
#   'basic',
#   'comfortable'],
#  ['decide',
#   'hotel',
#   'aviod',
#   'ruthless',
#   'drunk',
#   'loud',
#   'people',
#   'crowd',
#   'however',
#   'manage',
#   'find',
#   'room',
#   'noice',
#   'start',
#   'end',
#   'repeatetly',
#   'ask',
#   'noisy',
#   'guest',
#   'politely',
#   'quiet',
#   'respect',
#   'tell',
#   'guard',
#   'trouble',
#   'first',
#   'time',
#   'talk',
#   'work',
#   'second',
#   'time',
#   'neighbour',
#   'keep',
#   'talk',
#   'guard',
#   'even',
#   'come',
#   'room',
#   'nice',
#   'building',
#   'loud',
#   'neighbour',
#   'ruin',
#   'stay'],
#  ['room',
#   'lock',
#   'good',
#   'travel',
#   'desk',
#   'breakfast',
#   'bean',
#   'coffee',
#   'english_speake',
#   'staff',
#   'tell',
#   'website',
#   'also',
#   'can',
#   'pay',
#   'card',
#   'room',
#   'rather',
#   'grim',
#   'lock',
#   'window',
#   'together',
#   'muxh',
#   'overpriced'],
#  ['sure',
#   'hotel',
#   'describe',
#   'charming',
#   'maybe',
#   'old',
#   'gentleman',
#   'work',
#   'would',
#   'say',
#   'stop',
#   'grant',
#   'nice',
#   'want',
#   'cancel',
#   'second_night',
#   'originally_booke',
#   'positive',
#   'hotel',
#   'quiet',
#   'read',
#   'countless',
#   'review',
#   'place',
#   'seem',
#   'struggle',
#   'noise',
#   'hotel',
#   'least',
#   'quiet',
#   'room',
#   'tiny',
#   'dingy',
#   'dark',
#   'suspicious',
#   'shower',
#   'electrocute',
#   'husband',
#   'place',
#   'atmosphere',
#   'ever',
#   'kind',
#   'place',
#   'leave',
#   'feel',
#   'dirty',
#   'stay',
#   'leave',
#   'morning',
#   'comment',
#   'breakfast',
#   'want',
#   'leave',
#   'quickly',
#   'possible'],
#  ['recently',
#   'stay',
#   'route',
#   'hotel',
#   'strangely',
#   'arrange',
#   'pool_table',
#   'awkwardly',
#   'middle',
#   'way',
#   'check',
#   'suggestion',
#   'food',
#   'guest',
#   'step',
#   'offer',
#   'suggestion',
#   'american',
#   'owner',
#   'presumably',
#   'right',
#   'desk',
#   'remain',
#   'silent',
#   'try',
#   'communicate',
#   'staff',
#   'little',
#   'english',
#   'assist',
#   'stilted',
#   'communication',
#   'room',
#   'shared_bathroom',
#   'close',
#   'room',
#   'room',
#   'cramp',
#   'double_bed',
#   'room',
#   'bed',
#   'ceile',
#   'low',
#   'combination',
#   'bed',
#   'make',
#   'room',
#   'feel',
#   'claustrophobic',
#   'get',
#   'bed'],
#  ['anywhere',
#   'stay',
#   'expectation',
#   'heavily',
#   'influence',
#   'impression',
#   'review',
#   'place',
#   'expect',
#   'budget',
#   'hotel',
#   'locate',
#   'multiple',
#   'bar',
#   'nearby',
#   'think',
#   'people',
#   'would',
#   'ok',
#   'enough',
#   'book',
#   'know',
#   'bar',
#   'hotel',
#   'expect',
#   'hear',
#   'noise',
#   'night',
#   'choose',
#   'seem',
#   'optimally',
#   'locate',
#   'aim',
#   'location',
#   'block',
#   'right',
#   'centre',
#   'thing',
#   'say',
#   'realize',
#   'arrive',
#   'small',
#   'block',
#   'tiny',
#   'place',
#   'discount',
#   'extra',
#   'minute',
#   'walk',
#   'room',
#   'small',
#   'basic',
#   'little',
#   'dark',
#   'nice',
#   'touch'],
#  ['stay',
#   'wedding',
#   'really',
#   'want',
#   'place',
#   'sleep',
#   'unfortunately',
#   'room',
#   'close',
#   'street',
#   'bite',
#   'noisy',
#   'clean',
#   'centric',
#   'would',
#   'stay',
#   'option',
#   'would',
#   'look',
#   'first'],
#  ['stay',
#   'weekend',
#   'private',
#   'double',
#   'ok',
#   'quality',
#   'good',
#   'value_money',
#   'compare',
#   'similar',
#   'room',
#   'hostel',
#   'area',
#   'weekend',
#   'expect',
#   'bit',
#   'expect',
#   'terrace_bar',
#   'quite',
#   'noisy',
#   'day',
#   'room',
#   'right',
#   'bar',
#   'kitchen',
#   'could_hear',
#   'music',
#   'box',
#   'bottle',
#   'drag',
#   'around',
#   'midnight',
#   'need',
#   'power',
#   'nap',
#   'nasty',
#   'night',
#   'bus',
#   'want',
#   'sleep',
#   'lot',
#   'local',
#   'people',
#   'hostel',
#   'seem',
#   'visit',
#   'bar',
#   'tend',
#   'hog',
#   'upstairs',
#   'bathroom',
#   'whole',
#   'hostel',
#   'shower',
#   'little',
#   'tricky'],
#  ['mistaken',
#   'definitely',
#   'price',
#   'charge',
#   'much',
#   'say',
#   'thing',
#   'average',
#   'hotel',
#   'location',
#   'price',
#   'rest',
#   'room',
#   'bed',
#   'bathroom',
#   'say',
#   'even',
#   'hostel',
#   'even',
#   'room',
#   'locate',
#   'hotel',
#   'restaurant',
#   'noise',
#   'definitely',
#   'good',
#   'place'],
#  ['stayed_night',
#   'comfortable',
#   'room',
#   'bed',
#   'good',
#   'garden',
#   'look',
#   'good',
#   'comfortable',
#   'seat',
#   'plenty',
#   'insect',
#   'bite',
#   'average',
#   'breakfast',
#   'give',
#   'go',
#   'breakfast',
#   'place',
#   'well',
#   'away',
#   'block',
#   'km',
#   'quiet',
#   'street',
#   'want',
#   'walk',
#   'back',
#   'fact',
#   'place',
#   'lock',
#   'armed',
#   'tell',
#   'nee',
#   'know',
#   'security',
#   'concern'],
#  ['work',
#   'tourism',
#   'industry',
#   'stay',
#   'hotel',
#   'try',
#   'speak',
#   'people',
#   'manage',
#   'property',
#   'order',
#   'know',
#   'wrong',
#   'show',
#   'improve',
#   'unfortunately',
#   'case',
#   'hotel',
#   'bad',
#   'experience',
#   'ever',
#   'hotel',
#   'club',
#   'hotel',
#   'keep',
#   'room',
#   'small',
#   'picture',
#   'show',
#   'finish',
#   'thing',
#   'wake',
#   'sound',
#   'people',
#   'work',
#   'restaurant',
#   'prepare',
#   'breakfast',
#   'happen',
#   'stay',
#   'next_day',
#   'try',
#   'explain',
#   'case',
#   'agent',
#   'even',
#   'care',
#   'general',
#   'manager',
#   'never'],
#  ['small',
#   'establishment',
#   'kid',
#   'friendly',
#   'nice',
#   'playground',
#   'kid',
#   'loud',
#   'small',
#   'windows_open',
#   'get',
#   'air',
#   'hear',
#   'noise',
#   'courtyard',
#   'room',
#   'room',
#   'get',
#   'hot',
#   'beds_comfortable',
#   'room',
#   'big',
#   'small',
#   'bathroom',
#   'room',
#   'put',
#   'anywhere',
#   'time',
#   'take',
#   'breakfast_include',
#   'take',
#   'almost',
#   'hour',
#   'breakfast',
#   'many',
#   'day',
#   'thing',
#   'get',
#   'old',
#   'week',
#   'hotel',
#   'pretty',
#   'nice',
#   'many',
#   'place',
#   'stay',
#   'provide',
#   'well',
#   'value'],
#  ['book',
#   'book',
#   'double',
#   'triple',
#   'room',
#   'twin',
#   'switch',
#   'triple',
#   'tiny',
#   'room',
#   'double_bed',
#   'arrive',
#   'room',
#   'locate',
#   'back',
#   'next',
#   'laundry',
#   'quite',
#   'noisy',
#   'get',
#   'bad',
#   'start',
#   'also',
#   'room',
#   'available',
#   'outlet',
#   'phone',
#   'charging',
#   'different',
#   'circumstance',
#   'may',
#   'like',
#   'stay',
#   'serve',
#   'nice',
#   'breakfast',
#   'coffee',
#   'available',
#   'early',
#   'riser',
#   'well_situate',
#   'town'],
#  ['minute',
#   'walk',
#   'many',
#   'shops_restaurant',
#   'bar',
#   'pleasant',
#   'well',
#   'restore',
#   'traditional',
#   'hotel',
#   'good',
#   'room',
#   'queen',
#   'sized',
#   'bed',
#   'old',
#   'style',
#   'tv',
#   'roof',
#   'light',
#   'blind',
#   'wake',
#   'quite',
#   'early',
#   'light',
#   'problem',
#   'need',
#   'good',
#   'free',
#   'wi_fi',
#   'room',
#   'good',
#   'shower',
#   'shower',
#   'room',
#   'courtyard',
#   'supermarket'],
#  ['room',
#   'clean',
#   'building',
#   'nice',
#   'unfortunately',
#   'atmosphere',
#   'bit',
#   'cold',
#   'much',
#   'light',
#   'whole',
#   'building',
#   'staff',
#   'around',
#   'arrive',
#   'may',
#   'better_place'],
#  ['take',
#   'long',
#   'reach',
#   'downtown',
#   'advantage',
#   'hotel',
#   'small',
#   'bakery',
#   'nearby',
#   'min',
#   'walk',
#   'expensive',
#   'taste',
#   'good',
#   'convenient',
#   'next',
#   'hotel',
#   'pretty',
#   'good_location',
#   'shop',
#   'nearby',
#   'sick',
#   'travel',
#   'go',
#   'travel',
#   'day',
#   'take',
#   'rest',
#   'hotel',
#   'go',
#   'pastry',
#   'shop',
#   'lot',
#   'enough',
#   'power',
#   'walk',
#   'faraway',
#   'hotel',
#   'say',
#   'bread',
#   'save',
#   'life',
#   'old',
#   'town',
#   'beautiful',
#   'landscape',
#   'volcano',
#   'city'],
#  ['stay',
#   'part',
#   'adventure',
#   'tour',
#   'room',
#   'small',
#   'basic',
#   'hotel',
#   'great',
#   'hotel',
#   'shop',
#   'buy',
#   'drink',
#   'snack',
#   'nice',
#   'bakery',
#   'also',
#   'tasty',
#   'breakfast',
#   'nice',
#   'room',
#   'see',
#   'invite',
#   'hotel'],
#  ['place',
#   'type',
#   'place',
#   'get',
#   'pay',
#   'much',
#   'quite',
#   'simple',
#   'daunting',
#   'entrance',
#   'timber',
#   'door',
#   'open',
#   'nice',
#   'venue',
#   'hotel',
#   'different',
#   'room',
#   'quite_dark',
#   'eery',
#   'bathroom',
#   'basic',
#   'large',
#   'room',
#   'safe',
#   'air',
#   'conditioner',
#   'much',
#   'problem',
#   'quite',
#   'safe',
#   'high',
#   'brick',
#   'wall',
#   'solid',
#   'timber',
#   'gate',
#   'expose',
#   'concrete',
#   'brick',
#   'render',
#   'wall',
#   'act',
#   'good',
#   'insulator',
#   'keep',
#   'heat',
#   'invite',
#   'place',
#   'blink',
#   'door',
#   'convenience',
#   'store',
#   'purchase',
#   'snack',
#   'drink',
#   'smoke',
#   'next_door',
#   'side',
#   'find',
#   'nice',
#   'bakery',
#   'make',
#   'nice'],
#  ['fine',
#   'room',
#   'next',
#   'occupy',
#   'fart',
#   'could',
#   'smell',
#   'dorm',
#   'living',
#   'price',
#   'otherwise',
#   'clean',
#   'helpful',
#   'staff'],
#  ...]

# %%
def create_dictionary(documents: List[List[str]]):
    return Dictionary(documents)

# %%
negative_words = [item for sublist in negative_docs for item in sublist]
positive_words = [item for sublist in positive_docs for item in sublist]

# %%
positive_words
# Out:
# ['stay',
#  'incredible',
#  'staff',
#  'catering',
#  'need',
#  'family',
#  'stay',
#  'week',
#  'pandemic',
#  'impress',
#  'measure',
#  'hotel',
#  'put',
#  'place',
#  'keep',
#  'safe',
#  'well',
#  'give',
#  'box',
#  'mask',
#  'glove',
#  'bottle',
#  'hand',
#  'sanitiser',
#  'upon_arrival',
#  'staff',
#  'wear',
#  'mask',
#  'glove',
#  'room',
#  'everything_else',
#  'clean',
#  'high',
#  'standard',
#  'price',
#  'offer',
#  'time',
#  'incredible',
#  'value_money',
#  'definitely',
#  'hope',
#  'travel',
#  'reopen',
#  'thank_much',
#  'look',
#  'well',
#  'could',
#  'return',
#  'home',
#  'hotel',
#  'awesome',
#  'staff',
#  'welcome',
#  'minute',
#  'arrive',
#  'day',
#  'depart',
#  'view',
#  'dining_area',
#  'mountain',
#  'background',
#  'spectacular',
#  'ground',
#  'manicure',
#  'perfection',
#  'flowering_plant',
#  'direction',
#  'center',
#  'area',
#  'large',
#  'bougainvillea',
#  'blue',
#  'full',
#  'bloom',
#  'estimate',
#  'foot',
#  'height',
#  'fresh',
#  'flower_arrangement',
#  'reception',
#  'room',
#  'well_appointe',
#  'clean',
#  'comfortable',
#  'business_pleasure',
#  'stay',
#  'truly',
#  'amazing',
#  'experience',
#  'city',
#  'preserve',
#  'building',
#  'church',
#  'stay',
#  'view',
#  'picture',
#  'exactly',
#  'take',
#  'camera',
#  'room',
#  'spacious',
#  'fireplace',
#  'water',
#  'provide',
#  'jug',
#  'container',
#  'clean',
#  'staff',
#  'friendly',
#  'hospitable',
#  'excellent',
#  'use',
#  'go',
#  'reception',
#  'staff',
#  'incredible',
#  'hotel',
#  'lovely',
#  'nicely_appointe',
#  'pool',
#  'restaurant',
#  'client',
#  'parking',
#  'tell',
#  'oasis',
#  'bustling',
#  'quaint',
#  'town',
#  'relax',
#  'feel',
#  'pamper',
#  'almost',
#  'always',
#  'stay',
#  'room',
#  'staff',
#  'gracious',
#  'pool',
#  'wonderful',
#  'spa',
#  'amazing',
#  'massage',
#  'trip',
#  'outstanding',
#  'massage',
#  'therapist',
#  'kind',
#  'warm',
#  'loving',
#  'tune',
#  'need',
#  'preference',
#  'never',
#  'stay',
#  'hotel',
#  'get',
#  'reservation',
#  'use',
#  'reward',
#  'point',
#  'boy',
#  'glad',
#  'staff',
#  'helpful',
#  'guide',
#  'place',
#  'interest',
#  'even',
#  'help',
#  'take',
#  'stuff',
#  'room',
#  'also',
#  'shuttle',
#  'back',
#  'get',
#  'bed',
#  'arch',
#  'street',
#  'excellent',
#  'place',
#  'quiet',
#  'night',
#  'rest',
#  'price',
#  'excellent',
#  'service',
#  'render',
#  'hotel',
#  'beautiful',
#  'clean',
#  'nicely_decorate',
#  'room',
#  'upstairs',
#  'beautiful',
#  'comfortable',
#  'patio',
#  'accomodate',
#  'relax',
#  'afternoon',
#  'evening',
#  'staff',
#  'good',
#  'ever_experience',
#  'truly',
#  'interested',
#  'ensure',
#  'stay',
#  'perfect',
#  'want',
#  'stay',
#  'breakfast',
#  'morning',
#  'awesome',
#  'say',
#  'first',
#  'stay',
#  'close',
#  'everywhere',
#  'include',
#  'bed',
#  'minute',
#  'walking_distance',
#  'fact',
#  'give',
#  'central',
#  'location',
#  'attraction',
#  'town',
#  'accessible',
#  'walk',
#  'place',
#  'cosy',
#  'nook',
#  'room',
#  'say',
#  'almost',
#  'little',
#  'lounge',
#  'want',
#  'room',
#  'tastefully_done',
#  'guatemalan',
#  'textile',
#  'clean',
#  'bed',
#  'comfortable',
#  'well',
#  'issue',
#  'room',
#  'window_opene',
#  'step',
#  'room',
#  'would',
#  'compromise',
#  'privacy',
#  'mention',
#  'room',
#  'less',
#  'people',
#  'property',
#  'fine',
#  'highlight',
#  'place',
#  'breakfast',
#  'cook',
#  'place',
#  'amazing',
#  'staff',
#  'friendly',
#  'good',
#  'breakfast_include',
#  'room',
#  'clean',
#  'comfortable',
#  'view',
#  'street',
#  'clear_day',
#  'volcano',
#  'downfall',
#  'central',
#  'location',
#  'reveler',
#  'hope',
#  'stay',
#  'overall',
#  'experience',
#  'stay',
#  'family',
#  'four_night',
#  'love',
#  'stay',
#  'staff',
#  'friendly_helpful',
#  'tour',
#  'early_morne',
#  'miss',
#  'breakfast',
#  'four_night',
#  'morning',
#  'prepare',
#  'simple',
#  'breakfast',
#  'ham',
#  'cheese',
#  'sandwich',
#  'fruit',
#  'go',
#  'go',
#  'hungry',
#  'accommodate',
#  'flexible',
#  'amenity',
#  'airport_shuttle',
#  'service',
#  'person',
#  'available',
#  'airport',
#  'also',
#  'city',
#  'ask',
#  'advance',
#  'wonderful',
#  'outdoor',
#  'terrace',
#  'upstairs',
#  'especially',
#  'early_morning',
#  'weather',
#  'cool',
#  'simple',
#  'breakfast',
#  'great',
#  'location',
#  'close',
#  'tourist',
#  'hotspot',
#  'overall',
#  'would_highly',
#  'recommend',
#  'stayed_night',
#  'may',
#  'cute',
#  'place',
#  'small',
#  'quiet',
#  'blocks_central',
#  'square',
#  'restaurants_shop',
#  'church',
#  'also',
#  'love',
#  'breakfast_include',
#  'neat',
#  'little',
#  'hotel',
#  'fairly',
#  'close',
#  'action',
#  'stay',
#  'nice',
#  'enough',
#  'room',
#  'good',
#  'breakfast',
#  'choice',
#  'great',
#  'staff',
#  'make',
#  'happy',
#  'wife',
#  'other',
#  'group',
#  'stay',
#  'total',
#  'three_night',
#  'hotel',
#  'palacio_chico',
#  'confused',
#  'hotel',
#  'palacio_chico',
#  'totally',
#  'different',
#  'hotel',
#  'group',
#  'member',
#  'completely',
#  'satisfied',
#  'stay',
#  'service',
#  'exceptionally',
#  'accommodate',
#  'three_night',
#  'occur',
#  'period',
#  'day',
#  'volunteer',
#  'visit',
#  'city',
#  'store',
#  'extra',
#  'luggage',
#  'stay',
#  'room',
#  'bite',
#  'tight',
#  'beds_comfortable',
#  'room',
#  'bed',
#  'other',
#  'share',
#  'prefer',
#  'bed',
#  'option',
#  'small',
#  'hotel',
#  'possibly',
#  'room',
#  'maximum',
#  'include',
#  'breakfast',
#  'satisfactory',
#  'toast',
#  'also',
#  'clean',
#  'really',
#  'wonderful',
#  'place',
#  'recommand',
#  'sleep',
#  'room',
#  'clean',
#  'bed',
#  'perfect',
#  'people',
#  'friendly',
#  'breakfast',
#  'include',
#  'good',
#  'offer',
#  'night',
#  'room',
#  'fact',
#  'negative',
#  'recommand',
#  'good',
#  'spa',
#  'attention',
#  'amazing',
#  'food',
#  'experience',
#  'recommend',
#  'massage',
#  'great',
#  'room',
#  'clean',
#  'location',
#  'great',
#  'definitely',
#  'go',
#  'want',
#  'whole',
#  'experience',
#  'hesitate',
#  'choose',
#  'hotel',
#  'genuinely',
#  'friendly',
#  'interesting',
#  'hotel',
#  'close',
#  'reception',
#  'staff',
#  'breakfast',
#  'order',
#  'day',
#  'want',
#  'totally',
#  'unpretentious',
#  'staff',
#  'genuine',
#  'desire',
#  'ensure',
#  'stay',
#  'memorable',
#  'super',
#  'clean',
#  'super',
#  'cute',
#  'super',
#  'located',
#  'boyfriend',
#  'sleep',
#  'dorm_bed',
#  'totally',
#  'fine',
#  'price',
#  'breakfast_include',
#  'sooo',
#  'yummy',
#  'really',
#  'fresh',
#  'miss',
#  'nice',
#  'get',
#  'awesome',
#  'breakfast',
#  'sit',
#  'beautiful',
#  'green',
#  'terrace',
#  'clean',
#  'breakfast',
#  'lady',
#  'really',
#  'friendly',
#  'even',
#  'make',
#  'bed',
#  'every_morne',
#  'clean',
#  'bathrooms_shower',
#  'perfectly',
#  'thank',
#  'absolutely',
#  'wonderful',
#  'work',
#  'always',
#  'helpful',
#  'friendly',
#  'thank_guy',
#  'hostel',
#  'people',
#  'cute',
#  'clean',
#  'hostel',
#  'family',
#  'stay',
#  'hostel',
#  'trek',
#  'return',
#  'extremely',
#  'responsive',
#  'helpful',
#  'via_email',
#  'prior_arrival',
#  'lovely',
#  'friendly',
#  'give',
#  'good',
#  'restaurant',
#  'recommendation',
#  'lovely',
#  'clean',
#  'bathroom',
#  'throughout_day',
#  'shower',
#  'nice',
#  'hot',
#  'lovely',
#  'breakfast_include',
#  'rate',
#  'stay',
#  'stay',
#  'nice',
#  'double_bed',
#  'room',
#  'host',
#  'staff',
#  'friendly_helpful',
#  'room',
#  'clean',
#  'breakfast',
#  'delicious',
#  'pancake',
#  'nice',
#  'relaxing',
#  'roof_top',
#  'chill',
#  'nice',
#  'view',
#  'locate',
#  'staff',
#  'book',
#  'well',
#  'hostel',
#  'clean',
#  'breakfast',
#  'huge',
#  'varied',
#  'eat',
#  'overlook',
#  'three_volcanoe',
#  'party_hostel',
#  'good',
#  'couple',
#  'try',
#  'relax',
#  'nice',
#  'hammock',
#  'laundry',
#  'pound',
#  'back',
#  'day',
#  'santo_domingo',
#  'provide',
#  'perfect',
#  'locale',
#  'th_wedde',
#  'anniversary',
#  'variety',
#  'food',
#  'unsurpassed',
#  'ambience',
#  'service',
#  'suggest',
#  'mid',
#  'week',
#  'stay',
#  'hotel',
#  'restaurant',
#  'pack',
#  'weekend',
#  'sure',
#  'tour',
#  'entire',
#  'facility',
#  'unrestored',
#  'area',
#  'spend',
#  'architecture',
#  'unique',
#  'food',
#  'excellent',
#  'staff',
#  'help',
#  'anyway',
#  'leave',
#  'cheese',
#  'minibar',
#  'refrigerator',
#  'pick',
#  'staff',
#  'inmediately',
#  'took_care',
#  'order',
#  'room',
#  'service',
#  'breakfast',
#  'willing',
#  'pay',
#  'expense',
#  'cover',
#  'breakfast',
#  'charge',
#  'take',
#  'breakfast',
#  'room',
#  'activity',
#  'hotel',
#  'excepcional',
#  'gorgeous',
#  'outdoor',
#  'space',
#  'recommend',
#  'santo_domingo',
#  'tourist',
#  'seminar',
#  'forum',
#  'capacity',
#  'manage',
#  'small',
#  'big',
#  'group',
#  'outstanding',
#  'experience',
#  'small',
#  'exception',
#  'lady',
#  'take',
#  'table',
#  'restaurant',
#  'unfriendly',
#  'brusque',
#  'restaurant',
#  'top',
#  'mountain',
#  'divine',
#  'experience',
#  'way',
#  'hotel',
#  'good',
#  'ground',
#  'museum',
#  'pool',
#  'art',
#  'fabulous',
#  'beyond_expectation',
#  'pleased',
#  'try',
#  'return',
#  'complaint',
#  'minor',
#  'need',
#  'mention',
#  'location',
#  'hotel',
#  'seem',
#  'room',
#  'excellent',
#  'first',
#  'stay',
#  'beautiful',
#  'property',
#  'ground',
#  'lovely',
#  'room',
#  'well_appointe',
#  'clean',
#  'sure',
#  'window',
#  'patio',
#  'balcony',
#  'sure',
#  'take_advantage',
#  'visit',
#  'onsite',
#  'museum',
#  'ruin',
#  'staff',
#  'friendly',
#  'service_oriente',
#  'food',
#  'good',
#  'need',
#  'casual',
#  'option',
#  'dinner',
#  'property',
#  'expensive',
#  'standard',
#  'come',
#  'affordable',
#  'luxury',
#  'also',
#  'visit',
#  'restaurant',
#  'museum',
#  'hill',
#  'hotel',
#  'delicious',
#  'breakfast',
#  'enjoy',
#  'wonderful',
#  'art',
#  'installation',
#  'small',
#  'beautiful',
#  'hotel',
#  'home',
#  'night',
#  'locate',
#  'conveniently',
#  'close',
#  'famous',
#  'shopping',
#  'banking',
#  'restaurant',
#  'tell',
#  'outside',
#  'small',
#  'hotel',
#  'beautiful',
#  'courtyard',
#  'bloom',
#  'plant',
#  'greenery',
#  'pool',
#  'also',
#  'cover',
#  'breakfast',
#  'area',
#  'become',
#  'gather',
#  'place',
#  'morning',
#  'mostly',
#  'fortunately',
#  'room',
#  'upstairs',
#  'breakfast',
#  'area',
#  'even_though',
#  'stairs',
#  'haul',
#  'suitcase',
#  'try_reserve',
#  'room',
#  'room',
#  'watch',
#  'erupt',
#  'night',
#  'several',
#  'bench',
#  'sit',
#  'room',
#  'room',
#  'huge',
#  'actually',
#  'room',
#  'cool',
#  'room',
#  'staff',
#  'super',
#  'spoke_english',
#  'breakfast',
#  'let',
#  'book',
#  'ride_airport',
#  'also',
#  'tour',
#  'cheap',
#  'locate',
#  'yard',
#  'easy_walking',
#  'distance_sight',
#  'excellent',
#  'pool',
#  'nice',
#  'great',
#  'food',
#  'beautiful',
#  'scenery',
#  'mountain',
#  'close',
#  'far',
#  'many',
#  'volcano',
#  'room',
#  'come',
#  'kitchen',
#  'area',
#  'nice',
#  'view',
#  'window',
#  'many',
#  'tour',
#  'take',
#  'many',
#  'time',
#  'fun',
#  'much',
#  'bedroom',
#  'kitchen',
#  'room',
#  'clean',
#  'comfortable',
#  'king_bed',
#  'bedroom',
#  'fireplace',
#  'kitchen',
#  'stove',
#  'top',
#  'burner',
#  'make',
#  'plenty',
#  'breakfast',
#  'snack',
#  'problem',
#  'give',
#  'bottles_water',
#  'per_day',
#  'easily',
#  'purchase',
#  'use',
#  'cook',
#  'etc',
#  'issue',
#  'stick',
#  'couple_time',
#  'good',
#  'food',
#  'nice',
#  'staff',
#  'walk',
#  'town',
#  'many_time',
#  'far',
#  'walkable',
#  'mobility',
#  'issue',
#  'cobblestone',
#  'high',
#  'sidewalk',
#  'town',
#  'would',
#  'tough',
#  'kind',
#  'mobility',
#  'issue',
#  'hotel',
#  'provide',
#  'hourly',
#  'shuttle',
#  'pm',
#  'help',
#  'guest',
#  'center',
#  'conveniently',
#  'aware',
#  'work',
#  'room',
#  'excellent',
#  'dream',
#  'good',
#  'restaurant',
#  'breakfast',
#  'enjoy',
#  'spa_gym',
#  'also',
#  'tennis',
#  'court',
#  'also',
#  'shuttle_bus',
#  'daytime',
#  'lovely',
#  'stay',
#  'great',
#  'staff',
#  'well',
#  'helpful',
#  'friendly',
#  'room',
#  'clean',
#  'comfortable',
#  'price_reasonable',
#  'location',
#  'excellent',
#  'easy_walking',
#  'distance',
#  'central_park',
#  'great',
#  'restaurants_shoppe',
#  'beautiful',
#  'old',
#  'church',
#  'breakfast_buffet',
#  'inexpensive',
#  'thank',
#  'cute',
#  'hotel',
#  'really_enjoye',
#  'color',
#  'room',
#  'need',
#  'much',
#  'stay',
#  'notice',
#  'magnificent',
#  'garden',
#  'beautiful',
#  'flower',
#  'staff',
#  'welcome',
#  'lot',
#  'business',
#  'company',
#  'often',
#  'already',
#  'know',
#  'certain',
#  'accommodation',
#  'place',
#  'location_perfect',
#  'two_block',
#  'close',
#  'arch',
#  'block',
#  'close',
#  'good',
#  'bunch',
#  'restaurant',
#  'breakfast',
#  'delicious',
#  'overall',
#  'good',
#  'stay',
#  'suggestion',
#  'leave',
#  'night',
#  'light',
#  'entrance',
#  'flight',
#  'leave',
#  'room',
#  'use',
#  'flashlight',
#  'phone',
#  'find',
#  'way',
#  ...]

# %%
len(negative_words)
# Out:
# 78686

# %%
len(positive_words)
# Out:
# 432985

# %%
dictionary = create_dictionary([negative_words, positive_words])

# %%
for key, value in dictionary.items():
    print(key, value)
# Out:
# 0 abandon
# 1 abate
# 2 abhorrent
# 3 ability
# 4 able
# 5 able_get
# 6 abroad
# 7 abrupt
# 8 absence
# 9 absent
# 10 absolute
# 11 absolutely
# 12 absorb
# 13 abstract
# 14 absurd
# 15 absurdly
# 16 abundance
# 17 abuse
# 18 abysmal
# 19 ac
# 20 accept
# 21 acceptable
# 22 acception
# 23 access
# 24 accessible
# 25 accessory
# 26 accident
# 27 accidentally
# 28 acclaim
# 29 accommodate
# 30 accommodating
# 31 accommodation
# 32 accomodate
# 33 accomodating
# 34 accomodation
# 35 accompany
# 36 accord
# 37 accordingly
# 38 account
# 39 accountability
# 40 accounting
# 41 accurate
# 42 accurately
# 43 accuse
# 44 accustom
# 45 accustomed
# 46 ache
# 47 acknowledge
# 48 acquaint
# 49 acquire
# 50 acrid
# 51 across_street
# 52 act
# 53 action
# 54 activate
# 55 active
# 56 actively
# 57 activity
# 58 actual
# 59 actually
# 60 ad
# 61 adapt
# 62 add
# 63 addition
# 64 additional
# 65 additionally
# 66 additionaly
# 67 address
# 68 adequate
# 69 adequately
# 70 adhesive
# 71 aditionally
# 72 adjacent
# 73 adjoin
# 74 adjoining
# 75 adjust
# 76 administration
# 77 administrative
# 78 administrator
# 79 admire
# 80 admit
# 81 admittedly
# 82 adopt
# 83 adorable
# 84 adult
# 85 advance
# 86 advanced
# 87 advantage
# 88 adventure
# 89 adventurer
# 90 adventurous
# 91 advertise
# 92 advertisement
# 93 advertising
# 94 advice
# 95 advisable
# 96 advise
# 97 advisory
# 98 aerobics
# 99 aesthetic
# 100 aesthetically
# 101 afar
# 102 affair
# 103 affect
# 104 affordable
# 105 affortable
# 106 afraid
# 107 afternoon
# 108 afterwards
# 109 age
# 110 aged
# 111 agency
# 112 agent
# 113 aggressive
# 114 agitated
# 115 ago
# 116 agreat
# 117 agree
# 118 agreeable
# 119 agreed_pay
# 120 agreement
# 121 agressive
# 122 ahead
# 123 aim
# 124 aimlessly
# 125 air
# 126 air_circulation
# 127 air_con
# 128 air_conditione
# 129 air_conditioning
# 130 airbnb
# 131 aircon
# 132 airconditione
# 133 airflow
# 134 airless
# 135 airline
# 136 airport
# 137 airport_shuttle
# 138 airtight
# 139 airy
# 140 akd
# 141 akin
# 142 alarm
# 143 alas
# 144 alcohol
# 145 alcoholic
# 146 alike
# 147 alive
# 148 allegation
# 149 allegedly
# 150 allergic
# 151 allergy
# 152 alley
# 153 alliance
# 154 alll
# 155 allocate
# 156 allocating
# 157 allocation
# 158 allow
# 159 almost
# 160 alone
# 161 aloof
# 162 alot
# 163 already
# 164 alright
# 165 also
# 166 alter
# 167 alternate
# 168 alternative
# 169 although
# 170 altitude
# 171 altogether
# 172 altough
# 173 always
# 174 amaze
# 175 amazed
# 176 amazing
# 177 ambiance
# 178 ambience
# 179 amble
# 180 amenitite
# 181 amenititie
# 182 amenity
# 183 amentie
# 184 amentitie
# 185 american
# 186 amount
# 187 ample
# 188 amplify
# 189 ancient
# 190 anf
# 191 angel
# 192 anger
# 193 angieinfl
# 194 angle
# 195 angrily
# 196 angry
# 197 animal
# 198 animate
# 199 ankle
# 200 annex
# 201 anniversary
# 202 announce
# 203 announcer
# 204 annoy
# 205 annoyance
# 206 annoyed
# 207 annoying
# 208 annoyingly
# 209 annually
# 210 anothet
# 211 anoying
# 212 answer
# 213 answering
# 214 ant
# 215 anther
# 216 anti
# 217 anticipate
# 218 antiga
# 219 antigua
# 220 antigua_guatemala
# 221 antiguena
# 222 antiquated
# 223 antique
# 224 antiquity
# 225 antiseptic
# 226 antiuga
# 227 anyhow
# 228 anymore
# 229 anytime
# 230 anyway
# 231 anyways
# 232 anywhere
# 233 apart
# 234 apartment
# 235 apathetic
# 236 apologetic
# 237 apologise
# 238 apologize
# 239 apology
# 240 app
# 241 appal
# 242 appalling
# 243 apparent
# 244 apparently
# 245 appeal
# 246 appealing
# 247 appear
# 248 appearance
# 249 appliance
# 250 apply
# 251 appoint
# 252 appointment
# 253 appreciate
# 254 approach
# 255 appropriate
# 256 approve
# 257 approx
# 258 approximately
# 259 aptly
# 260 arabica
# 261 arbitrarily
# 262 arbitrary
# 263 arch
# 264 archaic
# 265 architechture
# 266 architectural
# 267 architecture
# 268 area
# 269 arguably
# 270 argue
# 271 argument
# 272 arguye
# 273 aristocratic
# 274 arm
# 275 armchair
# 276 armed
# 277 armoire
# 278 army
# 279 around
# 280 around_pm
# 281 arrange
# 282 arrangement
# 283 array
# 284 arrival
# 285 arrive
# 286 arrived_late
# 287 arriving_late
# 288 arrogant
# 289 arrow
# 290 art
# 291 article
# 292 artifact
# 293 artificial
# 294 artisinal
# 295 artist
# 296 artistically
# 297 asbolutely
# 298 ash
# 299 ashe
# 300 aside
# 301 ask
# 302 asleep
# 303 aspect
# 304 aspire
# 305 asset
# 306 assign
# 307 assist
# 308 assistance
# 309 assistant
# 310 associate
# 311 assume
# 312 assure
# 313 asthma
# 314 astounded
# 315 astounding
# 316 aswell
# 317 atleast
# 318 atm
# 319 atmosfere
# 320 atmosphere
# 321 atrium
# 322 attach
# 323 attack
# 324 attempt
# 325 attend
# 326 attendant
# 327 attention
# 328 attentive
# 329 attitude
# 330 attracktive
# 331 attract
# 332 attraction
# 333 attractive
# 334 attractively
# 335 attribute
# 336 audacity
# 337 audible
# 338 audience
# 339 audio
# 340 audiovisual
# 341 aura
# 342 authentic
# 343 authenticity
# 344 authority
# 345 authorization
# 346 authorize
# 347 auto
# 348 automatic
# 349 automatically
# 350 autorisation
# 351 avaiability
# 352 avail
# 353 availabe
# 354 availability
# 355 availabilty
# 356 available
# 357 availiblity
# 358 avarge
# 359 average
# 360 aviod
# 361 avocado
# 362 avoid
# 363 await
# 364 awake
# 365 awaken
# 366 awakened
# 367 award
# 368 aware
# 369 awareness
# 370 away
# 371 aweful
# 372 awesome
# 373 awful
# 374 awfully
# 375 awhile
# 376 awkward
# 377 awkwardly
# 378 awning
# 379 awoken
# 380 baby
# 381 bacause
# 382 back
# 383 back_forth
# 384 backdrop
# 385 background
# 386 backing
# 387 backlog
# 388 backpack
# 389 backpacker
# 390 backpacket
# 391 backpacking
# 392 backwards
# 393 backyard
# 394 bad
# 395 badger
# 396 badly
# 397 baffle
# 398 bag
# 399 bagel
# 400 baggage
# 401 bail
# 402 bait
# 403 bake
# 404 bakery
# 405 balance
# 406 balanced
# 407 balcony
# 408 ball
# 409 banana
# 410 band
# 411 bang
# 412 banging
# 413 bank
# 414 banking
# 415 banquet
# 416 bar
# 417 barbaric
# 418 bare
# 419 barefoot
# 420 barely
# 421 bargain
# 422 bargaining
# 423 bark
# 424 barman
# 425 barrier
# 426 bartender
# 427 barter
# 428 base
# 429 basement
# 430 basic
# 431 basically
# 432 basicly
# 433 basil
# 434 basin
# 435 basis
# 436 basket
# 437 bass
# 438 bath
# 439 bathmat
# 440 bathrom
# 441 bathroom
# 442 bathtub
# 443 battered
# 444 battle
# 445 be
# 446 beach
# 447 beam
# 448 bean
# 449 bear
# 450 bearing
# 451 bearly
# 452 beat
# 453 beatiful
# 454 beauitiful
# 455 beautful
# 456 beautiful
# 457 beautifully
# 458 beauty
# 459 beautyr
# 460 become
# 461 becuase
# 462 bed
# 463 bed_comfortable
# 464 bed_dorm
# 465 bedbug
# 466 bedding
# 467 bedroom
# 468 beds_comfortable
# 469 bedsheet
# 470 bedside
# 471 bedspread
# 472 bedtime
# 473 bee
# 474 beef
# 475 beehive
# 476 beep
# 477 beer
# 478 beet
# 479 beforehand
# 480 befuddled
# 481 beg
# 482 begin
# 483 beginning
# 484 behalf
# 485 behave
# 486 behaved
# 487 behavior
# 488 behaviour
# 489 behind
# 490 beholder
# 491 beleive
# 492 belief
# 493 believe
# 494 bell
# 495 bellman
# 496 belong
# 497 belonging
# 498 bench
# 499 bend
# 500 benefit
# 501 berth
# 502 beside
# 503 best
# 504 best_the
# 505 best_thing
# 506 better
# 507 better_option
# 508 better_place
# 509 beverage
# 510 beware
# 511 bias
# 512 biased
# 513 bicycle
# 514 big
# 515 big_deal
# 516 bike
# 517 bilingual
# 518 bill
# 519 billing
# 520 billow
# 521 bin
# 522 bind
# 523 bird
# 524 birthday
# 525 bit
# 526 bite
# 527 bitten
# 528 bizarre
# 529 bizkit
# 530 black
# 531 blackbean
# 532 blackberry
# 533 blackout
# 534 bladder
# 535 blade
# 536 blame
# 537 bland
# 538 blank
# 539 blanket
# 540 blare
# 541 blast
# 542 blatant
# 543 bleach
# 544 bleak
# 545 blend
# 546 blind
# 547 blink
# 548 blizzard
# 549 block
# 550 blocks_away
# 551 blocks_central
# 552 blocks_main
# 553 blocks_parque
# 554 bloke
# 555 blonde
# 556 blood
# 557 bloody
# 558 blow
# 559 blue
# 560 blunt
# 561 blur
# 562 blurry
# 563 board
# 564 boarding
# 565 boast
# 566 boat
# 567 bodily
# 568 body
# 569 boggling
# 570 bogus
# 571 boiler
# 572 boisterous
# 573 bolt
# 574 bone
# 575 bonus
# 576 book
# 577 book_shuttle
# 578 bookcase
# 579 booked
# 580 booker
# 581 booking
# 582 booking_com
# 583 boom
# 584 booming
# 585 booster
# 586 booth
# 587 booze
# 588 border
# 589 borderline
# 590 bore
# 591 bored
# 592 boring
# 593 borrow
# 594 boss
# 595 botanical
# 596 bother
# 597 bothered
# 598 bothering
# 599 bottle
# 600 bottom
# 601 bounce
# 602 bouquet
# 603 bout
# 604 boutique
# 605 bow
# 606 bowl
# 607 box
# 608 boxer
# 609 boy
# 610 boycott
# 611 boyfriend
# 612 bracket
# 613 branch
# 614 brand
# 615 bre
# 616 bread
# 617 break
# 618 breakast
# 619 breakdown
# 620 breaker
# 621 breakfast
# 622 breakfast_buffet
# 623 breakfast_include
# 624 breakfast_serve
# 625 breakfast_served
# 626 breakfeast
# 627 breakfest
# 628 breaky
# 629 breath
# 630 breathe
# 631 breathing
# 632 breathtake
# 633 breed
# 634 breeding
# 635 breeze
# 636 breezy
# 637 brekky
# 638 brew
# 639 brick
# 640 brickwork
# 641 bride
# 642 brief
# 643 briefly
# 644 bright
# 645 brighten
# 646 brighter
# 647 brightly
# 648 brilliant
# 649 bring
# 650 broad
# 651 brochure
# 652 broken
# 653 broom
# 654 broth
# 655 brother
# 656 brown
# 657 brunch
# 658 brush
# 659 btw
# 660 bubbly
# 661 buck
# 662 bucket
# 663 buddy
# 664 budget
# 665 buff
# 666 buffer
# 667 buffet
# 668 bug
# 669 bugbear
# 670 build
# 671 building
# 672 bulb
# 673 bulk
# 674 bulky
# 675 bullet
# 676 bum
# 677 bump
# 678 bumpy
# 679 bun
# 680 bunch
# 681 bundle
# 682 bunk
# 683 bunkbed
# 684 burden
# 685 burger
# 686 burglar
# 687 burglerie
# 688 burlap
# 689 burly
# 690 burn
# 691 burner
# 692 bus
# 693 business
# 694 busticket
# 695 bustle
# 696 busy
# 697 busy_street
# 698 but
# 699 butt
# 700 butter
# 701 buttery
# 702 button
# 703 buy
# 704 buzz
# 705 buzzer
# 706 bygone
# 707 byway
# 708 ca
# 709 cab
# 710 cabin
# 711 cabinet
# 712 cable
# 713 cacophony
# 714 cafe
# 715 cake
# 716 calculate
# 717 caliber
# 718 call
# 719 calm
# 720 calorie
# 721 came_back
# 722 camera
# 723 camp
# 724 camping
# 725 campsite
# 726 can
# 727 cancel
# 728 cancelation
# 729 cancellable
# 730 cancellation
# 731 cancelling
# 732 candle
# 733 canopy
# 734 capable
# 735 capacity
# 736 cappuccino
# 737 captive
# 738 capture
# 739 car
# 740 carbonara
# 741 carbs
# 742 card
# 743 cardboard
# 744 cardholder
# 745 care
# 746 careful
# 747 carefully
# 748 careless
# 749 caring
# 750 carpet
# 751 carriage
# 752 carry
# 753 carrying
# 754 cart
# 755 carte
# 756 casa
# 757 casa_cristina
# 758 casa_del
# 759 casa_florencia
# 760 casa_rustica
# 761 case
# 762 cash
# 763 castle
# 764 casual
# 765 casually
# 766 cat
# 767 catch
# 768 catching
# 769 category
# 770 cater
# 771 cathedral
# 772 catholic
# 773 caulk
# 774 cause
# 775 caution
# 776 cautionary
# 777 cave
# 778 cavernous
# 779 cayenne
# 780 ceile
# 781 ceiling
# 782 ceiling_fan
# 783 ceilinged
# 784 celebration
# 785 cell
# 786 cement
# 787 cent
# 788 center
# 789 center_town
# 790 centimetre
# 791 central
# 792 central_america
# 793 central_park
# 794 central_square
# 795 centralize
# 796 centrally
# 797 centrally_locate
# 798 centrally_located
# 799 centre
# 800 centre_town
# 801 centric
# 802 century
# 803 ceramic
# 804 cereal
# 805 ceremony
# 806 certain
# 807 certainly
# 808 cess
# 809 chachke
# 810 chagrin
# 811 chain
# 812 chainsaw
# 813 chair
# 814 challenge
# 815 challenging
# 816 chamber
# 817 champagne
# 818 chance
# 819 chandelier
# 820 change
# 821 changed
# 822 channel
# 823 chaos
# 824 chaotic
# 825 character
# 826 characterful
# 827 characteristic
# 828 charge
# 829 charged_us
# 830 charger
# 831 charghe
# 832 charging
# 833 charismatic
# 834 charm
# 835 charming
# 836 chase
# 837 chat
# 838 chatter
# 839 chatty
# 840 cheap
# 841 cheaper
# 842 cheapest
# 843 cheapie
# 844 cheaply
# 845 cheappest
# 846 cheat
# 847 check
# 848 checkin
# 849 checking
# 850 checkout
# 851 cheek
# 852 cheese
# 853 cheesy
# 854 chef
# 855 chemical
# 856 chemically
# 857 chest
# 858 chewable
# 859 chexke
# 860 chicken
# 861 chief
# 862 child
# 863 chill
# 864 chilled
# 865 chilli
# 866 chilly
# 867 chime
# 868 chiminea
# 869 chimney
# 870 chinese
# 871 chip
# 872 chipper
# 873 chisel
# 874 chlore
# 875 chlorine
# 876 chocolate
# 877 choice
# 878 choose
# 879 chorizo
# 880 chowe
# 881 christian
# 882 church
# 883 church_bell
# 884 cigarette
# 885 cinder
# 886 cinema
# 887 circular
# 888 circulation
# 889 circumstance
# 890 circus
# 891 cistern
# 892 citronella
# 893 city
# 894 claim
# 895 clam
# 896 clammy
# 897 clang
# 898 clanging
# 899 clarify
# 900 class
# 901 classical
# 902 classify
# 903 classy
# 904 clatter
# 905 claustrophobic
# 906 clean
# 907 cleaned
# 908 cleaner
# 909 cleaness
# 910 cleanest
# 911 cleaning
# 912 cleanliness
# 913 clear
# 914 clearly
# 915 clerk
# 916 clever
# 917 client
# 918 clientele
# 919 climate
# 920 climatized
# 921 climb
# 922 climbing
# 923 clipping
# 924 cloakroom
# 925 clock
# 926 clog
# 927 cloged
# 928 cloister
# 929 cloistered
# 930 clomp
# 931 cloroxed
# 932 close
# 933 close_central
# 934 close_everythe
# 935 close_main
# 936 closed
# 937 closely
# 938 closet
# 939 closing
# 940 cloth
# 941 clothe
# 942 clothing
# 943 cloud
# 944 cloudy
# 945 cloying
# 946 club
# 947 clueless
# 948 clump
# 949 clunk
# 950 clunky
# 951 cluster
# 952 clutter
# 953 cluttered
# 954 coach
# 955 coat
# 956 coathooks
# 957 coaxed
# 958 cobalt
# 959 cobble
# 960 cobbled
# 961 cobblestone
# 962 cobdition
# 963 cobwebs
# 964 cocaine
# 965 cock
# 966 cockerel
# 967 cockroach
# 968 cocktail
# 969 code
# 970 coffe
# 971 coffee
# 972 coffee_tea
# 973 coherent
# 974 coincidentally
# 975 cold
# 976 colder
# 977 collapse
# 978 colleague
# 979 collect
# 980 collection
# 981 college
# 982 colombian
# 983 colonial
# 984 colonian
# 985 color
# 986 colorful
# 987 colour
# 988 com
# 989 comb
# 990 combination
# 991 combine
# 992 combined
# 993 combo
# 994 come
# 995 come_back
# 996 comfort
# 997 comfortable
# 998 comfortably
# 999 comforter
# 1000 comfy
# 1001 comfy_bed
# 1002 coming
# 1003 comission
# 1004 commanding
# 1005 comment
# 1006 commentary
# 1007 commercial
# 1008 commercialize
# 1009 commission
# 1010 commit
# 1011 commitment
# 1012 committed
# 1013 commode
# 1014 common
# 1015 common_area
# 1016 common_areas
# 1017 commotion
# 1018 communal
# 1019 communal_area
# 1020 commune
# 1021 communicate
# 1022 communication
# 1023 community
# 1024 comodor
# 1025 compact
# 1026 companion
# 1027 company
# 1028 comparable
# 1029 comparatively
# 1030 compare
# 1031 comparison
# 1032 compassion
# 1033 compensate
# 1034 compensation
# 1035 complaie
# 1036 complain
# 1037 complaining
# 1038 complaint
# 1039 complement
# 1040 complementary
# 1041 complete
# 1042 completely
# 1043 complex
# 1044 complicate
# 1045 complicated
# 1046 compliment
# 1047 complimentary
# 1048 compose
# 1049 compound
# 1050 compromise
# 1051 compulsory
# 1052 computation
# 1053 computer
# 1054 con
# 1055 concede
# 1056 conceivable
# 1057 concentrate
# 1058 concern
# 1059 concerned
# 1060 concert
# 1061 concierge
# 1062 conclude
# 1063 conclusion
# 1064 concrete
# 1065 concur
# 1066 condescending
# 1067 condiione
# 1068 condiment
# 1069 condition
# 1070 conditioner
# 1071 conducive
# 1072 conference
# 1073 confirm
# 1074 confirmation
# 1075 confortable
# 1076 confront
# 1077 confuse
# 1078 confused
# 1079 confusing
# 1080 confusion
# 1081 congregate
# 1082 connect
# 1083 connected
# 1084 connection
# 1085 conquistador
# 1086 conscience
# 1087 consent
# 1088 consequently
# 1089 conservation
# 1090 consider
# 1091 considerable
# 1092 considerably
# 1093 considerate
# 1094 consideration
# 1095 consist
# 1096 consistent
# 1097 consistently
# 1098 conspicuous
# 1099 constant
# 1100 constantly
# 1101 constitute
# 1102 constraint
# 1103 construction
# 1104 constructive
# 1105 consume
# 1106 consumer
# 1107 contact
# 1108 contain
# 1109 contained
# 1110 content
# 1111 contest
# 1112 context
# 1113 continental
# 1114 continual
# 1115 continually
# 1116 continue
# 1117 continued
# 1118 continuous
# 1119 continuously
# 1120 contra
# 1121 contract
# 1122 contradict
# 1123 contradictory
# 1124 contribute
# 1125 control
# 1126 convenience
# 1127 convenient
# 1128 conveniently
# 1129 conveniently_locate
# 1130 conveniently_located
# 1131 convenition
# 1132 convent
# 1133 conversation
# 1134 converse
# 1135 conversion
# 1136 convert
# 1137 convince
# 1138 convinced
# 1139 convinient
# 1140 cook
# 1141 cookie
# 1142 cooking
# 1143 cool
# 1144 cooler
# 1145 coolness
# 1146 cooperative
# 1147 coordinate
# 1148 copy
# 1149 cord
# 1150 cordial
# 1151 corn
# 1152 corner
# 1153 cornflake
# 1154 corporate
# 1155 correct
# 1156 correctly
# 1157 correspond
# 1158 corridor
# 1159 corrugated
# 1160 cost
# 1161 costa
# 1162 costly
# 1163 costumer
# 1164 cosy
# 1165 cot
# 1166 cottage
# 1167 cotton
# 1168 couch
# 1169 cough
# 1170 could
# 1171 could_easily
# 1172 could_hear
# 1173 could_see
# 1174 count
# 1175 counter
# 1176 counting
# 1177 countless
# 1178 country
# 1179 couple
# 1180 couple_block
# 1181 couple_day
# 1182 couple_night
# 1183 coupon
# 1184 course
# 1185 court
# 1186 court_yard
# 1187 courteous
# 1188 courtesy
# 1189 courtyard
# 1190 courtyard_garden
# 1191 courtyeard
# 1192 cousin
# 1193 cover
# 1194 covered
# 1195 cowbell
# 1196 cozy
# 1197 crab
# 1198 crack
# 1199 craft
# 1200 cram
# 1201 cramp
# 1202 cramped
# 1203 crank
# 1204 cranny
# 1205 crap
# 1206 crappy
# 1207 crash
# 1208 crawl
# 1209 crazy
# 1210 creak
# 1211 creaky
# 1212 cream
# 1213 create
# 1214 creater
# 1215 creative
# 1216 creature
# 1217 credit
# 1218 credit_card
# 1219 creepy
# 1220 crepe
# 1221 crew
# 1222 crib
# 1223 crime
# 1224 criminal
# 1225 crisis
# 1226 crispy
# 1227 criss
# 1228 criterion
# 1229 critical
# 1230 criticism
# 1231 criticize
# 1232 croissant
# 1233 cross
# 1234 crossing
# 1235 crow
# 1236 crowd
# 1237 crowded
# 1238 cruise
# 1239 crumble
# 1240 crummy
# 1241 cry
# 1242 crystal
# 1243 cube
# 1244 cubic
# 1245 cubicle
# 1246 cucumber
# 1247 culdnt
# 1248 culminate
# 1249 culprit
# 1250 cultural
# 1251 culture
# 1252 cumbersome
# 1253 cup
# 1254 cupboard
# 1255 cupoboard
# 1256 cupola
# 1257 curdle
# 1258 curfew
# 1259 curiosity
# 1260 curious
# 1261 curly
# 1262 currency
# 1263 currently
# 1264 curse
# 1265 curt
# 1266 curtain
# 1267 curvy
# 1268 cushion
# 1269 customer
# 1270 customer_service
# 1271 cut
# 1272 cute
# 1273 cutely
# 1274 cutlery
# 1275 cycle
# 1276 cycling
# 1277 cynical
# 1278 d
# 1279 daddy
# 1280 daily
# 1281 damage
# 1282 damn
# 1283 damp
# 1284 dampen
# 1285 damper
# 1286 dance
# 1287 dancing
# 1288 dangerous
# 1289 dangly
# 1290 dank
# 1291 dare
# 1292 dark
# 1293 darken
# 1294 darkness
# 1295 dash
# 1296 database
# 1297 date
# 1298 dated
# 1299 datum
# 1300 daughter
# 1301 daunt
# 1302 daunting
# 1303 dawn
# 1304 day
# 1305 daylight
# 1306 daytime
# 1307 de_la
# 1308 dead
# 1309 deaden
# 1310 deadly
# 1311 deal
# 1312 dealing
# 1313 dearly
# 1314 death
# 1315 deben
# 1316 debit
# 1317 debris
# 1318 decade
# 1319 decay
# 1320 deceive
# 1321 decent
# 1322 decently
# 1323 decide
# 1324 decided_stay
# 1325 decision
# 1326 decission
# 1327 deck
# 1328 declare
# 1329 decline
# 1330 decor
# 1331 decorate
# 1332 decorated
# 1333 decoration
# 1334 decorative
# 1335 deed
# 1336 deep
# 1337 deeply
# 1338 def
# 1339 defect
# 1340 defend
# 1341 defiantly
# 1342 deficiency
# 1343 definately
# 1344 define
# 1345 definite
# 1346 definitely
# 1347 definitively
# 1348 defraud
# 1349 defy
# 1350 degree
# 1351 dehumidifier
# 1352 delay
# 1353 deliberately
# 1354 delicious
# 1355 delicous
# 1356 delight
# 1357 delightful
# 1358 delightfully
# 1359 deliver
# 1360 delivery
# 1361 deluxe
# 1362 demand
# 1363 dense
# 1364 dental
# 1365 deny
# 1366 deodorize
# 1367 deodorizer
# 1368 depart
# 1369 departure
# 1370 depend
# 1371 depending
# 1372 depict
# 1373 depleated
# 1374 deposit
# 1375 depot
# 1376 depress
# 1377 depressing
# 1378 derogatory
# 1379 desaster
# 1380 descent
# 1381 describe
# 1382 descript
# 1383 description
# 1384 desert
# 1385 deserve
# 1386 design
# 1387 designer
# 1388 desirable
# 1389 desire
# 1390 desk
# 1391 desolate
# 1392 desperate
# 1393 desperately
# 1394 desperation
# 1395 dessert
# 1396 destination
# 1397 detached
# 1398 detail
# 1399 detailed
# 1400 detect
# 1401 detectable
# 1402 detector
# 1403 detergent
# 1404 deteriorate
# 1405 determine
# 1406 detour
# 1407 detract
# 1408 develop
# 1409 developed
# 1410 deviation
# 1411 device
# 1412 devil
# 1413 devoid
# 1414 devolving
# 1415 dial
# 1416 dice
# 1417 dictionary
# 1418 die
# 1419 diesel
# 1420 dietary
# 1421 differ
# 1422 difference
# 1423 different
# 1424 differently
# 1425 difficult
# 1426 difficult_find
# 1427 difficulty
# 1428 diffident
# 1429 dificult
# 1430 dig
# 1431 digital
# 1432 dim
# 1433 dime
# 1434 dimly
# 1435 din
# 1436 dine
# 1437 diner
# 1438 dingy
# 1439 dining
# 1440 dinner
# 1441 dinnertime
# 1442 dip
# 1443 dire
# 1444 direct
# 1445 directed
# 1446 direction
# 1447 directly
# 1448 dirt
# 1449 dirty
# 1450 disadvantage
# 1451 disagree
# 1452 disappear
# 1453 disappoint
# 1454 disappointed
# 1455 disappointing
# 1456 disappointingly
# 1457 disappointment
# 1458 disaster
# 1459 disastrous
# 1460 disclaimer
# 1461 disclose
# 1462 disco
# 1463 discomfort
# 1464 disconcerting
# 1465 disconnected
# 1466 discotheque
# 1467 discount
# 1468 discourage
# 1469 discourtious
# 1470 discover
# 1471 discretely
# 1472 discretion
# 1473 discrimination
# 1474 discuss
# 1475 discussion
# 1476 disease
# 1477 disgraceful
# 1478 disgust
# 1479 disgusted
# 1480 disgusting
# 1481 disgustingly
# 1482 dish
# 1483 dishearten
# 1484 dishonest
# 1485 dishonestly
# 1486 disinfectant
# 1487 disintereste
# 1488 disinterested
# 1489 disjoint
# 1490 dislike
# 1491 dismal
# 1492 dismay
# 1493 dismiss
# 1494 dismissive
# 1495 disorganised
# 1496 disorganization
# 1497 disorganize
# 1498 disorganized
# 1499 dispatcher
# 1500 dispenser
# 1501 display
# 1502 dispute
# 1503 disrepair
# 1504 disrespectful
# 1505 disruptive
# 1506 dissapointe
# 1507 dissapointed
# 1508 dissapointment
# 1509 dissappointe
# 1510 disservice
# 1511 distance
# 1512 distant
# 1513 distinct
# 1514 distinguish
# 1515 distraction
# 1516 distribution
# 1517 district
# 1518 disturb
# 1519 disturbance
# 1520 disturbed
# 1521 dive
# 1522 diversity
# 1523 do
# 1524 doable
# 1525 docce
# 1526 doctor
# 1527 dodgy
# 1528 doen
# 1529 dog
# 1530 dole
# 1531 dollar
# 1532 doller
# 1533 dolly
# 1534 dome
# 1535 domestic
# 1536 dominate
# 1537 donation
# 1538 door
# 1539 door_open
# 1540 doorbell
# 1541 doorman
# 1542 dorm
# 1543 dormitory
# 1544 dot
# 1545 double
# 1546 double_be
# 1547 double_bed
# 1548 double_room
# 1549 doublebed
# 1550 doubt
# 1551 down
# 1552 downcast
# 1553 downer
# 1554 downfall
# 1555 downgrade
# 1556 downhill
# 1557 download
# 1558 downright
# 1559 downside
# 1560 downstairs
# 1561 downtown
# 1562 downwards
# 1563 dozen
# 1564 drab
# 1565 drag
# 1566 drain
# 1567 drama
# 1568 dramatic
# 1569 draw
# 1570 drawback
# 1571 drawer
# 1572 dreadful
# 1573 dreary
# 1574 dress
# 1575 dresser
# 1576 dressing
# 1577 dribble
# 1578 drink
# 1579 drinking
# 1580 drinking_water
# 1581 drip
# 1582 drive
# 1583 driver
# 1584 driveway
# 1585 driving
# 1586 drizzle
# 1587 drop
# 1588 dropping
# 1589 drown
# 1590 drug
# 1591 drugged
# 1592 drum
# 1593 drummer
# 1594 drunk
# 1595 drunken
# 1596 dry
# 1597 dryer
# 1598 duck
# 1599 dude
# 1600 due
# 1601 due_lack
# 1602 dueling
# 1603 dumb
# 1604 dump
# 1605 dungeon
# 1606 durable
# 1607 duration
# 1608 dust
# 1609 dusting
# 1610 dusty
# 1611 duty
# 1612 duvet
# 1613 dvd
# 1614 eager
# 1615 ear
# 1616 earful
# 1617 early
# 1618 early_hour
# 1619 early_morne
# 1620 earn
# 1621 earplug
# 1622 earth
# 1623 earth_lodge
# 1624 ease
# 1625 easiest
# 1626 easily
# 1627 easter
# 1628 easy
# 1629 easy_walk
# 1630 eat
# 1631 eatable
# 1632 eater
# 1633 echo
# 1634 echoey
# 1635 echos
# 1636 eco
# 1637 economical
# 1638 ect
# 1639 edge
# 1640 edible
# 1641 eek
# 1642 eery
# 1643 eeughhh
# 1644 effect
# 1645 effective
# 1646 effectively
# 1647 efficiency
# 1648 efficient
# 1649 efficiently
# 1650 effort
# 1651 eg
# 1652 egg
# 1653 egregious
# 1654 egregiously
# 1655 egyptian
# 1656 either
# 1657 el_carmen
# 1658 elaborate
# 1659 elderly
# 1660 election
# 1661 electric
# 1662 electrical
# 1663 electricity
# 1664 electrify
# 1665 electrocute
# 1666 electronic
# 1667 elegance
# 1668 element
# 1669 elementary
# 1670 elevate
# 1671 elevation
# 1672 elevator
# 1673 eliminate
# 1674 elliptical
# 1675 else
# 1676 elsewhere
# 1677 email
# 1678 email_saye
# 1679 embargo
# 1680 embarrass
# 1681 embarrassed
# 1682 embarrassing
# 1683 emerge
# 1684 emergency
# 1685 emission
# 1686 empathetic
# 1687 emphasise
# 1688 emphasize
# 1689 employee
# 1690 empty
# 1691 en_la
# 1692 enchant
# 1693 enchilada
# 1694 encino
# 1695 encircle
# 1696 enclave
# 1697 enclose
# 1698 encounter
# 1699 encourage
# 1700 end
# 1701 endemic
# 1702 endorse
# 1703 endorsement
# 1704 endup
# 1705 endure
# 1706 energize
# 1707 energy
# 1708 enforce
# 1709 enfuriatingly
# 1710 engage
# 1711 engaging
# 1712 engine
# 1713 engish
# 1714 english
# 1715 english_speake
# 1716 english_speaking
# 1717 enhance
# 1718 enjoy
# 1719 enjoyable
# 1720 enjoyed_stay
# 1721 enjoyment
# 1722 enojy
# 1723 enormous
# 1724 enough
# 1725 enquire
# 1726 ensuite
# 1727 ensure
# 1728 entail
# 1729 enter
# 1730 entertainment
# 1731 enthral
# 1732 enthused
# 1733 enthusiasm
# 1734 enthusiastic
# 1735 entire
# 1736 entirely
# 1737 entitle
# 1738 entrance
# 1739 entree
# 1740 entropy
# 1741 entry
# 1742 envelop
# 1743 envelope
# 1744 environment
# 1745 epic
# 1746 episode
# 1747 equal
# 1748 equally
# 1749 equip
# 1750 equiped
# 1751 equipment
# 1752 equivalent
# 1753 equpped
# 1754 er
# 1755 era
# 1756 error
# 1757 erupt
# 1758 escalate
# 1759 escape
# 1760 escort
# 1761 especially
# 1762 espresso
# 1763 espy
# 1764 essence
# 1765 essential
# 1766 essentially
# 1767 establish
# 1768 establishment
# 1769 estate
# 1770 esthetically
# 1771 estimate
# 1772 etc
# 1773 ethic
# 1774 etiquette
# 1775 euro
# 1776 euro_maya
# 1777 euromaya
# 1778 evaporate
# 1779 eve
# 1780 even
# 1781 even_though
# 1782 evening
# 1783 event
# 1784 eventhought
# 1785 eventually
# 1786 ever
# 1787 every_minute
# 1788 every_morne
# 1789 every_morning
# 1790 every_single
# 1791 every_time
# 1792 everyday
# 1793 everythin
# 1794 everything_goe
# 1795 everything_going
# 1796 everytime
# 1797 everywhere
# 1798 evety
# 1799 evidence
# 1800 evidently
# 1801 evrithing
# 1802 ex
# 1803 exact
# 1804 exactly
# 1805 example
# 1806 exceed
# 1807 exceedingly
# 1808 excelent
# 1809 excellent
# 1810 exception
# 1811 exceptional
# 1812 exceptionally
# 1813 excessive
# 1814 excessively
# 1815 exchamge
# 1816 exchange
# 1817 exchange_rate
# 1818 excite
# 1819 excited
# 1820 exclaim
# 1821 exclusive
# 1822 exclusivity
# 1823 excursion
# 1824 excuse
# 1825 execute
# 1826 executive
# 1827 exhaused
# 1828 exhaust
# 1829 exhausted
# 1830 exist
# 1831 existence
# 1832 exit
# 1833 exotic
# 1834 expat
# 1835 expect
# 1836 expectation
# 1837 expected
# 1838 expedia
# 1839 expense
# 1840 expensive
# 1841 experience
# 1842 experienced
# 1843 experince
# 1844 expire
# 1845 expirience
# 1846 explaiend
# 1847 explain
# 1848 explanation
# 1849 explicit
# 1850 explicitly
# 1851 explore
# 1852 expose
# 1853 exposition
# 1854 express
# 1855 expression
# 1856 exquisite
# 1857 extend
# 1858 extended
# 1859 extension
# 1860 extensive
# 1861 extensively
# 1862 extent
# 1863 exterior
# 1864 extern
# 1865 external
# 1866 extra
# 1867 extracurricular
# 1868 extraordinarily
# 1869 extraordinary
# 1870 extreme
# 1871 extremely
# 1872 extremely_loud
# 1873 exuberance
# 1874 exude
# 1875 eye
# 1876 fabric
# 1877 fabricate
# 1878 fabulous
# 1879 facade
# 1880 face
# 1881 faced
# 1882 facelift
# 1883 faciliie
# 1884 facility
# 1885 fact
# 1886 factor
# 1887 fade
# 1888 faece
# 1889 fail
# 1890 faint
# 1891 fair
# 1892 fairly
# 1893 fairness
# 1894 faith
# 1895 fake
# 1896 fall
# 1897 false
# 1898 fame
# 1899 famiky
# 1900 familiar
# 1901 familiarity
# 1902 family
# 1903 famous
# 1904 fan
# 1905 fancy
# 1906 fantastic
# 1907 far
# 1908 faraway
# 1909 fare
# 1910 farm
# 1911 farmland
# 1912 fart
# 1913 farther
# 1914 fascinating
# 1915 fashion
# 1916 fashioned
# 1917 fast
# 1918 fatal
# 1919 father
# 1920 fatty
# 1921 faucet
# 1922 fault
# 1923 faulty
# 1924 faux
# 1925 favor
# 1926 favorite
# 1927 favour
# 1928 favourable
# 1929 favourably
# 1930 favourite
# 1931 fb
# 1932 fear
# 1933 feasible
# 1934 feature
# 1935 fece
# 1936 fee
# 1937 feedback
# 1938 feel
# 1939 feel_comfortable
# 1940 feeling
# 1941 feels_like
# 1942 fellow
# 1943 felt_like
# 1944 felt_safe
# 1945 female
# 1946 fern
# 1947 fernando
# 1948 festival
# 1949 festivity
# 1950 few
# 1951 fiance
# 1952 fiasco
# 1953 fibre
# 1954 fibreglass
# 1955 field
# 1956 fiesta
# 1957 fig
# 1958 fight
# 1959 figure
# 1960 filch
# 1961 file
# 1962 filet
# 1963 filfille
# 1964 fill
# 1965 fillet
# 1966 film
# 1967 filter
# 1968 filtered_water
# 1969 filth
# 1970 filthy
# 1971 final
# 1972 finally
# 1973 finally_got
# 1974 financial
# 1975 fincas
# 1976 find
# 1977 find_somethe
# 1978 find_something
# 1979 finding
# 1980 fine
# 1981 finger
# 1982 finish
# 1983 finishing
# 1984 fire
# 1985 firecracker
# 1986 fireplace
# 1987 firewood
# 1988 firework
# 1989 firm
# 1990 first
# 1991 first_floor
# 1992 first_night
# 1993 firstable
# 1994 firstly
# 1995 firts
# 1996 fish
# 1997 fit
# 1998 fitted
# 1999 fix
# 2000 fixture
# 2001 flag
# 2002 flame
# 2003 flan
# 2004 flash
# 2005 flashlight
# 2006 flashpacker
# 2007 flask
# 2008 flat
# 2009 flatly
# 2010 flavor
# 2011 flavorless
# 2012 flavour
# 2013 flaw
# 2014 flea
# 2015 flexibility
# 2016 flexible
# 2017 flicker
# 2018 flight
# 2019 flimsy
# 2020 flip
# 2021 flipped
# 2022 float
# 2023 flock
# 2024 flood
# 2025 floor
# 2026 flooring
# 2027 flora
# 2028 floral
# 2029 flore
# 2030 flow
# 2031 flower
# 2032 flowering
# 2033 fluent
# 2034 fluffy
# 2035 fluid
# 2036 fluorescent
# 2037 flush
# 2038 flushed
# 2039 flustered
# 2040 flute
# 2041 fly
# 2042 fob
# 2043 focus
# 2044 focusse
# 2045 foe
# 2046 fold
# 2047 folk
# 2048 follow
# 2049 followed
# 2050 fond
# 2051 font
# 2052 food
# 2053 fool
# 2054 foolish
# 2055 foot
# 2056 footage
# 2057 footing
# 2058 footstep
# 2059 force
# 2060 forced
# 2061 forceful
# 2062 foreign
# 2063 foreigner
# 2064 foremost
# 2065 foresee
# 2066 foresight
# 2067 forest
# 2068 forever
# 2069 forewarn
# 2070 forget
# 2071 forgettable
# 2072 forgivable
# 2073 forgiving
# 2074 foriegn
# 2075 fork
# 2076 form
# 2077 former
# 2078 formerly
# 2079 forthcoming
# 2080 fortinately
# 2081 fortunate
# 2082 fortunately
# 2083 fortune
# 2084 forward
# 2085 foul
# 2086 fountain
# 2087 four_night
# 2088 fourth
# 2089 foyer
# 2090 frame
# 2091 franchise
# 2092 frankly
# 2093 frantic
# 2094 fraternity
# 2095 fraud
# 2096 fraudulent
# 2097 freak
# 2098 free
# 2099 free_breakfast
# 2100 free_coffee
# 2101 free_internet
# 2102 free_wifi
# 2103 freedom
# 2104 freely
# 2105 freeze
# 2106 freezer
# 2107 freezing
# 2108 freindly
# 2109 french
# 2110 frequent
# 2111 frequently
# 2112 fresh
# 2113 fresh_air
# 2114 freshen
# 2115 freshener
# 2116 friday
# 2117 fridge
# 2118 friend
# 2119 friendliness
# 2120 friendly
# 2121 friendly_helpful
# 2122 frightening
# 2123 frigid
# 2124 frijol
# 2125 frill
# 2126 fringe
# 2127 front
# 2128 front_desk
# 2129 front_door
# 2130 frontdesk
# 2131 frost
# 2132 frosted
# 2133 fruit
# 2134 fruitless
# 2135 frustrate
# 2136 frustrated
# 2137 frustrating
# 2138 frustratingly
# 2139 frustration
# 2140 fry
# 2141 frying
# 2142 fscilitie
# 2143 full
# 2144 fully
# 2145 fully_booke
# 2146 fume
# 2147 fumigate
# 2148 fun
# 2149 function
# 2150 functional
# 2151 functionality
# 2152 fund
# 2153 funky
# 2154 funnel
# 2155 funnily
# 2156 funny
# 2157 furious
# 2158 furnish
# 2159 furnished
# 2160 furnishing
# 2161 furniture
# 2162 furthermore
# 2163 furthest
# 2164 fuss
# 2165 fustrated
# 2166 future
# 2167 gadget
# 2168 gag
# 2169 gain
# 2170 gallery
# 2171 gallon
# 2172 galore
# 2173 game
# 2174 gap
# 2175 garage
# 2176 garbage
# 2177 garden
# 2178 garner
# 2179 gas
# 2180 gastronomic
# 2181 gate
# 2182 gated
# 2183 gather
# 2184 gave_u
# 2185 gave_us
# 2186 gay
# 2187 gear
# 2188 geckos
# 2189 gel
# 2190 gem
# 2191 general
# 2192 generally
# 2193 generation
# 2194 generator
# 2195 generic
# 2196 generous
# 2197 gentleman
# 2198 genuine
# 2199 genuinely
# 2200 german
# 2201 gesture
# 2202 get
# 2203 getaway
# 2204 ghost
# 2205 giant
# 2206 gift
# 2207 giggle
# 2208 ginger
# 2209 girl
# 2210 girl_reception
# 2211 girlfriend
# 2212 give
# 2213 give_u
# 2214 give_us
# 2215 giveaway
# 2216 glad
# 2217 gladly
# 2218 glam
# 2219 glamping
# 2220 glance
# 2221 glare
# 2222 glass
# 2223 glazing
# 2224 glimpse
# 2225 gloomy
# 2226 glorious
# 2227 glow
# 2228 glowing
# 2229 go
# 2230 go_back
# 2231 go_somewhere
# 2232 goal
# 2233 going
# 2234 golden
# 2235 gone
# 2236 good
# 2237 good_location
# 2238 good_size
# 2239 good_value
# 2240 goodness
# 2241 goose
# 2242 gorgeous
# 2243 gospel
# 2244 gossip
# 2245 got
# 2246 gothic
# 2247 gotten
# 2248 gouge
# 2249 gove
# 2250 grab
# 2251 grace
# 2252 gracious
# 2253 gradation
# 2254 grade
# 2255 grading
# 2256 gradually
# 2257 graduate
# 2258 grand
# 2259 grandeur
# 2260 grandparent
# 2261 granola
# 2262 grant
# 2263 granted
# 2264 grateful
# 2265 grave
# 2266 gray
# 2267 grear
# 2268 grease
# 2269 great
# 2270 great_location
# 2271 great_view
# 2272 great_views
# 2273 greatly
# 2274 greed
# 2275 greedy
# 2276 green
# 2277 greenhouse
# 2278 greet
# 2279 greeting
# 2280 grey
# 2281 grid
# 2282 grief
# 2283 grill
# 2284 grim
# 2285 grimmy
# 2286 grind
# 2287 gringo
# 2288 gripe
# 2289 gristle
# 2290 grocery
# 2291 grope
# 2292 gross
# 2293 grossly
# 2294 grotty
# 2295 grouch
# 2296 ground
# 2297 ground_floor
# 2298 grounds_beautiful
# 2299 group
# 2300 grout
# 2301 grow
# 2302 grubby
# 2303 grudging
# 2304 gtq
# 2305 guacamole
# 2306 guarantee
# 2307 guard
# 2308 guardian
# 2309 guatemala_city
# 2310 guatemalan
# 2311 guatemalan_standard
# 2312 guess
# 2313 guest
# 2314 guesthouse
# 2315 guide
# 2316 guidebook
# 2317 guideline
# 2318 guilty
# 2319 guitar
# 2320 gun
# 2321 gut
# 2322 guy
# 2323 gym
# 2324 habitation
# 2325 hacienda
# 2326 hack
# 2327 hacking
# 2328 hair
# 2329 hairdryer
# 2330 haired
# 2331 hairpin
# 2332 half
# 2333 half_block
# 2334 half_hour
# 2335 half_price
# 2336 hall
# 2337 hallroom
# 2338 hallway
# 2339 ham
# 2340 hamburger
# 2341 hammer
# 2342 hammering
# 2343 hammock
# 2344 hand
# 2345 handbag
# 2346 handed
# 2347 handicap
# 2348 handicraft
# 2349 handle
# 2350 handmade
# 2351 handsome
# 2352 handtowel
# 2353 handwashed
# 2354 handy
# 2355 hang
# 2356 hang_clothe
# 2357 hanger
# 2358 hanging
# 2359 hangout
# 2360 haphazard
# 2361 happen
# 2362 happend
# 2363 happende
# 2364 happily
# 2365 happy
# 2366 happy_hour
# 2367 hard
# 2368 harder
# 2369 hardly
# 2370 harvest
# 2371 hash
# 2372 hassle
# 2373 haste
# 2374 hasty
# 2375 hat
# 2376 hate
# 2377 hateful
# 2378 haul
# 2379 have
# 2380 havoc
# 2381 hawker
# 2382 hazard
# 2383 head
# 2384 headache
# 2385 headboard
# 2386 heading
# 2387 headphone
# 2388 heal
# 2389 health
# 2390 healthy
# 2391 heap
# 2392 hear
# 2393 hear_everythe
# 2394 hear_everything
# 2395 hear_people
# 2396 hearing
# 2397 heart
# 2398 heartedly
# 2399 heartless
# 2400 heat
# 2401 heated
# 2402 heater
# 2403 heating
# 2404 heavily
# 2405 heavy
# 2406 hectic
# 2407 heed
# 2408 heel
# 2409 height
# 2410 heighten
# 2411 hell
# 2412 help
# 2413 helpful
# 2414 helpfull
# 2415 helpfulness
# 2416 hen
# 2417 hence
# 2418 herb
# 2419 herd
# 2420 hermetically
# 2421 hesitant
# 2422 hesitate
# 2423 hesitation
# 2424 hidden
# 2425 hide
# 2426 high
# 2427 highlight
# 2428 highly
# 2429 highly_recommend
# 2430 highway
# 2431 hike
# 2432 hiker
# 2433 hiking
# 2434 hill
# 2435 hindsight
# 2436 hinge
# 2437 hint
# 2438 hip
# 2439 hippie
# 2440 hippy
# 2441 hipster
# 2442 hire
# 2443 hispanic
# 2444 historic
# 2445 historical
# 2446 history
# 2447 hit
# 2448 hitch
# 2449 hoard
# 2450 hoarde
# 2451 hoarder
# 2452 hobble
# 2453 hog
# 2454 hold
# 2455 hole
# 2456 holiday
# 2457 holy
# 2458 home
# 2459 homely
# 2460 homemade
# 2461 homeowner
# 2462 homestay
# 2463 homey
# 2464 honest
# 2465 honestly
# 2466 honesty
# 2467 honey
# 2468 honeymoon
# 2469 honor
# 2470 honorable
# 2471 honored
# 2472 hooe
# 2473 hook
# 2474 hop
# 2475 hope
# 2476 hopeful
# 2477 hopefully
# 2478 hoping
# 2479 horizon
# 2480 horizontal
# 2481 horn
# 2482 horrendous
# 2483 horrible
# 2484 horribly
# 2485 horrific
# 2486 horror
# 2487 horse
# 2488 hospitable
# 2489 hospital
# 2490 hospitalise
# 2491 hospitality
# 2492 hospitalize
# 2493 host
# 2494 hostage
# 2495 hostal
# 2496 hostel
# 2497 hostels_antigua
# 2498 hostess
# 2499 hostile
# 2500 hot
# 2501 hot_shower
# 2502 hot_tub
# 2503 hot_water
# 2504 hotel
# 2505 hoteling
# 2506 hotels_antigua
# 2507 hotstel
# 2508 hotter
# 2509 hotwater
# 2510 hour
# 2511 hourly
# 2512 house
# 2513 housekeep
# 2514 housekeeper
# 2515 housekeeping
# 2516 houseman
# 2517 housing
# 2518 hover
# 2519 however
# 2520 howl
# 2521 hr
# 2522 hrs
# 2523 hte
# 2524 hubbub
# 2525 huespede
# 2526 huge
# 2527 hugely
# 2528 hum
# 2529 human
# 2530 humbly
# 2531 humid
# 2532 humidity
# 2533 hummingbird
# 2534 humorous
# 2535 hunch
# 2536 hundred
# 2537 hung
# 2538 hungover
# 2539 hungry
# 2540 hunt
# 2541 hurry
# 2542 hurt
# 2543 husband
# 2544 hushed
# 2545 hustle
# 2546 hut
# 2547 hutch
# 2548 hygiene
# 2549 hygienic
# 2550 hype
# 2551 ice
# 2552 idea
# 2553 ideal
# 2554 ideally
# 2555 identical
# 2556 identity
# 2557 idiotic
# 2558 ie
# 2559 iffy
# 2560 ignorant
# 2561 ignore
# 2562 iin
# 2563 ill
# 2564 illegal
# 2565 illogically
# 2566 illuminate
# 2567 image
# 2568 imaginable
# 2569 imagination
# 2570 imagine
# 2571 imho
# 2572 immacualtely
# 2573 immature
# 2574 immediate
# 2575 immediately
# 2576 immense
# 2577 immersion
# 2578 imminent
# 2579 immune
# 2580 impact
# 2581 impecable
# 2582 impeccable
# 2583 impersonal
# 2584 imply
# 2585 impolite
# 2586 import
# 2587 importance
# 2588 important
# 2589 importantly
# 2590 imporve
# 2591 impose
# 2592 imposible
# 2593 impossible
# 2594 impossible_sleep
# 2595 impractical
# 2596 impractically
# 2597 impress
# 2598 impressed
# 2599 impression
# 2600 imprint
# 2601 improve
# 2602 improved
# 2603 improvement
# 2604 improvise
# 2605 in
# 2606 inability
# 2607 inadequate
# 2608 inappropriate
# 2609 inappropriately
# 2610 incapable
# 2611 incense
# 2612 incentive
# 2613 incessant
# 2614 incessantly
# 2615 inch
# 2616 incident
# 2617 incl
# 2618 inclement
# 2619 incline
# 2620 inclined
# 2621 include
# 2622 include_breakfast
# 2623 included_breakfast
# 2624 inclusive
# 2625 incoming
# 2626 incompetent
# 2627 incomplete
# 2628 inconsiderate
# 2629 inconsistent
# 2630 inconsistently
# 2631 inconvenience
# 2632 inconvenient
# 2633 inconvient
# 2634 inconvinience
# 2635 incorporate
# 2636 incorrect
# 2637 increase
# 2638 incredible
# 2639 incredibly
# 2640 incur
# 2641 indeed
# 2642 independent
# 2643 indescribable
# 2644 indicate
# 2645 indifference
# 2646 indifferent
# 2647 individual
# 2648 indoor
# 2649 induce
# 2650 induration
# 2651 industrial
# 2652 industry
# 2653 inedible
# 2654 inefficient
# 2655 ineptitude
# 2656 inevitably
# 2657 inexpensive
# 2658 inexperienced
# 2659 inexplicably
# 2660 infect
# 2661 inferior
# 2662 infest
# 2663 infestation
# 2664 infested
# 2665 infinite
# 2666 infinitely
# 2667 infirmed
# 2668 inflated
# 2669 inflexible
# 2670 influence
# 2671 info
# 2672 inform
# 2673 information
# 2674 informative
# 2675 informed
# 2676 infrastructure
# 2677 infrequent
# 2678 infuriating
# 2679 ingredient
# 2680 inhabitant
# 2681 inhibition
# 2682 inhospitable
# 2683 inhospitality
# 2684 initial
# 2685 initially
# 2686 initiative
# 2687 injure
# 2688 injury
# 2689 inly
# 2690 inn
# 2691 inner
# 2692 inoperable
# 2693 inputte
# 2694 inquire
# 2695 inquiry
# 2696 insane
# 2697 insanely
# 2698 insect
# 2699 insecticide
# 2700 insecure
# 2701 inside
# 2702 insight
# 2703 insincere
# 2704 insist
# 2705 insomniac
# 2706 insomniacs
# 2707 inspect
# 2708 inspection
# 2709 inspite
# 2710 instal
# 2711 install
# 2712 installation
# 2713 instance
# 2714 instant
# 2715 instantly
# 2716 inste
# 2717 instead
# 2718 institution
# 2719 instruct
# 2720 instruction
# 2721 insufficient
# 2722 insulate
# 2723 insulation
# 2724 insulator
# 2725 insult
# 2726 insurance
# 2727 intact
# 2728 intellect
# 2729 intend
# 2730 intended
# 2731 intense
# 2732 intensly
# 2733 intention
# 2734 interact
# 2735 interaction
# 2736 interest
# 2737 interested
# 2738 interesting
# 2739 interior
# 2740 intermittent
# 2741 internal
# 2742 international
# 2743 internet
# 2744 interrupt
# 2745 interrupted
# 2746 interruption
# 2747 interval
# 2748 intetesting
# 2749 intoxicated
# 2750 intrepid
# 2751 intriguing
# 2752 intrusiuve
# 2753 intrusive
# 2754 invade
# 2755 invasion
# 2756 inventory
# 2757 invest
# 2758 investigate
# 2759 investigation
# 2760 investment
# 2761 invite
# 2762 inviting
# 2763 involve
# 2764 inward
# 2765 inwards
# 2766 iphone
# 2767 irish
# 2768 iron
# 2769 ironic
# 2770 ironing
# 2771 irony
# 2772 irresponsible
# 2773 irritate
# 2774 irritating
# 2775 ish
# 2776 isolate
# 2777 isolated
# 2778 isolation
# 2779 israeli
# 2780 issue
# 2781 italian
# 2782 itch
# 2783 itchy
# 2784 item
# 2785 itzamna
# 2786 jabber
# 2787 jacuzzi
# 2788 jacuzzis
# 2789 jaded
# 2790 jail
# 2791 jam
# 2792 jar
# 2793 jazz
# 2794 jet
# 2795 jetlagge
# 2796 jetlagged
# 2797 job
# 2798 join
# 2799 joint
# 2800 joke
# 2801 jokingly
# 2802 journey
# 2803 joy
# 2804 judge
# 2805 judgement
# 2806 jug
# 2807 juggle
# 2808 juice
# 2809 juinior
# 2810 jump
# 2811 jumping
# 2812 junior
# 2813 junk
# 2814 junky
# 2815 justify
# 2816 karaoke
# 2817 keen
# 2818 keep
# 2819 kettle
# 2820 key
# 2821 keyhole
# 2822 keyword
# 2823 kg
# 2824 kick
# 2825 kicker
# 2826 kid
# 2827 kiddie
# 2828 kiddo
# 2829 kill
# 2830 kilometer
# 2831 kind
# 2832 kinda
# 2833 kindly
# 2834 kindness
# 2835 king
# 2836 kingsize
# 2837 kitchen
# 2838 kitchenette
# 2839 kitschy
# 2840 km
# 2841 knackered
# 2842 knee
# 2843 knit
# 2844 knob
# 2845 knock
# 2846 knot
# 2847 know
# 2848 knowing
# 2849 knowledgable
# 2850 knowledge
# 2851 knowledgeable
# 2852 la_merce
# 2853 la_merced
# 2854 label
# 2855 lack
# 2856 lack_air
# 2857 lacked
# 2858 lacquer
# 2859 ladder
# 2860 lady
# 2861 lag
# 2862 laide
# 2863 lake
# 2864 lake_atitlan
# 2865 lame
# 2866 lamp
# 2867 land
# 2868 landing
# 2869 landmark
# 2870 landscape
# 2871 landscaped
# 2872 landscaping
# 2873 language
# 2874 lanquin
# 2875 lap
# 2876 lapse
# 2877 laptop
# 2878 large
# 2879 largely
# 2880 largish
# 2881 last
# 2882 last_minute
# 2883 last_night
# 2884 lastly
# 2885 late
# 2886 late_evene
# 2887 late_evening
# 2888 late_night
# 2889 latecomer
# 2890 later
# 2891 latin
# 2892 latin_america
# 2893 latter
# 2894 laugh
# 2895 laughing
# 2896 laughter
# 2897 launder
# 2898 laundry
# 2899 laundry_service
# 2900 lava
# 2901 lavatory
# 2902 lave
# 2903 law
# 2904 lay
# 2905 layer
# 2906 layout
# 2907 laze
# 2908 laziness
# 2909 lazy
# 2910 lead
# 2911 leader
# 2912 leadership
# 2913 leak
# 2914 leaky
# 2915 learn
# 2916 lease
# 2917 least
# 2918 leave
# 2919 ledge
# 2920 leech
# 2921 left
# 2922 leftover
# 2923 leg
# 2924 legally
# 2925 legend
# 2926 legendary
# 2927 legitimate
# 2928 leisure
# 2929 leisurely
# 2930 lemon
# 2931 lend
# 2932 length
# 2933 lengthy
# 2934 less
# 2935 lesson
# 2936 let
# 2937 letdown
# 2938 lettuce
# 2939 level
# 2940 liar
# 2941 lid
# 2942 lie
# 2943 lier
# 2944 life
# 2945 lifetime
# 2946 lift
# 2947 light
# 2948 light_sleeper
# 2949 lightbulb
# 2950 lighting
# 2951 lightly
# 2952 like
# 2953 likely
# 2954 liking
# 2955 lilliputian
# 2956 limit
# 2957 limited
# 2958 limitless
# 2959 limp
# 2960 line
# 2961 linen
# 2962 liner
# 2963 lining
# 2964 link
# 2965 lipstick
# 2966 liquid
# 2967 liquor
# 2968 list
# 2969 listen
# 2970 lit
# 2971 literal
# 2972 literally
# 2973 little
# 2974 little_bit
# 2975 live
# 2976 live_music
# 2977 lively
# 2978 living
# 2979 living_room
# 2980 livingroom
# 2981 loaction
# 2982 load
# 2983 loan
# 2984 lobby
# 2985 local
# 2986 locale
# 2987 locate
# 2988 located
# 2989 located_near
# 2990 location
# 2991 location_close
# 2992 location_great
# 2993 location_perfect
# 2994 lock
# 2995 lockable
# 2996 locked
# 2997 locker
# 2998 locking
# 2999 loco
# 3000 lod
# 3001 lodge
# 3002 lodging
# 3003 loft
# 3004 log
# 3005 lonely
# 3006 lonely_planet
# 3007 long
# 3008 long_time
# 3009 longer
# 3010 look
# 3011 look_like
# 3012 looked_like
# 3013 looking
# 3014 lookout
# 3015 looks_like
# 3016 looks_nice
# 3017 loos
# 3018 loose
# 3019 lore
# 3020 lorry
# 3021 lose
# 3022 loss
# 3023 lost
# 3024 lot
# 3025 lot_noise
# 3026 lots
# 3027 lotsa
# 3028 loud
# 3029 loud_music
# 3030 louder
# 3031 loudly
# 3032 loudspeaker
# 3033 lounge
# 3034 lounger
# 3035 lousy
# 3036 louvered
# 3037 louvre
# 3038 love
# 3039 loved
# 3040 lovely
# 3041 lover
# 3042 lovey
# 3043 low
# 3044 low_season
# 3045 lower
# 3046 lttle
# 3047 luck
# 3048 luckily
# 3049 lucky
# 3050 ludicrous
# 3051 luggage
# 3052 luguage
# 3053 luke_warm
# 3054 lukewarm
# 3055 luminous
# 3056 lump
# 3057 lumpy
# 3058 lunch
# 3059 lunch_dinner
# 3060 lurk
# 3061 lush
# 3062 luxurious
# 3063 luxurius
# 3064 luxury
# 3065 macaw
# 3066 macaws
# 3067 machine
# 3068 machinery
# 3069 macho
# 3070 mad
# 3071 made_reservation
# 3072 magagement
# 3073 magazine
# 3074 magical
# 3075 magnificent
# 3076 magnify
# 3077 maid
# 3078 mail
# 3079 maim
# 3080 main
# 3081 main_plaza
# 3082 main_road
# 3083 main_square
# 3084 mainly
# 3085 mainstream
# 3086 maintain
# 3087 maintenance
# 3088 major
# 3089 majority
# 3090 make
# 3091 make_reservation
# 3092 make_sure
# 3093 makeover
# 3094 maker
# 3095 makeup
# 3096 making
# 3097 male
# 3098 malfunction
# 3099 man
# 3100 manage
# 3101 manageable
# 3102 management
# 3103 manager
# 3104 manageress
# 3105 mandatory
# 3106 maneuver
# 3107 manger
# 3108 manicure
# 3109 manicured
# 3110 manicurist
# 3111 manifest
# 3112 manky
# 3113 manner
# 3114 mansion
# 3115 many
# 3116 many_hotel
# 3117 many_restaurant
# 3118 many_time
# 3119 map
# 3120 march
# 3121 margin
# 3122 marginally
# 3123 mariachi
# 3124 marimaba
# 3125 marimba
# 3126 mark
# 3127 marked
# 3128 market
# 3129 marketing
# 3130 marketplace
# 3131 marking
# 3132 marmalade
# 3133 married
# 3134 marry
# 3135 marvel
# 3136 marvelous
# 3137 mask
# 3138 masked
# 3139 massage
# 3140 masseuse
# 3141 massive
# 3142 massively
# 3143 master
# 3144 mat
# 3145 match
# 3146 material
# 3147 math
# 3148 matrasse
# 3149 matress
# 3150 matresse
# 3151 matter
# 3152 mattress
# 3153 mature
# 3154 maximum
# 3155 may
# 3156 mayan
# 3157 maybe
# 3158 mayor
# 3159 mbit
# 3160 mbps
# 3161 meagre
# 3162 meal
# 3163 mean
# 3164 meander
# 3165 meaning
# 3166 meanwhile
# 3167 measly
# 3168 measure
# 3169 measureable
# 3170 meat
# 3171 mechanic
# 3172 mechanical
# 3173 medic
# 3174 medical
# 3175 medication
# 3176 medicine
# 3177 mediocre
# 3178 medium
# 3179 meet
# 3180 meeting
# 3181 meh
# 3182 member
# 3183 memo
# 3184 memorable
# 3185 memory
# 3186 men
# 3187 menagerie
# 3188 mentality
# 3189 mention
# 3190 menu
# 3191 mercado
# 3192 mercy
# 3193 mere
# 3194 merely
# 3195 merit
# 3196 mesh
# 3197 meson
# 3198 mess
# 3199 message
# 3200 messenger
# 3201 messy
# 3202 metal
# 3203 meter
# 3204 metre
# 3205 mexican
# 3206 micro
# 3207 microphone
# 3208 microwave
# 3209 mid
# 3210 middle
# 3211 middle_night
# 3212 midnight
# 3213 mil
# 3214 mild
# 3215 mildew
# 3216 mile
# 3217 milk
# 3218 mimic
# 3219 min
# 3220 mind
# 3221 minded
# 3222 mindful
# 3223 mine
# 3224 mingle
# 3225 mini
# 3226 minibar
# 3227 minimal
# 3228 minimalist
# 3229 minimalistic
# 3230 minimum
# 3231 minor
# 3232 minus
# 3233 minute
# 3234 minute_walk
# 3235 miraculously
# 3236 mirror
# 3237 miscalculate
# 3238 miserable
# 3239 misfortune
# 3240 misheard
# 3241 misinformed
# 3242 mislead
# 3243 misleading
# 3244 misogynistic
# 3245 misplaced
# 3246 miss
# 3247 missing
# 3248 mission
# 3249 missionary
# 3250 mist
# 3251 mistake
# 3252 mistaken
# 3253 mistakenly
# 3254 mistreat
# 3255 mix
# 3256 mixed
# 3257 mixup
# 3258 moan
# 3259 moat
# 3260 mobile
# 3261 mobility
# 3262 modem
# 3263 moderate
# 3264 moderately
# 3265 modern
# 3266 modernity
# 3267 modest
# 3268 modestly
# 3269 moisture
# 3270 mold
# 3271 moldy
# 3272 mom
# 3273 moment
# 3274 mommy
# 3275 monastery
# 3276 money
# 3277 money_back
# 3278 monkey
# 3279 monotony
# 3280 month
# 3281 monthly
# 3282 montior
# 3283 mood
# 3284 moove
# 3285 mopping
# 3286 moral
# 3287 moreover
# 3288 morne
# 3289 morning
# 3290 mosquiro
# 3291 mosquito
# 3292 mostly
# 3293 motel
# 3294 moth
# 3295 mother
# 3296 motion
# 3297 motor
# 3298 motorbike
# 3299 motorcycle
# 3300 mould
# 3301 mouldy
# 3302 mount
# 3303 mountain
# 3304 mourning
# 3305 mouth
# 3306 move
# 3307 movement
# 3308 movie
# 3309 much
# 3310 much_better
# 3311 much_nicer
# 3312 mucky
# 3313 mud
# 3314 mudslide
# 3315 muesli
# 3316 mug
# 3317 muggy
# 3318 muldy
# 3319 multiple
# 3320 museum
# 3321 mushroom
# 3322 music
# 3323 musician
# 3324 musk
# 3325 musky
# 3326 mussel
# 3327 must
# 3328 musty
# 3329 muted
# 3330 muxh
# 3331 mysterious
# 3332 nacho
# 3333 nachos
# 3334 nail
# 3335 naked
# 3336 name
# 3337 nap
# 3338 narrow
# 3339 nasty
# 3340 national
# 3341 natural
# 3342 natural_light
# 3343 naturally
# 3344 nature
# 3345 nauseous
# 3346 navigate
# 3347 nd_floor
# 3348 near
# 3349 nearby
# 3350 nearer
# 3351 nearest
# 3352 nearly
# 3353 nearness
# 3354 neat
# 3355 necessarily
# 3356 necessary
# 3357 necessitate
# 3358 necessity
# 3359 neck
# 3360 nee
# 3361 need
# 3362 needed
# 3363 needless
# 3364 needless_say
# 3365 negative
# 3366 negatively
# 3367 neglect
# 3368 negotiate
# 3369 negotiating
# 3370 negotiation
# 3371 neighbor
# 3372 neighborhood
# 3373 neighboring
# 3374 neighbour
# 3375 neighbourhood
# 3376 neighbouring
# 3377 nervous
# 3378 net
# 3379 network
# 3380 never
# 3381 nevertheless
# 3382 new
# 3383 new_year
# 3384 newish
# 3385 newly
# 3386 news
# 3387 next
# 3388 next_day
# 3389 next_door
# 3390 next_morne
# 3391 next_morning
# 3392 nice
# 3393 nicely
# 3394 nicer
# 3395 nickel
# 3396 nickle
# 3397 nifty
# 3398 night
# 3399 night_guard
# 3400 nightclub
# 3401 nighter
# 3402 nightime
# 3403 nightlife
# 3404 nightly
# 3405 nightmare
# 3406 nighttime
# 3407 ninth
# 3408 nite
# 3409 noce
# 3410 noice
# 3411 noise
# 3412 noise_level
# 3413 noisey
# 3414 noisily
# 3415 noisiness
# 3416 noisy
# 3417 noisybar
# 3418 nomad
# 3419 non
# 3420 none
# 3421 nonetheless
# 3422 nonexistent
# 3423 nonfunctional
# 3424 nook
# 3425 noon
# 3426 noone
# 3427 norm
# 3428 normal
# 3429 normally
# 3430 north
# 3431 norwegian
# 3432 nose
# 3433 notably
# 3434 notch
# 3435 note
# 3436 noted
# 3437 noteworthy
# 3438 nothing_special
# 3439 notice
# 3440 noticeable
# 3441 noticeably
# 3442 noticed
# 3443 notify
# 3444 nowhere
# 3445 nuisance
# 3446 number
# 3447 numbered
# 3448 numblingly
# 3449 numerous
# 3450 nut
# 3451 nylon
# 3452 oasis
# 3453 object
# 3454 objectionable
# 3455 objective
# 3456 obligation
# 3457 oblige
# 3458 obligingly
# 3459 oblivious
# 3460 obnoxious
# 3461 obnoxiously
# 3462 obscene
# 3463 obscure
# 3464 observation
# 3465 observe
# 3466 obtain
# 3467 obvious
# 3468 obviously
# 3469 ocassion
# 3470 occasion
# 3471 occasional
# 3472 occasionally
# 3473 occassion
# 3474 occitane
# 3475 occupancy
# 3476 occupant
# 3477 occupy
# 3478 occur
# 3479 occurrence
# 3480 ocelot
# 3481 odd
# 3482 oddly
# 3483 oder
# 3484 odor
# 3485 odour
# 3486 ofcourse
# 3487 offend
# 3488 offer
# 3489 offering
# 3490 office
# 3491 officer
# 3492 official
# 3493 officially
# 3494 offish
# 3495 offline
# 3496 often
# 3497 ohter
# 3498 oike
# 3499 oil
# 3500 ok
# 3501 okay
# 3502 old
# 3503 olde
# 3504 olive
# 3505 omelet
# 3506 omelette
# 3507 omellete
# 3508 omellette
# 3509 ominous
# 3510 one
# 3511 ongoing
# 3512 online
# 3513 onsite
# 3514 onvisa
# 3515 onward
# 3516 onwards
# 3517 opaque
# 3518 open
# 3519 open_air
# 3520 openable
# 3521 opener
# 3522 opening
# 3523 opera
# 3524 operable
# 3525 operate
# 3526 operation
# 3527 operational
# 3528 operator
# 3529 opinion
# 3530 oposite
# 3531 opportunity
# 3532 oppose
# 3533 opposite
# 3534 opt
# 3535 optimal
# 3536 optimally
# 3537 optimistic
# 3538 option
# 3539 optional
# 3540 options_antigua
# 3541 orange
# 3542 orange_juice
# 3543 ordeal
# 3544 order
# 3545 ordinary
# 3546 organisation
# 3547 organise
# 3548 organization
# 3549 organize
# 3550 organizer
# 3551 orient
# 3552 orientation
# 3553 oriented
# 3554 origin
# 3555 original
# 3556 originally
# 3557 originally_booke
# 3558 oropax
# 3559 orphanage
# 3560 other
# 3561 otherwise
# 3562 othet
# 3563 otter
# 3564 ounce
# 3565 outcome
# 3566 outdate
# 3567 outdated
# 3568 outdoor
# 3569 outer
# 3570 outfit
# 3571 outfitter
# 3572 outgoing
# 3573 outlet
# 3574 outline
# 3575 outlive
# 3576 outpost
# 3577 outrage
# 3578 outrageous
# 3579 outright
# 3580 outside
# 3581 outside_window
# 3582 outskirt
# 3583 outstanding
# 3584 outstandingly
# 3585 outta
# 3586 outwards
# 3587 outweigh
# 3588 oven
# 3589 overall
# 3590 overbear
# 3591 overbook
# 3592 overbooke
# 3593 overbooking
# 3594 overcharge
# 3595 overcome
# 3596 overcrowd
# 3597 overcrowded
# 3598 overdone
# 3599 overfilling
# 3600 overflow
# 3601 overfly
# 3602 overhead
# 3603 overhear
# 3604 overlook
# 3605 overly
# 3606 overnight
# 3607 overpower
# 3608 overprice
# 3609 overpriced
# 3610 overprized
# 3611 overrate
# 3612 overrated
# 3613 overseas
# 3614 overshadowed
# 3615 oversleep
# 3616 overspeed
# 3617 overstate
# 3618 overstuffed
# 3619 overtouriste
# 3620 overview
# 3621 overwhelming
# 3622 owe
# 3623 owful
# 3624 own
# 3625 owner
# 3626 ownership
# 3627 oxygen
# 3628 pacaya
# 3629 pacaya_volcano
# 3630 pace
# 3631 pack
# 3632 package
# 3633 packet
# 3634 packing
# 3635 pad
# 3636 padding
# 3637 padlock
# 3638 page
# 3639 pain
# 3640 painful
# 3641 painstaking
# 3642 paint
# 3643 paintball
# 3644 painting
# 3645 palace
# 3646 palicochico
# 3647 palm
# 3648 palmolive
# 3649 paltry
# 3650 pampered
# 3651 pan
# 3652 pancake
# 3653 pane
# 3654 panel
# 3655 pant
# 3656 panza_verde
# 3657 papaya
# 3658 paper
# 3659 paperwork
# 3660 parent
# 3661 park
# 3662 parking
# 3663 parking_lot
# 3664 parque_central
# 3665 parrot
# 3666 part
# 3667 partake
# 3668 partial
# 3669 partially
# 3670 particle
# 3671 particular
# 3672 particularly
# 3673 particulary
# 3674 partie
# 3675 partier
# 3676 partly
# 3677 partner
# 3678 party
# 3679 party_hostel
# 3680 partygo
# 3681 partying
# 3682 pass
# 3683 passage
# 3684 passageway
# 3685 passenger
# 3686 passeport
# 3687 passive
# 3688 passport
# 3689 passthrough
# 3690 password
# 3691 past
# 3692 paste
# 3693 pastry
# 3694 patch
# 3695 patchy
# 3696 path
# 3697 pathetic
# 3698 pathway
# 3699 patience
# 3700 patient
# 3701 patiently
# 3702 patina
# 3703 patio
# 3704 patron
# 3705 patronise
# 3706 pattern
# 3707 patty
# 3708 pavement
# 3709 pay
# 3710 payment
# 3711 pc
# 3712 peace
# 3713 peaceful
# 3714 peacefully
# 3715 peacock
# 3716 peak
# 3717 pearson
# 3718 pedicure
# ...
# 12916 thick_wall
# 12917 thickness
# 12918 things_say
# 12919 thirsty
# 12920 thoight
# 12921 thoroughfare
# 12922 thoroughly_enjoye
# 12923 thoug
# 12924 thoughful
# 12925 thoughfully
# 12926 thoughout
# 12927 thoughtful
# 12928 thoughtfully
# 12929 thoughtfulness
# 12930 thoughtless
# 12931 thouroughly
# 12932 thr
# 12933 thrash
# 12934 thread
# 12935 threat
# 12936 threatening
# 12937 three_different
# 12938 three_separate
# 12939 three_time
# 12940 three_volcanoe
# 12941 three_week
# 12942 threshold
# 12943 thrid
# 12944 thridly
# 12945 thrill
# 12946 thrilled
# 12947 thrive
# 12948 thriving
# 12949 throat
# 12950 throughly
# 12951 throughout
# 12952 throughout_day
# 12953 throughout_property
# 12954 throwback
# 12955 thruly
# 12956 thst
# 12957 thub
# 12958 thumbs
# 12959 thunder
# 12960 thunderstorm
# 12961 thursday
# 12962 thw
# 12963 tick
# 12964 ticked
# 12965 tidbit
# 12966 tidiness
# 12967 tidying
# 12968 tier
# 12969 tight_budget
# 12970 tigua
# 12971 tile_floor
# 12972 tiling
# 12973 tilt
# 12974 timbered
# 12975 timeless
# 12976 timeline
# 12977 timer
# 12978 times
# 12979 times_last
# 12980 times_past
# 12981 timetable
# 12982 timey
# 12983 timidly
# 12984 tinkle
# 12985 tint
# 12986 tipee
# 12987 tipi
# 12988 tipico
# 12989 tipicos
# 12990 tippy
# 12991 tiramisu
# 12992 tiredness
# 12993 tireless
# 12994 tirelessly
# 12995 tiresome
# 12996 tje
# 12997 toal
# 12998 toast_jam
# 12999 toaster
# 13000 toastie
# 13001 toasting
# 13002 toasty
# 13003 tofu
# 13004 toher
# 13005 toil
# 13006 toilet_pap
# 13007 toilet_shower
# 13008 toilet_sink
# 13009 toileterie
# 13010 toiletrie
# 13011 toiletries_provide
# 13012 toiletterie
# 13013 toilletrie
# 13014 tolerable
# 13015 tolerably
# 13016 tolerant
# 13017 tolerate
# 13018 tolilet
# 13019 toll
# 13020 tom
# 13021 tomatoes_pancake
# 13022 tomatoes_pancakes
# 13023 tomb
# 13024 tomoatoe
# 13025 tong
# 13026 tongue
# 13027 tonic
# 13028 tonne
# 13029 tooand
# 13030 took_advantage
# 13031 took_care
# 13032 toolkit
# 13033 toomany
# 13034 toooo
# 13035 toothbrush
# 13036 toothpaste
# 13037 top_bunk
# 13038 top_deck
# 13039 top_list
# 13040 top_notch
# 13041 tope
# 13042 topmost
# 13043 topper
# 13044 tornado
# 13045 tornarci
# 13046 torrential
# 13047 torte
# 13048 tortoise
# 13049 total_night
# 13050 totally_recommend
# 13051 totally_recommende
# 13052 totally_recommended
# 13053 totally_safe
# 13054 totally_worth
# 13055 totaly
# 13056 tough
# 13057 tour_agency
# 13058 tour_guide
# 13059 tour_operator
# 13060 tourguide
# 13061 touring
# 13062 tourist_attraction
# 13063 touristed
# 13064 tournament
# 13065 tournys
# 13066 tours
# 13067 tours_shuttle
# 13068 tours_transfer
# 13069 tours_transport
# 13070 towelling
# 13071 towels_soap
# 13072 tower
# 13073 town_centre
# 13074 town_square
# 13075 toxic
# 13076 toy
# 13077 tracking
# 13078 tradeoff
# 13079 tradicionne
# 13080 trading
# 13081 tradional
# 13082 traditional_guatemalan
# 13083 traditionally
# 13084 trafficky
# 13085 trailer
# 13086 traipse
# 13087 tramp
# 13088 tranportation
# 13089 tranquility
# 13090 tranquill
# 13091 tranquillity
# 13092 tranquillo
# 13093 transaction
# 13094 transfer_airport
# 13095 transfers_etc
# 13096 transform
# 13097 transition
# 13098 transorte
# 13099 transpiration
# 13100 transpire
# 13101 transplant
# 13102 transporation
# 13103 transport_airport
# 13104 transportantion
# 13105 transportation_airport
# 13106 transportqation
# 13107 trapping
# 13108 trashcan
# 13109 travel_agencie
# 13110 travel_agent
# 13111 travel_arrangement
# 13112 travel_extensively
# 13113 traveling_alone
# 13114 traveling_companion
# 13115 traveling_month
# 13116 travelling_alone
# 13117 travelocity
# 13118 traverse
# 13119 travertine
# 13120 travesia
# 13121 travller
# 13122 tray
# 13123 treacherous
# 13124 treadle
# 13125 treadmill
# 13126 treasure
# 13127 treasured
# 13128 treated_like
# 13129 treatement
# 13130 tree_house
# 13131 treehouse
# 13132 treetop
# 13133 trekking
# 13134 tremendous
# 13135 tremendously
# 13136 tremor
# 13137 trend
# 13138 trendy
# 13139 tress
# 13140 trestaurant
# 13141 treturne
# 13142 tri
# 13143 tribe
# 13144 tribulation
# 13145 tribute
# 13146 trigger
# 13147 trim
# 13148 trimming
# 13149 trio
# 13150 trip_guatemala
# 13151 trip_lake
# 13152 trip_pacaya
# 13153 trip_tikal
# 13154 tripadviser
# 13155 triple_bunk
# 13156 triple_room
# 13157 tripper
# 13158 tripple
# 13159 trips_lake
# 13160 trivia
# 13161 trivial
# 13162 trivium
# 13163 troll
# 13164 trophy
# 13165 tropical_flower
# 13166 tropical_plant
# 13167 trot
# 13168 trouble_finde
# 13169 troubled
# 13170 troublesome
# 13171 trrrre
# 13172 trudge
# 13173 true_gem
# 13174 truely
# 13175 truffel
# 13176 truffle
# 13177 truly_gem
# 13178 truly_unique
# 13179 trunk
# 13180 trustworthy
# 13181 trvelle
# 13182 try_reserve
# 13183 trying
# 13184 tshirt
# 13185 tuba
# 13186 tube
# 13187 tuche
# 13188 tucked_away
# 13189 tuesday
# 13190 tuk_tuk
# 13191 tuk_tuks
# 13192 tumbergia
# 13193 tummy
# 13194 turist
# 13195 turistic
# 13196 turkish
# 13197 turn_service
# 13198 turnback
# 13199 turndown
# 13200 turnover
# 13201 turny
# 13202 turquoise
# 13203 turret
# 13204 turtle
# 13205 tut
# 13206 tutor
# 13207 tv_cable
# 13208 tv_channel
# 13209 tv_netflix
# 13210 tvs
# 13211 twice_year
# 13212 twilight
# 13213 twine
# 13214 twise
# 13215 twisty
# 13216 twitter
# 13217 two_block
# 13218 two_computer
# 13219 two_different
# 13220 two_double
# 13221 two_level
# 13222 two_night
# 13223 two_occasion
# 13224 two_pool
# 13225 two_separate
# 13226 two_weeks
# 13227 tying
# 13228 typewriter
# 13229 typico
# 13230 ubicacion
# 13231 ubication
# 13232 ultimate
# 13233 ultra
# 13234 umbrella
# 13235 umpteenth
# 13236 unaffected
# 13237 unaltere
# 13238 unanimous
# 13239 unanimously
# 13240 unannounced
# 13241 unappealing
# 13242 unappropriate
# 13243 unashamed
# 13244 unavailble
# 13245 unbeliaveble
# 13246 unbelieveable
# 13247 unbelieveably
# 13248 unbeliveably
# 13249 unbooked
# 13250 uncertainty
# 13251 uncle
# 13252 uncluttered
# 13253 uncomfrotable
# 13254 uncommon
# 13255 uncover
# 13256 undecided
# 13257 undeniable
# 13258 undeniably
# 13259 undercooked
# 13260 undercut
# 13261 underdeveloped
# 13262 underestimate
# 13263 underground
# 13264 underground_tunnel
# 13265 underpowered
# 13266 underprice
# 13267 underrate
# 13268 underrated
# 13269 understate
# 13270 understated
# 13271 understatement
# 13272 underutilise
# 13273 underwhelme
# 13274 undesirable
# 13275 undesired
# 13276 undetermined
# 13277 undiscovered
# 13278 undisturbed
# 13279 undivided
# 13280 undone
# 13281 unearth
# 13282 unease
# 13283 uneasy
# 13284 unequal
# 13285 unequalled
# 13286 unerring
# 13287 unesco_world
# 13288 unexceptable
# 13289 unexciting
# 13290 unexistent
# 13291 unfailingly
# 13292 unfit
# 13293 unforeseeable
# 13294 unforgetable
# 13295 unforgettable
# 13296 unforgettable_experience
# 13297 unfortuantely
# 13298 unfortunatelly
# 13299 unfortunetly
# 13300 ungodly
# 13301 unhappily
# 13302 unhappiness
# 13303 unhealthy
# 13304 unheard
# 13305 unheated
# 13306 unhurried
# 13307 uniformity
# 13308 uniformly
# 13309 unimpeded
# 13310 uninterrupted
# 13311 union
# 13312 unique_experience
# 13313 uniquely
# 13314 uniquely_decorate
# 13315 uniquely_decorated
# 13316 unison
# 13317 united_state
# 13318 universal
# 13319 university
# 13320 unknowingly
# 13321 unlike_hotel
# 13322 unlimited_coffee
# 13323 unload
# 13324 unmade
# 13325 unmask
# 13326 unmatched
# 13327 unmet
# 13328 unneeded
# 13329 unnerving
# 13330 unnotice
# 13331 unnoticeable
# 13332 unnoticed
# 13333 unobstructed
# 13334 unobtrusive
# 13335 unoccupied
# 13336 unoverlooked
# 13337 unpacked
# 13338 unparallele
# 13339 unparalleled
# 13340 unpaved
# 13341 unplanned
# 13342 unplug
# 13343 unplugged
# 13344 unprecedented
# 13345 unprepared
# 13346 unpresuming
# 13347 unpretentious
# 13348 unreal
# 13349 unrelated
# 13350 unremarkable
# 13351 unrestored
# 13352 unrivaled
# 13353 unscented
# 13354 unseasonably
# 13355 unseen
# 13356 unsettled
# 13357 unshaven
# 13358 unsolvable
# 13359 unspoiled
# 13360 unspoken
# 13361 unsteady
# 13362 unsurpassable
# 13363 unsurpasse
# 13364 unsurpassed
# 13365 unthinkable
# 13366 untypical
# 13367 unwell
# 13368 unwind
# 13369 unzip
# 13370 upbeat
# 13371 upcharge
# 13372 updating
# 13373 upgrading
# 13374 uphill
# 13375 upholstery
# 13376 upkeep
# 13377 uplifting
# 13378 upmost
# 13379 upon_arrive
# 13380 upon_entere
# 13381 upon_requ
# 13382 upon_return
# 13383 upper_floor
# 13384 upper_level
# 13385 upperfloor
# 13386 uppon
# 13387 upright
# 13388 upstair
# 13389 upstairs_balcony
# 13390 upstairs_patio
# 13391 upstairs_terrace
# 13392 upstanding
# 13393 uptempo
# 13394 upto
# 13395 uptown
# 13396 upward
# 13397 upwards
# 13398 ur
# 13399 urban
# 13400 urgent
# 13401 urn
# 13402 usb
# 13403 use_facilitie
# 13404 use_kitchen
# 13405 usefull
# 13406 username
# 13407 usful
# 13408 usher
# 13409 ushered
# 13410 utmost
# 13411 utterly
# 13412 uxlabil
# 13413 vacay
# 13414 vaccinate
# 13415 vacinity
# 13416 vacuum
# 13417 vaguely
# 13418 valentine
# 13419 valet_parke
# 13420 valet_parking
# 13421 validation
# 13422 valley
# 13423 valuation
# 13424 valuble
# 13425 valueformoney
# 13426 van
# 13427 vanish
# 13428 vanity
# 13429 vantage
# 13430 vapor
# 13431 variated
# 13432 vary_size
# 13433 vastness
# 13434 vault
# 13435 vaulted_ceiling
# 13436 veg
# 13437 vega
# 13438 vegan
# 13439 vegemite
# 13440 vegetarianism
# 13441 vegeterian
# 13442 vegitation
# 13443 vego
# 13444 vehicular
# 13445 velvet
# 13446 vending
# 13447 venerate
# 13448 ventilator
# 13449 venting
# 13450 veranda
# 13451 verandah
# 13452 verandas
# 13453 verbal
# 13454 verbatim
# 13455 verdant
# 13456 verge
# 13457 verily
# 13458 veritable
# 13459 vermin
# 13460 verry
# 13461 versa
# 13462 version
# 13463 vessel
# 13464 vest
# 13465 vestibule
# 13466 veteran
# 13467 veterinary
# 13468 via_email
# 13469 vibes
# 13470 vibrance
# 13471 vibrant
# 13472 viceversa
# 13473 victorian
# 13474 vie
# 13475 view_agua
# 13476 view_mountain
# 13477 view_surrounde
# 13478 view_surrounding
# 13479 view_volcan
# 13480 view_volcano
# 13481 view_volcanoe
# 13482 view_volcanos
# 13483 viewpoint
# 13484 views_agua
# 13485 views_mountain
# 13486 views_surrounde
# 13487 views_surrounding
# 13488 views_volcan
# 13489 views_volcano
# 13490 views_volcanoe
# 13491 views_volcanos
# 13492 vigilante
# 13493 vignette
# 13494 vigorous
# 13495 villa_esthela
# 13496 villager
# 13497 violence
# 13498 vip
# 13499 viriety
# 13500 visibility
# 13501 vision
# 13502 visionary
# 13503 visiste
# 13504 visited_antigua
# 13505 visiting_antigua
# 13506 visitng
# 13507 vista
# 13508 vistarific
# 13509 vistas
# 13510 viste
# 13511 visual
# 13512 visually
# 13513 vivid
# 13514 vlean
# 13515 vlocanoe
# 13516 vocabulary
# 13517 vodka
# 13518 void
# 13519 volanco
# 13520 volcan
# 13521 volcan_acatenango
# 13522 volcan_agua
# 13523 volcan_de
# 13524 volcan_fuego
# 13525 volcan_pacaya
# 13526 volcanic
# 13527 volcano_agua
# 13528 volcano_background
# 13529 volcano_erupt
# 13530 volcano_erupte
# 13531 volcano_erupting
# 13532 volcano_fuego
# 13533 volcano_hike
# 13534 volcano_tour
# 13535 volcano_trek
# 13536 volcanoe
# 13537 volcanoes_surrounde
# 13538 volcanot
# 13539 volleyball
# 13540 volonteer
# 13541 voluntarily
# 13542 volunteer_work
# 13543 volunteering
# 13544 volunter
# 13545 vote
# 13546 votive
# 13547 vouch
# 13548 vow
# 13549 voyage
# 13550 vulcan
# 13551 vulcanoe
# 13552 vwry
# 13553 waa
# 13554 wafer
# 13555 waffle
# 13556 waffles
# 13557 waft
# 13558 wag
# 13559 wail
# 13560 wait_come
# 13561 wait_return
# 13562 waiting_u
# 13563 waitresses
# 13564 waitstaff
# 13565 waive
# 13566 wake_call
# 13567 waking
# 13568 walk_anywhere
# 13569 walk_center
# 13570 walk_central
# 13571 walk_everywhere
# 13572 walk_main
# 13573 walk_parque
# 13574 walkability
# 13575 walkable_distance
# 13576 walked
# 13577 walked_around
# 13578 walked_everywhere
# 13579 walked_past
# 13580 walking_around
# 13581 walkout
# 13582 walkto
# 13583 wallflower
# 13584 waltz
# 13585 wand
# 13586 wander_around
# 13587 wanderer
# 13588 want_leave
# 13589 wanted_somethe
# 13590 wanting
# 13591 ward
# 13592 warm_invite
# 13593 warm_inviting
# 13594 warm_welcome
# 13595 warm_welcoming
# 13596 warmer
# 13597 warmly_greete
# 13598 warmly_welcome
# 13599 warmness
# 13600 warmwater
# 13601 warmy
# 13602 warp
# 13603 wary
# 13604 wash_clothe
# 13605 wash_clothes
# 13606 washable
# 13607 washer
# 13608 wasteful
# 13609 watch_movie
# 13610 watch_sun
# 13611 watch_sunset
# 13612 watch_tv
# 13613 watcher
# 13614 watchful
# 13615 watching_fuego
# 13616 water_available
# 13617 water_bottle
# 13618 water_feature
# 13619 water_heater
# 13620 water_refill
# 13621 water_show
# 13622 water_tap
# 13623 waterbottle
# 13624 waterfall
# 13625 watering
# 13626 waterproof
# 13627 wattage
# 13628 wave
# 13629 way_ensure
# 13630 way_possible
# 13631 weakling
# 13632 weakly
# 13633 weakness
# 13634 wealth
# 13635 wealthy
# 13636 weaver
# 13637 weaving
# 13638 webcam
# 13639 wedding_anniversary
# 13640 wednesday
# 13641 week_long
# 13642 weekend_getaway
# 13643 weeklong
# 13644 weekly
# 13645 weeknd
# 13646 weeknight
# 13647 weeks_ago
# 13648 weeks_later
# 13649 weigh
# 13650 weighted
# 13651 weirdly
# 13652 welcome_drink
# 13653 welcomed_u
# 13654 welcomed_us
# 13655 welfare
# 13656 well_appointed
# 13657 well_care
# 13658 well_cared
# 13659 well_designe
# 13660 well_designed
# 13661 well_done
# 13662 well_equipe
# 13663 well_equiped
# 13664 well_equippe
# 13665 well_equipped
# 13666 well_furnishe
# 13667 well_furnished
# 13668 well_known
# 13669 well_lit
# 13670 well_located
# 13671 well_organize
# 13672 well_organized
# 13673 well_presente
# 13674 well_presented
# 13675 well_price
# 13676 well_priced
# 13677 well_run
# 13678 well_situated
# 13679 well_stocke
# 13680 well_taken
# 13681 well_tende
# 13682 well_traine
# 13683 well_worth
# 13684 wellbee
# 13685 wellbeing
# 13686 went_beyond
# 13687 went_smoothly
# 13688 went_way
# 13689 wernt
# 13690 west
# 13691 westernized
# 13692 whash
# 13693 whater
# 13694 whatever_neede
# 13695 wheat
# 13696 whee
# 13697 wheeled
# 13698 wheeze
# 13699 whenever_neede
# 13700 whereby
# 13701 wherr
# 13702 whilst
# 13703 whim
# 13704 whimsical
# 13705 whip
# 13706 whirlwind
# 13707 whirpool
# 13708 whish
# 13709 whisk
# 13710 whiskey
# 13711 whistle
# 13712 whit
# 13713 white_noise
# 13714 whith
# 13715 whodoesthis
# 13716 wholehartedly
# 13717 wholeheartedly
# 13718 whre
# 13719 wicke
# 13720 wicked
# 13721 wide_range
# 13722 widen
# 13723 wider
# 13724 width
# 13725 wierd
# 13726 wiew
# 13727 wife_spent
# 13728 wife_staye
# 13729 wife_stayed
# 13730 wifi_connection
# 13731 wifi_fast
# 13732 wifi_signal
# 13733 wifi_spotty
# 13734 wifi_strong
# 13735 wifi_worke
# 13736 wifi_worked
# 13737 wih
# 13738 wihich
# 13739 wii
# 13740 wiifi
# 13741 wil
# 13742 wilderness
# 13743 wildlife
# 13744 wildly
# 13745 wile
# 13746 wiling
# 13747 willing_assist
# 13748 willing_go
# 13749 willing_help
# 13750 willingly
# 13751 willingness
# 13752 willle
# 13753 willy
# 13754 win
# 13755 wind
# 13756 winded
# 13757 windowds
# 13758 windows_close
# 13759 windows_closed
# 13760 windows_face
# 13761 windows_facing
# 13762 windows_opene
# 13763 wine_list
# 13764 winery
# 13765 winged
# 13766 wingler
# 13767 wingman
# 13768 winner
# 13769 wintry
# 13770 wipe
# 13771 wired
# 13772 wireless_internet
# 13773 wiring
# 13774 wisely
# 13775 wish_could
# 13776 wit
# 13777 with
# 13778 withe
# 13779 within_easy
# 13780 within_minute
# 13781 withn
# 13782 without_doubt
# 13783 without_hesitation
# 13784 without_intrusive
# 13785 without_problem
# 13786 without_question
# 13787 without_reservation
# 13788 withtv
# 13789 witty
# 13790 wiuld
# 13791 wizard
# 13792 wlak
# 13793 wlake
# 13794 wlke
# 13795 wll
# 13796 wnat
# 13797 woe
# 13798 woken
# 13799 woman_travele
# 13800 womens
# 13801 womfortable
# 13802 wondefull
# 13803 wonderfully_decorate
# 13804 wondering
# 13805 wonderment
# 13806 wood_burne
# 13807 wood_burning
# 13808 wooded
# 13809 wooden_ceiling
# 13810 wooden_door
# 13811 wooden_furniture
# 13812 wooden_shutter
# 13813 woodpecker
# 13814 woodworke
# 13815 woodworker
# 13816 woodworking
# 13817 woofer
# 13818 woolly
# 13819 work_done
# 13820 work_hard
# 13821 workable
# 13822 worked_fine
# 13823 worked_perfectly
# 13824 worked_well
# 13825 working_fireplace
# 13826 works_hard
# 13827 workshop
# 13828 workspace
# 13829 world_clas
# 13830 world_heritage
# 13831 worship
# 13832 worth_every
# 13833 worth_extra
# 13834 worth_price
# 13835 worth_visit
# 13836 worth_visite
# 13837 worth_visiting
# 13838 worthwhile
# 13839 woudl
# 13840 woukd
# 13841 would_certainly
# 13842 would_definately
# 13843 would_definetely
# 13844 would_definetly
# 13845 would_definitely
# 13846 would_gladly
# 13847 would_happily
# 13848 would_hesitate
# 13849 would_highly
# 13850 would_preferre
# 13851 would_preferred
# 13852 would_reccomend
# 13853 wouls
# 13854 wound
# 13855 woven
# 13856 wow
# 13857 wreck
# 13858 wrinkle
# 13859 wristband
# 13860 write_review
# 13861 writer
# 13862 writhe
# 13863 writing_review
# 13864 wrongly
# 13865 wrought_iron
# 13866 wsrm
# 13867 wyc
# 13868 włascicielka
# 13869 xonnection
# 13870 xylophone
# 13871 yanira
# 13872 year_ago
# 13873 year_year
# 13874 yearly
# 13875 yearning
# 13876 years_old
# 13877 years_row
# 13878 yellow_church
# 13879 yellowhouse
# 13880 yelow
# 13881 yesteryear
# 13882 yet_far
# 13883 yhere
# 13884 yoga_clas
# 13885 yoga_class
# 13886 yoga_classe
# 13887 yoga_studio
# 13888 yogalesson
# 13889 yoke
# 13890 yolk
# 13891 young_children
# 13892 young_kid
# 13893 young_man
# 13894 youngster
# 13895 youth
# 13896 ypu
# 13897 yr
# 13898 yrs
# 13899 yucca
# 13900 yum
# 13901 yummi
# 13902 yummmy
# 13903 yuumi
# 13904 zacapa
# 13905 zebra
# 13906 zen
# 13907 zesty
# 13908 ziggurat
# 13909 zinfandel
# 13910 zip_line
# 13911 zipline
# 13912 ziplining
# 13913 zone
# 13914 פעיל
# 13915 눇love

# %%
negative_bow = dictionary.doc2bow(negative_words)
positive_bow = dictionary.doc2bow(positive_words)

# %%
positive_bow
# Out:
# [(0, 4),
#  (3, 19),
#  (4, 382),
#  (6, 11),
#  (8, 3),
#  (9, 1),
#  (10, 58),
#  (11, 447),
#  (12, 1),
#  (16, 12),
#  (19, 29),
#  (20, 25),
#  (21, 20),
#  (23, 210),
#  (24, 45),
#  (25, 8),
#  (26, 14),
#  (27, 7),
#  (29, 496),
#  (30, 14),
#  (31, 301),
#  (32, 97),
#  (33, 4),
#  (34, 49),
#  (35, 22),
#  (36, 20),
#  (37, 4),
#  (38, 12),
#  (41, 23),
#  (42, 2),
#  (44, 4),
#  (45, 2),
#  (46, 2),
#  (48, 2),
#  (49, 4),
#  (51, 35),
#  (52, 9),
#  (53, 54),
#  (54, 1),
#  (55, 33),
#  (56, 5),
#  (57, 276),
#  (58, 28),
#  (59, 253),
#  (60, 4),
#  (61, 4),
#  (62, 254),
#  (63, 96),
#  (64, 63),
#  (65, 23),
#  (67, 20),
#  (68, 127),
#  (69, 8),
#  (72, 47),
#  (73, 23),
#  (74, 7),
#  (75, 15),
#  (76, 6),
#  (77, 1),
#  (78, 3),
#  (79, 18),
#  (80, 13),
#  (81, 7),
#  (82, 6),
#  (83, 48),
#  (84, 61),
#  (85, 49),
#  (86, 2),
#  (87, 40),
#  (88, 91),
#  (89, 4),
#  (90, 10),
#  (91, 22),
#  (92, 2),
#  (93, 3),
#  (94, 157),
#  (95, 1),
#  (96, 65),
#  (97, 1),
#  (99, 15),
#  (100, 5),
#  (101, 1),
#  (102, 7),
#  (103, 9),
#  (104, 171),
#  (105, 1),
#  (106, 13),
#  (107, 161),
#  (108, 19),
#  (109, 69),
#  (110, 7),
#  (111, 31),
#  (112, 15),
#  (113, 1),
#  (115, 40),
#  (117, 61),
#  (118, 4),
#  (120, 1),
#  (122, 30),
#  (123, 7),
#  (125, 67),
#  (126, 2),
#  (128, 25),
#  (129, 6),
#  (130, 5),
#  (131, 5),
#  (132, 1),
#  (133, 3),
#  (135, 13),
#  (136, 300),
#  (137, 13),
#  (139, 41),
#  (141, 1),
#  (142, 9),
#  (143, 1),
#  (144, 7),
#  (145, 3),
#  (146, 12),
#  (147, 10),
#  (149, 2),
#  (150, 6),
#  (151, 9),
#  (152, 12),
#  (155, 7),
#  (157, 1),
#  (158, 164),
#  (159, 262),
#  (160, 105),
#  (162, 21),
#  (163, 140),
#  (164, 4),
#  (165, 2871),
#  (166, 1),
#  (167, 6),
#  (168, 27),
#  (169, 1),
#  (170, 9),
#  (171, 12),
#  (172, 1),
#  (173, 1386),
#  (174, 197),
#  (175, 25),
#  (176, 1612),
#  (177, 140),
#  (178, 75),
#  (182, 360),
#  (183, 1),
#  (184, 1),
#  (185, 51),
#  (186, 70),
#  (187, 66),
#  (188, 3),
#  (189, 28),
#  (191, 79),
#  (192, 1),
#  (194, 3),
#  (196, 2),
#  (197, 22),
#  (198, 2),
#  (199, 10),
#  (200, 10),
#  (201, 33),
#  (202, 3),
#  (204, 9),
#  (205, 4),
#  (206, 1),
#  (207, 29),
#  (208, 1),
#  (209, 5),
#  (212, 83),
#  (213, 3),
#  (214, 4),
#  (215, 1),
#  (216, 1),
#  (217, 14),
#  (219, 3),
#  (221, 1),
#  (222, 3),
#  (223, 138),
#  (224, 4),
#  (227, 3),
#  (228, 10),
#  (229, 50),
#  (230, 53),
#  (231, 3),
#  (232, 145),
#  (233, 47),
#  (234, 119),
#  (236, 5),
#  (237, 3),
#  (238, 5),
#  (239, 7),
#  (240, 13),
#  (243, 5),
#  (244, 25),
#  (245, 33),
#  (246, 2),
#  (247, 61),
#  (248, 16),
#  (249, 8),
#  (250, 6),
#  (251, 31),
#  (252, 14),
#  (253, 208),
#  (254, 13),
#  (255, 14),
#  (256, 1),
#  (257, 16),
#  (258, 22),
#  (259, 2),
#  (260, 1),
#  (263, 117),
#  (264, 1),
#  (266, 21),
#  (267, 128),
#  (268, 1357),
#  (269, 1),
#  (270, 5),
#  (274, 6),
#  (275, 2),
#  (276, 3),
#  (277, 8),
#  (279, 133),
#  (280, 10),
#  (281, 341),
#  (282, 72),
#  (283, 13),
#  (284, 100),
#  (285, 630),
#  (286, 4),
#  (287, 3),
#  (288, 2),
#  (290, 126),
#  (291, 2),
#  (292, 21),
#  (293, 1),
#  (295, 15),
#  (296, 2),
#  (298, 16),
#  (299, 1),
#  (300, 24),
#  (301, 613),
#  (302, 4),
#  (303, 26),
#  (305, 9),
#  (306, 7),
#  (307, 58),
#  (308, 44),
#  (309, 7),
#  (310, 9),
#  (311, 12),
#  (312, 18),
#  (313, 1),
#  (315, 4),
#  (316, 14),
#  (318, 33),
#  (320, 531),
#  (321, 15),
#  (322, 48),
#  (323, 1),
#  (324, 12),
#  (325, 92),
#  (326, 21),
#  (327, 118),
#  (328, 353),
#  (329, 36),
#  (331, 28),
#  (332, 139),
#  (333, 81),
#  (334, 6),
#  (335, 3),
#  (337, 4),
#  (341, 4),
#  (342, 74),
#  (343, 9),
#  (347, 1),
#  (348, 3),
#  (352, 5),
#  (354, 23),
#  (356, 575),
#  (359, 79),
#  (361, 37),
#  (362, 72),
#  (363, 17),
#  (364, 33),
#  (365, 13),
#  (367, 7),
#  (368, 55),
#  (370, 535),
#  (371, 1),
#  (372, 504),
#  (373, 11),
#  (374, 2),
#  (375, 10),
#  (376, 9),
#  (377, 3),
#  (380, 49),
#  (381, 1),
#  (382, 881),
#  (383, 15),
#  (384, 17),
#  (385, 30),
#  (388, 55),
#  (389, 96),
#  (391, 16),
#  (392, 9),
#  (393, 14),
#  (394, 185),
#  (396, 3),
#  (398, 188),
#  (399, 4),
#  (400, 6),
#  (402, 1),
#  (403, 7),
#  (404, 66),
#  (405, 12),
#  (406, 3),
#  (407, 222),
#  (408, 5),
#  (409, 26),
#  (410, 19),
#  (411, 14),
#  (413, 48),
#  (414, 4),
#  (415, 3),
#  (416, 1065),
#  (418, 12),
#  (420, 31),
#  (421, 54),
#  (422, 1),
#  (423, 12),
#  (424, 5),
#  (425, 4),
#  (426, 36),
#  (427, 1),
#  (428, 134),
#  (429, 5),
#  (430, 227),
#  (431, 54),
#  (433, 1),
#  (434, 3),
#  (435, 18),
#  (436, 4),
#  (437, 5),
#  (438, 162),
#  (440, 2),
#  (441, 1728),
#  (442, 47),
#  (444, 2),
#  (445, 25),
#  (446, 6),
#  (447, 14),
#  (448, 77),
#  (449, 18),
#  (450, 2),
#  (452, 88),
#  (453, 16),
#  (456, 3387),
#  (457, 119),
#  (458, 127),
#  (460, 104),
#  (461, 2),
#  (462, 1850),
#  (464, 5),
#  (465, 1),
#  (466, 46),
#  (467, 225),
#  (468, 228),
#  (469, 1),
#  (470, 18),
#  (471, 6),
#  (472, 1),
#  (473, 4),
#  (474, 10),
#  (476, 1),
#  (477, 213),
#  (478, 2),
#  (479, 4),
#  (481, 3),
#  (482, 95),
#  (483, 3),
#  (484, 7),
#  (485, 4),
#  (486, 3),
#  (487, 2),
#  (488, 1),
#  (489, 3),
#  (491, 1),
#  (492, 4),
#  (493, 142),
#  (494, 15),
#  (495, 2),
#  (496, 10),
#  (497, 24),
#  (498, 27),
#  (499, 6),
#  (500, 30),
#  (503, 89),
#  (504, 38),
#  (505, 7),
#  (506, 19),
#  (509, 32),
#  (510, 21),
#  (512, 1),
#  (513, 7),
#  (514, 841),
#  (515, 1),
#  (516, 18),
#  (517, 35),
#  (518, 33),
#  (519, 2),
#  (520, 2),
#  (521, 5),
#  (522, 3),
#  (523, 103),
#  (524, 64),
#  (525, 404),
#  (526, 377),
#  (528, 2),
#  (530, 20),
#  (533, 5),
#  (536, 5),
#  (537, 12),
#  (538, 2),
#  (539, 80),
#  (540, 1),
#  (541, 30),
#  (543, 2),
#  (545, 25),
#  (546, 7),
#  (549, 357),
#  (550, 43),
#  (551, 71),
#  (552, 10),
#  (553, 14),
#  (554, 2),
#  (555, 2),
#  (556, 2),
#  (557, 9),
#  (558, 30),
#  (559, 13),
#  (560, 1),
#  (563, 11),
#  (564, 6),
#  (565, 21),
#  (566, 5),
#  (568, 15),
#  (572, 1),
#  (573, 3),
#  (574, 8),
#  (575, 88),
#  (576, 1054),
#  (577, 19),
#  (579, 4),
#  (581, 123),
#  (582, 5),
#  (583, 3),
#  (585, 1),
#  (587, 8),
#  (588, 11),
#  (589, 2),
#  (590, 9),
#  (591, 3),
#  (592, 6),
#  (593, 14),
#  (594, 8),
#  (595, 1),
#  (596, 75),
#  (599, 64),
#  (600, 10),
#  (601, 1),
#  (602, 5),
#  (604, 46),
#  (606, 10),
#  (607, 69),
#  (609, 47),
#  (611, 66),
#  (612, 1),
#  (613, 2),
#  (614, 6),
#  (615, 2),
#  (616, 188),
#  (617, 100),
#  (618, 1),
#  (619, 1),
#  (620, 4),
#  (621, 4452),
#  (622, 5),
#  (623, 410),
#  (624, 52),
#  (625, 64),
#  (627, 5),
#  (628, 5),
#  (629, 12),
#  (630, 5),
#  (631, 1),
#  (632, 66),
#  (633, 1),
#  (635, 29),
#  (636, 2),
#  (637, 4),
#  (638, 14),
#  (639, 18),
#  (640, 2),
#  (641, 4),
#  (642, 12),
#  (643, 5),
#  (644, 89),
#  (645, 1),
#  (646, 2),
#  (647, 4),
#  (648, 65),
#  (649, 305),
#  (650, 3),
#  (651, 4),
#  (652, 6),
#  (653, 2),
#  (655, 40),
#  (656, 7),
#  (657, 25),
#  (658, 3),
#  (659, 15),
#  (660, 3),
#  (661, 13),
#  (662, 10),
#  (663, 7),
#  (664, 192),
#  (666, 2),
#  (667, 119),
#  (668, 29),
#  (669, 1),
#  (670, 249),
#  (671, 249),
#  (672, 4),
#  (673, 1),
#  (674, 1),
#  (676, 1),
#  (677, 12),
#  (678, 7),
#  (679, 6),
#  (680, 36),
#  (681, 1),
#  (682, 63),
#  (683, 4),
#  (685, 33),
#  (690, 13),
#  (691, 4),
#  (692, 162),
#  (693, 144),
#  (695, 45),
#  (696, 213),
#  (697, 8),
#  (700, 24),
#  (701, 1),
#  (702, 2),
#  (703, 143),
#  (704, 34),
#  (705, 7),
#  (706, 2),
#  (707, 1),
#  (708, 12),
#  (709, 27),
#  (710, 108),
#  (711, 12),
#  (712, 21),
#  (714, 80),
#  (715, 58),
#  (716, 2),
#  (717, 4),
#  (718, 298),
#  (719, 114),
#  (720, 2),
#  (721, 7),
#  (722, 16),
#  (723, 16),
#  (724, 20),
#  (725, 6),
#  (726, 153),
#  (727, 39),
#  (728, 1),
#  (730, 6),
#  (732, 100),
#  (733, 27),
#  (734, 7),
#  (735, 7),
#  (736, 22),
#  (738, 19),
#  (739, 152),
#  (741, 1),
#  (742, 56),
#  (745, 295),
#  (746, 30),
#  (747, 18),
#  (748, 1),
#  (749, 23),
#  (750, 20),
#  (751, 3),
#  (752, 54),
#  (754, 5),
#  (757, 7),
#  (758, 10),
#  (759, 67),
#  (760, 4),
#  (761, 107),
#  (762, 31),
#  (763, 5),
#  (764, 13),
#  (765, 1),
#  (766, 66),
#  (767, 85),
#  (768, 1),
#  (769, 9),
#  (770, 42),
#  (771, 54),
#  (772, 2),
#  (774, 58),
#  (775, 9),
#  (777, 7),
#  (778, 1),
#  (780, 2),
#  (781, 57),
#  (782, 31),
#  (783, 3),
#  (784, 42),
#  (785, 3),
#  (786, 2),
#  (787, 7),
#  (788, 249),
#  (789, 123),
#  (790, 1),
#  (791, 563),
#  (792, 9),
#  (793, 249),
#  (794, 79),
#  (796, 4),
#  (797, 147),
#  (798, 10),
#  (799, 116),
#  (800, 31),
#  (801, 5),
#  (802, 25),
#  (803, 3),
#  (804, 47),
#  (805, 15),
#  (806, 51),
#  (807, 104),
#  (811, 33),
#  (813, 130),
#  (814, 29),
#  (815, 4),
#  (816, 4),
#  (817, 13),
#  (818, 92),
#  (819, 19),
#  (820, 247),
#  (821, 1),
#  (822, 52),
#  (823, 5),
#  (824, 5),
#  (825, 79),
#  (826, 4),
#  (827, 3),
#  (828, 233),
#  (830, 12),
#  (832, 3),
#  (833, 1),
#  (834, 280),
#  (835, 520),
#  (836, 4),
#  (837, 112),
#  (838, 2),
#  (839, 4),
#  (840, 492),
#  (841, 11),
#  (842, 6),
#  (844, 5),
#  (847, 529),
#  (848, 6),
#  (849, 13),
#  (850, 22),
#  (852, 46),
#  (854, 55),
#  (857, 3),
#  (860, 44),
#  (861, 1),
#  (862, 140),
#  (863, 356),
#  (864, 15),
#  (866, 26),
#  (867, 4),
#  (869, 15),
#  (870, 3),
#  (871, 10),
#  (872, 1),
#  (876, 62),
#  (877, 445),
#  (878, 347),
#  (879, 1),
#  (881, 5),
#  (882, 165),
#  (883, 21),
#  (884, 3),
#  (886, 6),
#  (887, 3),
#  (888, 1),
#  (889, 6),
#  (891, 1),
#  (892, 1),
#  (893, 1018),
#  (894, 11),
#  (895, 1),
#  (899, 4),
#  (900, 78),
#  (901, 4),
#  (902, 2),
#  (903, 32),
#  (905, 7),
#  (906, 4777),
#  (907, 2),
#  (908, 28),
#  (910, 5),
#  (911, 59),
#  (912, 114),
#  (913, 53),
#  (914, 45),
#  (915, 17),
#  (916, 3),
#  (917, 32),
#  (918, 10),
#  (919, 17),
#  (920, 1),
#  (921, 71),
#  (922, 6),
#  (925, 20),
#  (926, 2),
#  (928, 8),
#  (929, 2),
#  (932, 936),
#  (934, 100),
#  (935, 24),
#  (936, 26),
#  (937, 5),
#  (938, 56),
#  (939, 7),
#  (940, 13),
#  (941, 58),
#  (942, 10),
#  (943, 37),
#  (944, 2),
#  (946, 66),
#  (947, 2),
#  (951, 5),
#  (952, 2),
#  (954, 2),
#  (955, 6),
#  (959, 17),
#  (960, 9),
#  (961, 41),
#  (965, 1),
#  (967, 4),
#  (968, 68),
#  (969, 3),
#  (970, 5),
#  (971, 1016),
#  (972, 100),
#  (975, 153),
#  (976, 2),
#  (978, 19),
#  (979, 24),
#  (980, 25),
#  (981, 11),
#  (983, 231),
#  (985, 40),
#  (986, 49),
#  (987, 13),
#  (988, 12),
#  (990, 29),
#  (991, 26),
#  (993, 7),
#  (994, 896),
#  (995, 193),
#  (996, 175),
#  (997, 2457),
#  (998, 31),
#  (999, 15),
#  (1000, 204),
#  (1001, 51),
#  (1002, 2),
#  (1005, 95),
#  (1006, 3),
#  (1007, 5),
#  (1008, 2),
#  (1009, 3),
#  (1010, 4),
#  (1011, 4),
#  (1012, 2),
#  (1014, 91),
#  (1015, 45),
#  (1016, 1),
#  (1017, 2),
#  (1018, 47),
#  (1019, 15),
#  (1020, 1),
#  (1021, 41),
#  (1022, 30),
#  (1023, 68),
#  (1025, 9),
#  (1026, 20),
#  (1027, 85),
#  (1028, 11),
#  (1029, 3),
#  (1030, 85),
#  (1031, 13),
#  (1032, 1),
#  (1033, 9),
#  (1034, 2),
#  (1036, 73),
#  (1038, 203),
#  (1039, 6),
#  (1040, 13),
#  (1041, 99),
#  (1042, 109),
#  (1043, 41),
#  (1044, 6),
#  (1045, 5),
#  (1046, 22),
#  (1047, 66),
#  (1048, 2),
#  (1049, 20),
#  (1050, 3),
#  (1053, 79),
#  (1054, 86),
#  (1055, 2),
#  (1056, 1),
#  (1057, 1),
#  (1058, 61),
#  (1059, 20),
#  (1060, 5),
#  (1061, 36),
#  (1062, 4),
#  (1063, 3),
#  (1064, 10),
#  (1065, 5),
#  (1068, 1),
#  (1069, 40),
#  (1070, 5),
#  (1071, 5),
#  (1072, 69),
#  (1073, 28),
#  (1074, 11),
#  (1075, 61),
#  (1077, 7),
#  (1078, 3),
#  (1079, 6),
#  (1080, 4),
#  (1081, 6),
#  (1082, 72),
#  (1083, 6),
#  (1084, 51),
#  (1085, 2),
#  (1086, 1),
#  (1088, 3),
#  (1089, 1),
#  (1090, 140),
#  (1091, 3),
#  (1092, 7),
#  (1093, 19),
#  (1094, 15),
#  (1095, 39),
#  (1096, 17),
#  (1097, 37),
#  (1099, 22),
#  (1100, 44),
#  (1101, 4),
#  (1102, 1),
#  (1103, 47),
#  (1105, 7),
#  (1107, 63),
#  (1108, 21),
#  (1110, 7),
#  (1112, 3),
#  (1113, 30),
#  (1115, 9),
#  (1116, 68),
#  (1118, 3),
#  (1119, 5),
#  (1121, 2),
#  (1124, 12),
#  (1125, 26),
#  (1126, 46),
#  (1127, 211),
#  (1128, 18),
#  (1129, 81),
#  (1130, 5),
#  (1132, 39),
#  (1133, 71),
#  (1134, 6),
#  (1135, 4),
#  (1136, 42),
#  (1137, 9),
#  (1138, 3),
#  (1139, 2),
#  (1140, 254),
#  (1141, 32),
#  (1142, 39),
#  (1143, 362),
#  (1144, 9),
#  (1145, 1),
#  (1146, 4),
#  (1147, 31),
#  (1149, 1),
#  (1150, 14),
#  (1151, 10),
#  (1152, 93),
#  (1154, 10),
#  (1155, 19),
#  (1156, 3),
#  (1157, 3),
#  (1158, 61),
#  (1160, 166),
#  (1161, 1),
#  (1162, 2),
#  (1163, 7),
#  (1164, 90),
#  (1165, 4),
#  (1166, 7),
#  (1167, 11),
#  (1168, 63),
#  (1169, 7),
#  (1170, 1051),
#  (1171, 4),
#  (1172, 25),
#  (1174, 28),
#  (1175, 9),
#  (1176, 1),
#  (1177, 11),
#  (1178, 208),
#  (1179, 378),
#  (1180, 41),
#  (1181, 38),
#  (1182, 40),
#  (1183, 2),
#  (1184, 147),
#  (1185, 20),
#  (1186, 11),
#  (1187, 107),
#  (1188, 13),
#  (1189, 1282),
#  (1190, 17),
#  (1192, 5),
#  (1193, 127),
#  (1194, 9),
#  (1196, 385),
#  (1197, 3),
#  (1198, 14),
#  (1199, 39),
#  (1200, 6),
#  (1201, 11),
#  (1202, 27),
#  (1203, 3),
#  (1204, 1),
#  (1205, 1),
#  (1206, 3),
#  (1207, 11),
#  (1208, 9),
#  (1209, 55),
#  (1210, 2),
#  (1211, 1),
#  (1212, 11),
#  (1213, 74),
#  (1215, 12),
#  (1216, 3),
#  (1217, 12),
#  (1218, 22),
#  (1219, 6),
#  (1220, 23),
#  (1221, 46),
#  (1222, 4),
#  (1223, 1),
#  (1225, 1),
#  (1226, 1),
#  (1228, 3),
#  (1229, 3),
#  (1230, 27),
#  (1231, 2),
#  (1232, 57),
#  (1233, 15),
#  (1234, 5),
#  (1235, 10),
#  (1236, 89),
#  (1237, 20),
#  (1238, 14),
#  (1239, 1),
#  (1241, 7),
#  (1242, 5),
#  (1243, 3),
#  (1245, 2),
#  (1246, 1),
#  (1250, 13),
#  (1251, 43),
#  ...]

# %%
dictionary.doc2idx(['abysmal', 'abuse'])
# Out:
# [18, 17]

# %%
def split_data(data: List[str], weights: Tuple = (0.8, 0.2, 0.0), seed: int = 100) -> Dict:
    split = {}
    
    random.seed(seed)
    random.shuffle(data)
    
    total_words = len(data)
    train_limit = math.floor(total_words * weights[0])
    test_limit = math.floor(total_words * weights[1] + total_words * weights[0])
    
    split['train'] = data[:train_limit]
    split['test'] = data[train_limit:test_limit]
    split['validation'] = data[test_limit:]

    return split

# %%
split_data(negative_words)
# Out:
# {'train': ['especially',
#   'go',
#   'good',
#   'private',
#   'room',
#   'shared_bathroom',
#   'great',
#   'price',
#   'ish',
#   'garden',
#   'swing',
#   'basic',
#   'bathroom',
#   'tatty',
#   'hot',
#   'water',
#   'flow',
#   'slow',
#   'super',
#   'basic',
#   'dirty',
#   'load',
#   'cat',
#   'dog',
#   'cheap',
#   'basic',
#   'go',
#   'hotel',
#   'book',
#   'room',
#   'receptionist',
#   'really',
#   'high',
#   'price',
#   'lower',
#   'ask',
#   'much',
#   'cost',
#   'qetale',
#   'comission',
#   'rate',
#   'dollar',
#   'know',
#   'randomly',
#   'exist',
#   'rate',
#   'lower',
#   'rate',
#   'agree',
#   'price',
#   'morning',
#   'get',
#   'receive',
#   'plain',
#   'piece',
#   'fruit',
#   'theother',
#   'table',
#   'receive',
#   'also',
#   'egg',
#   'ask',
#   'also',
#   'egg',
#   'reply',
#   'come',
#   'breakfast',
#   'pay',
#   'good',
#   'experience',
#   'hotel',
#   'place',
#   'break',
#   'good',
#   'bad',
#   'good_location',
#   'warm',
#   'helpful',
#   'hour',
#   'massage',
#   'small',
#   'room',
#   'great',
#   'air_circulation',
#   'awful',
#   'dog',
#   'let',
#   'important',
#   'awful',
#   'bed',
#   'kill',
#   'massage',
#   'make',
#   'feel',
#   'well',
#   'sure',
#   'come_back',
#   'back',
#   'handle',
#   'night',
#   'advertise',
#   'totally',
#   'wrong',
#   'end',
#   'triple',
#   'room',
#   'really',
#   'worth',
#   'night',
#   'delay',
#   'bus',
#   'journey',
#   'accommodation',
#   'away',
#   'place',
#   'could',
#   'find',
#   'could',
#   'accommodate',
#   'grateful',
#   'price',
#   'wifi',
#   'seem',
#   'decent',
#   'however',
#   'room',
#   'incredibly',
#   'basic',
#   'unclean',
#   'mosquito',
#   'insect',
#   'floor',
#   'bathroom',
#   'key',
#   'door',
#   'apparently',
#   'however',
#   'lock',
#   'inside',
#   'secure',
#   'place',
#   'stay',
#   'big',
#   'night',
#   'staff',
#   'limit',
#   'test',
#   'else',
#   'bathroom',
#   'bedroom',
#   'morning',
#   'come',
#   'offer',
#   'towel',
#   'sheet',
#   'nasty',
#   'bathroom',
#   'gross',
#   'owner',
#   'take',
#   'dollar',
#   'give',
#   'receipt',
#   'terrible',
#   'use',
#   'tourist',
#   'shuttle',
#   'get',
#   'back_forth',
#   'country',
#   'pretty',
#   'often',
#   'book',
#   'shuttle',
#   'shuttle',
#   'woman',
#   'phone',
#   'look',
#   'time',
#   'tell',
#   'come',
#   'standard',
#   'bus',
#   'pick',
#   'early',
#   'sometimes',
#   'pick',
#   'minute',
#   'late',
#   'today',
#   'bus',
#   'still',
#   'wait',
#   'front',
#   'woman',
#   'say',
#   'fault',
#   'charge',
#   'inflated',
#   'price',
#   'later',
#   'shuttle',
#   'say',
#   'less',
#   'shuttle',
#   'price',
#   'expensive',
#   'finally',
#   'call',
#   'shuttle',
#   'company',
#   'say',
#   'pick',
#   'stay',
#   'home',
#   'last',
#   'weekend',
#   'want',
#   'room',
#   'nice',
#   'hotel',
#   'want',
#   'see',
#   'hotel',
#   'maybe',
#   'even',
#   'room',
#   'friend',
#   'look',
#   'arrive',
#   'early',
#   'clerk',
#   'personal',
#   'call',
#   'refuse',
#   'acknowledge',
#   'look',
#   'minute',
#   'early',
#   'take',
#   'look',
#   'lobby',
#   'pool',
#   'use',
#   'man',
#   'room',
#   'go',
#   'wild',
#   'man',
#   'room',
#   'guest',
#   'embarrassing',
#   'kick',
#   'group',
#   'book',
#   'hotel',
#   'pool',
#   'parking',
#   'good',
#   'request',
#   'upstairs',
#   'room',
#   'get',
#   'room',
#   'clean',
#   'however',
#   'overpriced',
#   'get',
#   'tiny',
#   'quaint',
#   'rather',
#   'charming',
#   'room',
#   'big',
#   'drawback',
#   'venue',
#   'bar',
#   'loud_music',
#   'reverberate',
#   'wall',
#   'way',
#   'go',
#   'able',
#   'sleep',
#   'credit',
#   'management',
#   'ring',
#   'bar',
#   'ask',
#   'turn',
#   'still',
#   'terribly',
#   'loud',
#   'come',
#   'offer',
#   'room',
#   'hotel',
#   'arrive',
#   'hotel',
#   'around',
#   'already',
#   'previous',
#   'charge',
#   'early',
#   'check',
#   'expect',
#   'bad',
#   'first',
#   'tell',
#   'couple',
#   'minute',
#   'wait',
#   'receptionist',
#   'call',
#   'say',
#   'room',
#   'available',
#   'charging',
#   'hour',
#   'check',
#   'time',
#   'ask',
#   'additional',
#   'order',
#   'check',
#   'treated',
#   'way',
#   'specially',
#   'explain',
#   'pay',
#   'almost',
#   'fly',
#   'want',
#   'rest',
#   'somehow',
#   'negotiate',
#   'still',
#   'rip',
#   'disgusting',
#   'decided_stay',
#   'stay',
#   'total',
#   'nearly',
#   'week',
#   'visit',
#   'already',
#   'family',
#   'friend',
#   'stranger',
#   'friend',
#   'slap',
#   'dash',
#   'haphazard',
#   'time',
#   'wifi',
#   'wonky',
#   'back',
#   'recommend',
#   'friend',
#   'oasis',
#   'expectation',
#   'courtyard',
#   'walk',
#   'hang',
#   'dense',
#   'flower',
#   'vine',
#   'spring',
#   'summer',
#   'add',
#   'flowering',
#   'tree',
#   'perfume',
#   'small',
#   'main',
#   'courtyard',
#   'add',
#   'soundtrack',
#   'splash',
#   'water',
#   'perfect',
#   'place',
#   'sip',
#   'beer',
#   'read',
#   'fall',
#   'size',
#   'make',
#   'big',
#   'effort',
#   'give',
#   'feel',
#   'town',
#   'feel',
#   'authentic',
#   'distance',
#   'central_park',
#   'block',
#   'food',
#   'coffee',
#   'people',
#   'bite',
#   'eye',
#   'contact',
#   'bathroom',
#   'design',
#   'smart',
#   'step',
#   'open',
#   'light',
#   'switch',
#   'step',
#   'easily',
#   'trip',
#   'shower',
#   'partial',
#   'wall',
#   'water',
#   'floor',
#   'pool',
#   'pretty',
#   'warmish',
#   'water',
#   'area',
#   'take',
#   'care',
#   'room',
#   'front',
#   'squeaky',
#   'gate',
#   'drop',
#   'oil',
#   'would',
#   'sort',
#   'problem',
#   'second',
#   'come',
#   'also',
#   'people',
#   'stop',
#   'front',
#   'room',
#   'talk',
#   'look',
#   'window',
#   'shutter',
#   'room',
#   'dark',
#   'maybe',
#   'well',
#   'old',
#   'look',
#   'worn',
#   'fit',
#   'mattress',
#   'also',
#   'pretty',
#   'towel',
#   'bite',
#   'threadbare',
#   'plus_side',
#   'good',
#   'room',
#   'clean',
#   'could',
#   'decent',
#   'place',
#   'need',
#   'look',
#   'certainly',
#   'overpriced',
#   'dump',
#   'day',
#   'evening',
#   'day',
#   'shower',
#   'disgusting',
#   'waste',
#   'money',
#   'less',
#   'money',
#   'stay',
#   'hotstel',
#   'terrible',
#   'way',
#   'entire',
#   'stay',
#   'people',
#   'hotel',
#   'order',
#   'properly',
#   'take',
#   'nearly',
#   'extremely',
#   'cold',
#   'big',
#   'issue',
#   'travel',
#   'girl',
#   'sit',
#   'shower',
#   'overall',
#   'stay',
#   'hotel',
#   'ruin',
#   'beautiful',
#   'friendly',
#   'staff',
#   'room',
#   'amenity',
#   'close',
#   'town',
#   'centre',
#   'apartment',
#   'own',
#   'really',
#   'like',
#   'voice',
#   'like',
#   'drink',
#   'lot',
#   'stay',
#   'unpleasant',
#   'fairly',
#   'affordable',
#   'location',
#   'good',
#   'fairly',
#   'busy',
#   'loud',
#   'basic',
#   'amenity',
#   'clean',
#   'safe',
#   'place',
#   'nice',
#   'little',
#   'hairdryer',
#   'overall',
#   'decent',
#   'place',
#   'picky',
#   'former',
#   'hotel',
#   'other',
#   'say',
#   'review',
#   'room',
#   'super',
#   'clean',
#   'bathroom',
#   'nice',
#   'flat',
#   'screen',
#   'tv',
#   'room',
#   'cute',
#   'little',
#   'hotel',
#   'exceptional',
#   'nice',
#   'kind',
#   'super',
#   'friendly',
#   'owner',
#   'son',
#   's',
#   'little',
#   'difficult',
#   'want',
#   'hotel',
#   'support',
#   'hotel',
#   'owner',
#   'likely',
#   'stay',
#   'kinda',
#   'inside',
#   'literally',
#   'asleep',
#   'pm',
#   'awaken',
#   'sound',
#   'car',
#   'backing',
#   'downstairs',
#   'noise',
#   'loud',
#   'enough',
#   'sound',
#   'great',
#   'set',
#   'relax',
#   'lot',
#   'really',
#   'resort',
#   'gym',
#   'good',
#   'pool',
#   'area',
#   'great',
#   'kid',
#   'playground',
#   'recently',
#   'renovate',
#   'smart',
#   'dinner',
#   'restaurant',
#   'good',
#   'also',
#   'lovely',
#   'vibe',
#   'negative',
#   'stuff',
#   'mainly',
#   'hinge',
#   'reception',
#   'experience',
#   'honest',
#   'arrive',
#   'reception',
#   'large',
#   'wedding',
#   'party',
#   'take',
#   'place',
#   'bit',
#   'however',
#   'welcome',
#   'quite',
#   'dismissive',
#   'want',
#   'sign',
#   'various',
#   'paperwork',
#   'key',
#   'send',
#   'way',
#   'hour',
#   'say',
#   'seem',
#   'new',
#   'working',
#   'order',
#   'breakfast',
#   'good',
#   'far',
#   'nightmare',
#   'parking',
#   'send',
#   'place',
#   'parking',
#   'attendant',
#   'seem',
#   'confused',
#   'hotel',
#   'come',
#   'block',
#   'exit',
#   'work',
#   'well',
#   'also',
#   'bathroom',
#   'small',
#   'toiletry',
#   'bag',
#   'finally',
#   'hotel',
#   'heavy',
#   'traffic',
#   'time',
#   'weekend',
#   'friend',
#   'online',
#   'say',
#   'room',
#   'leave',
#   'hotel',
#   'receptionist',
#   'lady',
#   'turn',
#   'room',
#   'say',
#   'small',
#   'room',
#   'small',
#   'room',
#   'would',
#   'put',
#   'extra',
#   'bed',
#   'would',
#   'tight',
#   'look',
#   'accommodation',
#   'ask',
#   'cancel',
#   'reservation',
#   'charge',
#   'say',
#   'would',
#   'cancel',
#   'stay',
#   'hotel',
#   'still',
#   'get',
#   'charge',
#   'back',
#   'ask',
#   'stay',
#   'get',
#   'suppose',
#   'reservation',
#   'come',
#   'could',
#   'lady',
#   'stayed_night',
#   'aware',
#   'high',
#   'rating',
#   'hotel',
#   'mention',
#   'clean',
#   'good',
#   'service',
#   'transportation',
#   'fast',
#   'efficient',
#   'however',
#   'room',
#   'small',
#   'put',
#   'fast',
#   'small',
#   'tv',
#   'english',
#   'channel',
#   'room',
#   'safe',
#   'visit',
#   'city',
#   'take',
#   'passport',
#   'money',
#   'also',
#   'question',
#   'shut',
#   'light',
#   'pass',
#   'would',
#   'see',
#   'room',
#   'bed_comfortable',
#   'bite',
#   'short',
#   'foot',
#   'almost',
#   'stick',
#   'bed',
#   'pillow',
#   'thin',
#   'stack',
#   'together',
#   'make',
#   'pillow',
#   'noisy',
#   'earplug',
#   'paint',
#   'bathroom',
#   'old',
#   'miss',
#   'ring',
#   'hole',
#   'stay',
#   'everywhere',
#   'else',
#   'book',
#   'pay',
#   'night',
#   'printout',
#   'confirmation',
#   'arrive',
#   'tourist',
#   'shuttle',
#   'eve',
#   'soon',
#   'mention',
#   'hotel',
#   'name',
#   'driver',
#   'couple',
#   'front',
#   'book',
#   'hotel',
#   'day',
#   'prior',
#   'use',
#   'think',
#   'bad',
#   'incident',
#   'wrong',
#   'manager',
#   'look',
#   'booking_com',
#   'printout',
#   'room',
#   'problem',
#   'know',
#   'hotel',
#   'full',
#   'time',
#   'even',
#   'one',
#   'room',
#   'charge',
#   'much',
#   'high',
#   'normal',
#   'reason',
#   'book',
#   'advance',
#   'luckily',
#   'find',
#   'view',
#   'obligingly',
#   'spew',
#   'cloud',
#   'smoke',
#   'dust',
#   'breakfast',
#   'time',
#   'room',
#   'poor',
#   'lighting',
#   'window_opene',
#   'internal',
#   'street',
#   'rather',
#   'useless',
#   'main',
#   'problem',
#   'hotel',
#   'situation',
#   'long',
#   'way',
#   'walk_centre',
#   'many',
#   'uneven',
#   'surface',
#   'pothole',
#   'route',
#   'dimly',
#   'light',
#   'street',
#   'dark',
#   'necessitate',
#   'taxi',
#   'especially',
#   'concerned',
#   'safety',
#   'go',
#   'tend',
#   'stay',
#   'return',
#   'tend',
#   'go_back',
#   'problem',
#   'breakfast',
#   'absolutely',
#   'disgusting',
#   'coffee',
#   'merely',
#   'poor',
#   'nearest',
#   'want',
#   'much',
#   'hotel',
#   'nice',
#   'place',
#   'price',
#   'point',
#   'quite',
#   'centrally_located',
#   'nice',
#   'garden',
#   'clean',
#   'fantastic',
#   'view',
#   'room',
#   'great',
#   'apart',
#   'soft',
#   'bed',
#   'breakfast',
#   'parking',
#   'site',
#   'inconvenient',
#   'square',
#   'min',
#   'shape',
#   'deal',
#   'fact',
#   'clanging',
#   'bell',
#   'nearby',
#   'church',
#   'complaint',
#   'unfortunately',
#   'loud',
#   'bar',
#   'playing',
#   'music',
#   'hate',
#   'write',
#   'arrive',
#   'hotel',
#   'truly',
#   'beautiful',
#   'staff',
#   'lovely',
#   'food',
#   'friend',
#   'travel',
#   'arrival',
#   'wake',
#   'way',
#   'spend',
#   'vacation',
#   'horrible',
#   'hotel',
#   'ask',
#   'proof',
#   'provide',
#   'clothe',
#   'change',
#   'appreciate',
#   'bad',
#   'rented',
#   'night',
#   'take',
#   'quickly',
#   'city',
#   'would',
#   'stay',
#   'discover',
#   'reservation',
#   'room',
#   'generous',
#   'bathroom',
#   'roomy',
#   'parking',
#   'need',
#   'owner',
#   'people',
#   'hotel',
#   'distance',
#   'restaurant',
#   'internet',
#   'disappointment',
#   'hotel',
#   'start',
#   'fact',
#   'reservation',
#   'want',
#   'send',
#   'hotel',
#   'complaie',
#   'day',
#   'exchange',
#   'mail',
#   'own',
#   'transfer',
#   'airport',
#   'hotel',
#   'come',
#   'say',
#   'reservation',
#   'end',
#   'gave_us',
#   'place',
#   'commune',
#   'photo',
#   'web',
#   'end',
#   'use',
#   'hotel',
#   'clean',
#   'comfortable',
#   'nicer',
#   'none',
#   'people',
#   'reception',
#   'train',
#   'idea',
#   'accept',
#   'payment',
#   'stay',
#   'decide',
#   'book',
#   'upmarket',
#   ...],
#  'test': ['town',
#   'be',
#   'antiguena',
#   'sized',
#   'twin',
#   'nice',
#   'shower',
#   'always',
#   'keep',
#   'pretty',
#   'kitchenette',
#   's',
#   'directly',
#   'first',
#   'gove',
#   'non',
#   'real',
#   'include',
#   'breakfast',
#   'follow',
#   'breakfast',
#   'toast',
#   'stay',
#   'go',
#   'free_breakfast',
#   'staff',
#   'bad',
#   'quality',
#   'bed',
#   'noisy',
#   'decide',
#   'choice',
#   'way',
#   'night',
#   'many',
#   'choice',
#   'original',
#   'give',
#   'value',
#   'everywhere',
#   'feel',
#   'night_guard',
#   'lock',
#   'see',
#   'much',
#   'dirty',
#   'sit',
#   'minute',
#   'sometimes',
#   'minute',
#   'late',
#   'true',
#   'people',
#   'people',
#   'already',
#   'look',
#   'meeting',
#   'take',
#   'even',
#   'start',
#   'scream',
#   'scream',
#   'basically',
#   'hotel',
#   'review',
#   'balcony',
#   'way',
#   'noise',
#   'manager',
#   'happy',
#   'read',
#   'review',
#   'want',
#   'room',
#   'available',
#   'wait',
#   'hour',
#   'early',
#   'standard',
#   'checking',
#   'pm',
#   'disappoint',
#   'upset',
#   'already',
#   'red',
#   'eye',
#   'additional',
#   'night',
#   'visit',
#   'reserve',
#   'become',
#   'much',
#   'way',
#   'shrub',
#   'aspire',
#   'bouquet',
#   'book',
#   'hotel',
#   'medium',
#   'colonial',
#   'walkable',
#   'good',
#   'however',
#   'cold',
#   'make',
#   'door',
#   'dark',
#   'get',
#   'make',
#   'slippery',
#   'well',
#   'entrance',
#   'go',
#   'tend',
#   'could',
#   'closed',
#   'however',
#   'room',
#   'upstairs',
#   'double',
#   'pillow',
#   'horrendous',
#   'shower',
#   'place',
#   'hotel',
#   'measureable',
#   'door',
#   'lock',
#   'go',
#   'shower',
#   'lock',
#   'visit',
#   'town',
#   'unlucky',
#   'sound',
#   'make',
#   'street',
#   'work',
#   'courtyard',
#   'truly',
#   'make',
#   'review',
#   'love',
#   'thing',
#   'struggle',
#   'noisey',
#   'parking',
#   'bed',
#   'sleep',
#   'garage',
#   'positive',
#   'stuff',
#   'room',
#   'staff',
#   'friendly_helpful',
#   'relaxed',
#   'pm',
#   'guy',
#   'probably',
#   'stressed',
#   'travel',
#   'good',
#   'impecable',
#   'negative',
#   'parking',
#   'sketchy',
#   'car',
#   'would',
#   'end',
#   'place',
#   'put',
#   'book',
#   'online',
#   'book',
#   'show',
#   'away',
#   'available',
#   'card',
#   'night',
#   'card',
#   'go',
#   'refund',
#   'night',
#   'office',
#   'card',
#   'charge',
#   'cancel',
#   'agree',
#   'point',
#   'book',
#   'stuff',
#   'closet',
#   'internet',
#   'privacy',
#   'window',
#   'use',
#   'peel',
#   'would',
#   'book',
#   'honor',
#   'refuse',
#   'normally',
#   'tend',
#   'rate',
#   'good',
#   'day',
#   'minute',
#   'ride',
#   'evening',
#   'town',
#   'inconvenient',
#   'hotel',
#   'lovely',
#   'would',
#   'overlook',
#   'first',
#   'day',
#   'constant',
#   'stay',
#   'cover',
#   'room',
#   'room',
#   'next',
#   'check',
#   'wonderful',
#   'fall',
#   'gain',
#   'sized',
#   'lovely',
#   'within_walke',
#   'la_merce',
#   'service',
#   'close',
#   'mention',
#   'confirm',
#   'take',
#   'know',
#   'room',
#   'discover',
#   'dirty',
#   'noisy',
#   'site',
#   'trip',
#   'much',
#   'also',
#   'previously',
#   'flight',
#   'hotel',
#   'location',
#   'compare',
#   'change',
#   'stay',
#   'mug',
#   'old',
#   'lipstick',
#   'towel',
#   'first',
#   'time',
#   'problem',
#   'relevant',
#   'clean',
#   'visit',
#   'stay',
#   'book',
#   'single',
#   'discount',
#   'taxis',
#   'cable',
#   'gtq',
#   'rate',
#   'breakfast',
#   'host',
#   'people',
#   'comfy',
#   'edge',
#   'decent',
#   'book',
#   'egg',
#   'nee',
#   'accept',
#   'hotel',
#   'market',
#   'really',
#   'early',
#   'sleeper',
#   'look',
#   'pay',
#   'week',
#   'ask',
#   'twice',
#   'get',
#   'avoid',
#   'cost',
#   'experience',
#   'careful',
#   'price',
#   'tax',
#   'high',
#   'style',
#   'room',
#   'place',
#   'room',
#   'move',
#   'huge',
#   'otherwise',
#   'cute',
#   'space',
#   'staff_friendly',
#   'great',
#   'add',
#   'paint',
#   'old',
#   'relax',
#   'mix',
#   'payment',
#   'later',
#   'push',
#   'cramped',
#   'couple',
#   'cleaning',
#   'morning',
#   'conversation',
#   'housekeeping',
#   'room',
#   'exterior',
#   'euro_maya',
#   'name',
#   'hotel',
#   'due',
#   'review',
#   'question',
#   'opinion',
#   'service',
#   'hotel',
#   'totally',
#   'pay',
#   'night',
#   'clean',
#   'nasty',
#   'towel',
#   'colonial',
#   'euro_maya',
#   'room',
#   'go',
#   'roof_top',
#   'view',
#   'posh',
#   'friendly',
#   'affordable',
#   'fact',
#   'tell',
#   'property',
#   'problem',
#   'disgraceful',
#   'issue',
#   'arrive',
#   'time',
#   'employee',
#   'hotel',
#   'centrally_locate',
#   'price',
#   'town',
#   'parking',
#   'hotel',
#   'police',
#   'close',
#   'go',
#   'first',
#   'full',
#   'room',
#   'general',
#   'bite',
#   'event',
#   'recommend',
#   'room',
#   'thing',
#   'small',
#   'lot',
#   'sleep',
#   'costumer',
#   'amazing',
#   'noise',
#   'clock',
#   'noise',
#   'quiet',
#   'look',
#   'credit',
#   'location',
#   'dinner',
#   'hotel',
#   'window',
#   'also',
#   'safe',
#   'valuable',
#   'good',
#   'window',
#   'water',
#   'attempt',
#   'filtered_water',
#   'tea',
#   'also',
#   'way',
#   'charge',
#   'flower',
#   'petal',
#   'turn',
#   'would',
#   'call',
#   'hotel',
#   'stay',
#   'check',
#   'well',
#   'refuse',
#   'many',
#   'well',
#   'clear',
#   'bed',
#   'location',
#   'want',
#   'cold',
#   'social',
#   'atmosphere',
#   'usefulness',
#   'hostel',
#   'concern',
#   'past',
#   'arrive',
#   'dirty',
#   'smell',
#   'damp',
#   'insist',
#   'pay',
#   'try',
#   'problem',
#   'three_night',
#   'unfortunately',
#   'appear',
#   'well',
#   'hotel',
#   'fan',
#   'hotel',
#   'ask',
#   'small',
#   'even',
#   'tiny',
#   'view',
#   'night',
#   'say',
#   'staff',
#   'stay',
#   'keep',
#   'imagine',
#   'desk',
#   'window',
#   'window',
#   'value',
#   'screen',
#   'mosquiro',
#   'room',
#   'noisy',
#   'terrace',
#   'price',
#   'breakfast',
#   'book',
#   'really',
#   'place',
#   'attend',
#   'site',
#   'restaurant',
#   'view',
#   'fry',
#   'nice',
#   'drop',
#   'stay',
#   'wake',
#   'uncomfortable',
#   'really',
#   'cute',
#   'staff',
#   'safe',
#   'quiet',
#   'downside',
#   'area',
#   'day',
#   'night',
#   'expedia',
#   'cancel',
#   'day',
#   'egg',
#   'fruit',
#   'monotony',
#   'terrace',
#   'book',
#   'site',
#   'public',
#   'advance',
#   'staff',
#   'noisy',
#   'bring',
#   'midnight',
#   'breakfast',
#   'fruit',
#   'egg',
#   'fruit',
#   'go',
#   'restaurant',
#   'expect',
#   'coffee',
#   'bad',
#   'feel',
#   'welcome',
#   'breakfast',
#   'spacious',
#   'dislike',
#   'activity',
#   'wall',
#   'hear',
#   'terrible',
#   'room',
#   'hotel',
#   'people',
#   'say',
#   'can',
#   'train',
#   'good',
#   'morning',
#   'never',
#   'last',
#   'check',
#   'massively',
#   'loud',
#   'aware',
#   'desk',
#   'intermittent',
#   'due',
#   'also',
#   'room',
#   'people',
#   'better_place',
#   'around',
#   'small',
#   'easily',
#   'night',
#   'say',
#   'rude',
#   'night',
#   'service',
#   'change',
#   'month',
#   'often',
#   'weak',
#   'quality',
#   'staff',
#   'stay',
#   'staff_friendly',
#   'especially',
#   'exceptional',
#   'standard',
#   'great',
#   'restaurant',
#   'overlook',
#   'garden',
#   'ground',
#   'room',
#   'helpful',
#   'hotel',
#   'stay',
#   'room',
#   'night',
#   'sleep',
#   'noise',
#   'street',
#   'notify',
#   'beforehand',
#   'agree',
#   'common',
#   'room',
#   'perhaps',
#   'floor',
#   'experience',
#   'last_night',
#   'try',
#   'come',
#   'touch',
#   'leave',
#   'try',
#   'come',
#   'additional',
#   'guy',
#   'get',
#   'room',
#   'full',
#   'tell',
#   'nicer',
#   'apparently',
#   'quick',
#   'euro_maya',
#   'rooftop_terrace',
#   'time',
#   'other',
#   'stuffy',
#   'lose',
#   'luckily',
#   'really',
#   'speak',
#   'pro',
#   'could',
#   'breakfast',
#   'con',
#   'really',
#   'guest',
#   'hotel',
#   'night',
#   'impossible',
#   'finally_got',
#   'quiet',
#   'addition',
#   'coffee',
#   'rubbish',
#   'cup',
#   'solo',
#   'positive',
#   'nice',
#   'housekeeping',
#   'never',
#   'come',
#   'great',
#   'sure',
#   'could',
#   'pad',
#   'access',
#   'access',
#   'quickly',
#   'negative',
#   'side',
#   'otherwise',
#   'hear_everythe',
#   'people',
#   'hotel',
#   'space',
#   'bag',
#   'book',
#   'triple',
#   'understand',
#   'room',
#   'mold',
#   'ceile',
#   'clean',
#   'regulate',
#   'shower',
#   'airport',
#   'pick',
#   'book',
#   'garden',
#   'room',
#   'provide',
#   'run',
#   'water',
#   'common',
#   'job',
#   'clean',
#   'fit',
#   'high',
#   'room',
#   'narrow',
#   'place',
#   'great',
#   'much',
#   'soon',
#   'realise',
#   'place',
#   'sheet',
#   'photo',
#   'see',
#   'reality',
#   'floor',
#   'eventually',
#   'warm',
#   'shower',
#   'street',
#   'room',
#   'talk',
#   'late',
#   'pro',
#   'beautiful',
#   'check',
#   'experience',
#   'arrival',
#   'keep',
#   'clean',
#   'room',
#   'courtyard',
#   'carry',
#   'full',
#   'well',
#   'regular',
#   'multiple',
#   'get',
#   'thimble',
#   'great',
#   'sort',
#   'thank',
#   'breakfast',
#   'good',
#   'great',
#   'want',
#   'start',
#   'visitor',
#   'arrive',
#   'ask',
#   'clearly',
#   'go',
#   'location',
#   'location',
#   'nice',
#   'location',
#   'get',
#   'suite',
#   'call',
#   'cramped',
#   'also',
#   'fan',
#   'stuffy',
#   'breakfast',
#   'lovely',
#   'location',
#   'top',
#   'nice',
#   'breakfast_include',
#   'coffee_tea',
#   'cold',
#   'let',
#   'lock',
#   'use',
#   'call',
#   'find',
#   'service',
#   'market',
#   'travel',
#   'sparsely',
#   'decorate',
#   'public',
#   'area',
#   'stay',
#   'spend',
#   'would',
#   'downstairs',
#   'subject',
#   'night',
#   'room',
#   'clean',
#   'double',
#   'mistake',
#   'doctor',
#   'trust',
#   'towel',
#   'night',
#   'old',
#   'old',
#   'leisure',
#   'always',
#   'staff',
#   'area',
#   'stay',
#   'rude',
#   'definitely',
#   'friendly',
#   'know',
#   'stay',
#   'change',
#   'locate',
#   'noisy',
#   'loud',
#   'people',
#   'night',
#   'cash',
#   'reluctant',
#   'try',
#   'door',
#   'assistance',
#   'young',
#   'female',
#   'however',
#   'shower',
#   'family',
#   'keep',
#   'people',
#   'clean',
#   'staff',
#   'least',
#   'close',
#   'clerk',
#   'pay',
#   'charge',
#   'bed',
#   'group',
#   'central_park',
#   'quite',
#   'friendly',
#   'sleep',
#   'tour',
#   'arrive',
#   'hour',
#   'make',
#   'peaceful',
#   'friendly',
#   'one',
#   'smell',
#   'alarm',
#   'sound',
#   'control',
#   'poor',
#   'give',
#   'absolutely',
#   'ask',
#   'minute',
#   'make',
#   'old',
#   'run',
#   'road',
#   'thin',
#   'matress',
#   'thumb',
#   'mainly',
#   'retrospect',
#   'satisfaction',
#   'much',
#   'simply',
#   'many',
#   'considerably',
#   'month',
#   'old',
#   'sauna',
#   'deck',
#   'patio',
#   'day',
#   'wifi',
#   'disappointment',
#   'include',
#   'dining',
#   'area',
#   'fountain',
#   'well',
#   'great_views',
#   'pet',
#   'visit',
#   'small',
#   'clean',
#   'hotel',
#   'cafe',
#   'hotel',
#   'parking',
#   'expect',
#   'room',
#   'tariff',
#   'quite',
#   'food',
#   'great_views',
#   'hotel',
#   'yet',
#   'share',
#   'pm',
#   'say',
#   'hotel',
#   'great',
#   'breakfast',
#   'issue',
#   'people',
#   'bit',
#   'much',
#   'music',
#   'staff',
#   'mistake',
#   'end',
#   'pay',
#   'check',
#   'room',
#   'snore',
#   'insulation',
#   'breakfast',
#   'small',
#   'attend',
#   'church',
#   'next_door',
#   'decent',
#   'stay',
#   'hotel',
#   'shake',
#   'stay',
#   'bad',
#   'lovely',
#   'room',
#   'restaurant',
#   'nice',
#   'anyway',
#   'see',
#   'hope',
#   'date',
#   'want',
#   'cute',
#   'pretty',
#   'home',
#   'stair',
#   'location',
#   'night',
#   'dinner',
#   'nice',
#   'book',
#   'book',
#   'however',
#   'barely',
#   'remarkable',
#   'bail',
#   'wedding',
#   'hotel',
#   'wife',
#   'clerk',
#   'buffet',
#   'guest',
#   'sit',
#   'go',
#   'tell',
#   'menu',
#   'staff',
#   'go',
#   'review',
#   'ago',
#   'hostel',
#   'fine',
#   'also',
#   'welcome',
#   'time',
#   'catch',
#   'leave',
#   'notice',
#   'noisy',
#   'messy',
#   'really',
#   'place',
#   'walk',
#   'say',
#   'literally',
#   'price',
#   'unprofessional',
#   'make',
#   'delay',
#   'go',
#   'worth',
#   'salt',
#   'never',
#   'location',
#   'interrupted',
#   'arm',
#   'half',
#   'christian',
#   'helpful',
#   'issue',
#   'lovely',
#   'conveniently_locate',
#   'hotel',
#   'landmark',
#   'style',
#   'charm',
#   'category',
#   'could',
#   'comfortable',
#   'lot',
#   'apart',
#   'breakfast',
#   'acceptable',
#   'photo',
#   'dreadful',
#   'euro_maya',
#   'management',
#   'disgusted',
#   'book',
#   'attraction',
#   'market',
#   'walk',
#   'drive',
#   'hotel',
#   'spacious',
#   'courtyard',
#   'get',
#   'breakfast',
#   'wifi',
#   'ask',
#   'arrive',
#   'construction',
#   'move',
#   'cheap',
#   'staff',
#   'say',
#   'room',
#   'cheap',
#   'staffed',
#   'liar',
#   'great_location',
#   'room',
#   'basic',
#   ...],
#  'validation': []}
